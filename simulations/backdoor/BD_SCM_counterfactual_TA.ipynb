# %%
# Imports
import torch
import numpy as np
import random

# Causal_cocycle imports
from causal_cocycle.model_factory import FlowFactory
from causal_cocycle.loss import FlowLoss
from causal_cocycle.optimise_new import validate, optimise
from causal_cocycle.kernels import gaussian_kernel
from causal_cocycle.helper_functions import kolmogorov_distance

# Import the DGP and policy functions from BD.py
from BD import DGP, policy, new_policy

# Import configs 
from BD_scm_config_ta import model_config, opt_config
from BD_dgp_config import dgp_config

import matplotlib.pyplot as plt

# %%
# Generating observatioanl data with configs
seed = 0
N = int(dgp_config['N']/2)
torch.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)
Z,X,Y = DGP(policy = policy,**dgp_config)
Z1,X1,Y1 = Z[:N], X[:N],Y[:N]
Z2,X2,Y2 = Z[N:], X[N:],Y[N:]
plt.scatter(Z @ dgp_config['projection_coeffs'],torch.sigmoid(Y), s = 10);
plt.show()

# Generating interventional data with configs
torch.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)
Zint,Xint,Yint = DGP(policy = new_policy,**dgp_config)
Zint1,Xint1,Yint1 = Zint[:N], Xint[:N],Yint[:N]
Zint2,Xint2,Yint2 = Zint[N:], Xint[N:],Yint[N:]
plt.scatter(Zint @ dgp_config['projection_coeffs'],torch.sigmoid(Yint), s = 10);

# Random dataset shuffle
id = torch.randperm(Z.size(0))
Ztr,Xtr,Ytr = Z[id],X[id],Y[id]

# %%
# Model construction
input_dim = dgp_config['D']
factory = FlowFactory(input_dim+1, model_config)
models, hyper_args = factory.build_models()
print(f"Constructed {len(models)} candidate models.")
# Out:
# Constructed 3 candidate models.

# %%
# Loss construction
loss= FlowLoss()

# %%
# 1. Best overall model (choose one candidate based on average CV loss, then retrain on full training set)
final_model_overall, val_loss_overall = validate(
    models, 
    loss, 
    Xtr, Ytr,
    loss_val=loss,
    method="fixed",
    train_val_split=0.8,  # 2-fold CV: 50% training per fold.
    opt_kwargs=opt_config,
    hyper_kwargs=hyper_args,
    choose_best_model="overall",
    retrain=True
)
print(f"Best overall model validation loss: {val_loss_overall:.4f}")
# Out:
# Epoch 1/100, Training Loss: 1.5359
# Epoch 2/100, Training Loss: 1.2180
# Epoch 3/100, Training Loss: 0.8798
# Epoch 4/100, Training Loss: 0.7427
# Epoch 5/100, Training Loss: 0.6470
# Epoch 6/100, Training Loss: 0.5560
# Epoch 7/100, Training Loss: 0.5587
# Epoch 8/100, Training Loss: 0.4753
# Epoch 9/100, Training Loss: 0.5115
# Epoch 10/100, Training Loss: 0.4671
# Epoch 11/100, Training Loss: 0.4408
# Epoch 12/100, Training Loss: 0.4334
# Epoch 13/100, Training Loss: 0.4010
# Epoch 14/100, Training Loss: 0.4043
# Epoch 15/100, Training Loss: 0.4269
# Epoch 16/100, Training Loss: 0.3620
# Epoch 17/100, Training Loss: 0.3923
# Epoch 18/100, Training Loss: 0.3675
# Epoch 19/100, Training Loss: 0.3578
# Epoch 20/100, Training Loss: 0.3410
# Epoch 21/100, Training Loss: 0.3598
# Epoch 22/100, Training Loss: 0.3176
# Epoch 23/100, Training Loss: 0.3367
# Epoch 24/100, Training Loss: 0.3059
# Epoch 25/100, Training Loss: 0.3129
# Epoch 26/100, Training Loss: 0.3291
# Epoch 27/100, Training Loss: 0.2803
# Epoch 28/100, Training Loss: 0.2914
# Epoch 29/100, Training Loss: 0.3176
# Epoch 30/100, Training Loss: 0.3034
# Epoch 31/100, Training Loss: 0.2654
# Epoch 32/100, Training Loss: 0.2838
# Epoch 33/100, Training Loss: 0.3234
# Epoch 34/100, Training Loss: 0.2763
# Epoch 35/100, Training Loss: 0.2993
# Epoch 36/100, Training Loss: 0.3023
# Epoch 37/100, Training Loss: 0.2801
# Epoch 38/100, Training Loss: 0.2468
# Epoch 39/100, Training Loss: 0.3033
# Epoch 40/100, Training Loss: 0.2691
# Epoch 41/100, Training Loss: 0.2845
# Epoch 42/100, Training Loss: 0.2557
# Epoch 43/100, Training Loss: 0.2769
# Epoch 44/100, Training Loss: 0.2599
# Epoch 45/100, Training Loss: 0.2659
# Epoch 46/100, Training Loss: 0.2502
# Epoch 47/100, Training Loss: 0.2940
# Epoch 48/100, Training Loss: 0.2816
# Epoch 49/100, Training Loss: 0.2706
# Epoch 50/100, Training Loss: 0.2607
# Epoch 51/100, Training Loss: 0.2792
# Epoch 52/100, Training Loss: 0.2243
# Epoch 53/100, Training Loss: 0.2752
# Epoch 54/100, Training Loss: 0.2704
# Epoch 55/100, Training Loss: 0.2886
# Epoch 56/100, Training Loss: 0.2625
# Epoch 57/100, Training Loss: 0.2671
# Epoch 58/100, Training Loss: 0.2747
# Epoch 59/100, Training Loss: 0.2403
# Epoch 60/100, Training Loss: 0.3061
# Epoch 61/100, Training Loss: 0.2396
# Epoch 62/100, Training Loss: 0.2563
# Epoch 63/100, Training Loss: 0.2836
# Epoch 64/100, Training Loss: 0.2632
# Epoch 65/100, Training Loss: 0.2552
# Epoch 66/100, Training Loss: 0.2472
# Epoch 67/100, Training Loss: 0.2666
# Epoch 68/100, Training Loss: 0.2983
# Epoch 69/100, Training Loss: 0.2751
# Epoch 70/100, Training Loss: 0.2912
# Epoch 71/100, Training Loss: 0.2694
# Epoch 72/100, Training Loss: 0.2951
# Epoch 73/100, Training Loss: 0.2826
# Epoch 74/100, Training Loss: 0.2665
# Epoch 75/100, Training Loss: 0.2806
# Epoch 76/100, Training Loss: 0.2788
# Epoch 77/100, Training Loss: 0.2737
# Epoch 78/100, Training Loss: 0.2765
# Epoch 79/100, Training Loss: 0.2777
# Epoch 80/100, Training Loss: 0.3191
# Epoch 81/100, Training Loss: 0.2725
# Epoch 82/100, Training Loss: 0.2668
# Epoch 83/100, Training Loss: 0.2766
# Epoch 84/100, Training Loss: 0.2729
# Epoch 85/100, Training Loss: 0.2590
# Epoch 86/100, Training Loss: 0.2946
# Epoch 87/100, Training Loss: 0.2600
# Epoch 88/100, Training Loss: 0.2664
# Epoch 89/100, Training Loss: 0.2977
# Epoch 90/100, Training Loss: 0.2544
# Epoch 91/100, Training Loss: 0.2676
# Epoch 92/100, Training Loss: 0.2871
# Epoch 93/100, Training Loss: 0.2499
# Epoch 94/100, Training Loss: 0.2647
# Epoch 95/100, Training Loss: 0.2843
# Epoch 96/100, Training Loss: 0.2761
# Epoch 97/100, Training Loss: 0.2609
# Epoch 98/100, Training Loss: 0.2923
# Epoch 99/100, Training Loss: 0.2542
# Epoch 100/100, Training Loss: 0.3286
# Validation Loss: 0.5740
# Model 0, Fold 0: Validation Loss = 0.5740
# Epoch 1/100, Training Loss: 1.1894
# Epoch 2/100, Training Loss: 0.9945
# Epoch 3/100, Training Loss: 0.8987
# Epoch 4/100, Training Loss: 0.8409
# Epoch 5/100, Training Loss: 0.7884
# Epoch 6/100, Training Loss: 0.6597
# Epoch 7/100, Training Loss: 0.6298
# Epoch 8/100, Training Loss: 0.5568
# Epoch 9/100, Training Loss: 0.5474
# Epoch 10/100, Training Loss: 0.5119
# Epoch 11/100, Training Loss: 0.5037
# Epoch 12/100, Training Loss: 0.4907
# Epoch 13/100, Training Loss: 0.4787
# Epoch 14/100, Training Loss: 0.4580
# Epoch 15/100, Training Loss: 0.4771
# Epoch 16/100, Training Loss: 0.4233
# Epoch 17/100, Training Loss: 0.4497
# Epoch 18/100, Training Loss: 0.4329
# Epoch 19/100, Training Loss: 0.4275
# Epoch 20/100, Training Loss: 0.3952
# Epoch 21/100, Training Loss: 0.4023
# Epoch 22/100, Training Loss: 0.3574
# Epoch 23/100, Training Loss: 0.3501
# Epoch 24/100, Training Loss: 0.3699
# Epoch 25/100, Training Loss: 0.3489
# Epoch 26/100, Training Loss: 0.3444
# Epoch 27/100, Training Loss: 0.3825
# Epoch 28/100, Training Loss: 0.3607
# Epoch 29/100, Training Loss: 0.3626
# Epoch 30/100, Training Loss: 0.3692
# Epoch 31/100, Training Loss: 0.3271
# Epoch 32/100, Training Loss: 0.3418
# Epoch 33/100, Training Loss: 0.3438
# Epoch 34/100, Training Loss: 0.3099
# Epoch 35/100, Training Loss: 0.3155
# Epoch 36/100, Training Loss: 0.3136
# Epoch 37/100, Training Loss: 0.3269
# Epoch 38/100, Training Loss: 0.3115
# Epoch 39/100, Training Loss: 0.3103
# Epoch 40/100, Training Loss: 0.3229
# Epoch 41/100, Training Loss: 0.3839
# Epoch 42/100, Training Loss: 0.3287
# Epoch 43/100, Training Loss: 0.3109
# Epoch 44/100, Training Loss: 0.3233
# Epoch 45/100, Training Loss: 0.3105
# Epoch 46/100, Training Loss: 0.3217
# Epoch 47/100, Training Loss: 0.2924
# Epoch 48/100, Training Loss: 0.2734
# Epoch 49/100, Training Loss: 0.3192
# Epoch 50/100, Training Loss: 0.2934
# Epoch 51/100, Training Loss: 0.3604
# Epoch 52/100, Training Loss: 0.3203
# Epoch 53/100, Training Loss: 0.3218
# Epoch 54/100, Training Loss: 0.3440
# Epoch 55/100, Training Loss: 0.3410
# Epoch 56/100, Training Loss: 0.3096
# Epoch 57/100, Training Loss: 0.2886
# Epoch 58/100, Training Loss: 0.3223
# Epoch 59/100, Training Loss: 0.2893
# Epoch 60/100, Training Loss: 0.3076
# Epoch 61/100, Training Loss: 0.3276
# Epoch 62/100, Training Loss: 0.3468
# Epoch 63/100, Training Loss: 0.2878
# Epoch 64/100, Training Loss: 0.2965
# Epoch 65/100, Training Loss: 0.3395
# Epoch 66/100, Training Loss: 0.3069
# Epoch 67/100, Training Loss: 0.3220
# Epoch 68/100, Training Loss: 0.3098
# Epoch 69/100, Training Loss: 0.2964
# Epoch 70/100, Training Loss: 0.3016
# Epoch 71/100, Training Loss: 0.3148
# Epoch 72/100, Training Loss: 0.3074
# Epoch 73/100, Training Loss: 0.3393
# Epoch 74/100, Training Loss: 0.2922
# Epoch 75/100, Training Loss: 0.3325
# Epoch 76/100, Training Loss: 0.3199
# Epoch 77/100, Training Loss: 0.3432
# Epoch 78/100, Training Loss: 0.3159
# Epoch 79/100, Training Loss: 0.2932
# Epoch 80/100, Training Loss: 0.3355
# Epoch 81/100, Training Loss: 0.3049
# Epoch 82/100, Training Loss: 0.3491
# Epoch 83/100, Training Loss: 0.3513
# Epoch 84/100, Training Loss: 0.2985
# Epoch 85/100, Training Loss: 0.3108
# Epoch 86/100, Training Loss: 0.3399
# Epoch 87/100, Training Loss: 0.3216
# Epoch 88/100, Training Loss: 0.3198
# Epoch 89/100, Training Loss: 0.2809
# Epoch 90/100, Training Loss: 0.3061
# Epoch 91/100, Training Loss: 0.3175
# Epoch 92/100, Training Loss: 0.2996
# Epoch 93/100, Training Loss: 0.2933
# Epoch 94/100, Training Loss: 0.3199
# Epoch 95/100, Training Loss: 0.3301
# Epoch 96/100, Training Loss: 0.3015
# Epoch 97/100, Training Loss: 0.3002
# Epoch 98/100, Training Loss: 0.3345
# Epoch 99/100, Training Loss: 0.2929
# Epoch 100/100, Training Loss: 0.3035
# Validation Loss: 0.6164
# Model 1, Fold 0: Validation Loss = 0.6164
# Epoch 1/100, Training Loss: 1.1412
# Epoch 2/100, Training Loss: 0.9851
# Epoch 3/100, Training Loss: 0.9525
# Epoch 4/100, Training Loss: 0.9654
# Epoch 5/100, Training Loss: 0.8961
# Epoch 6/100, Training Loss: 0.9180
# Epoch 7/100, Training Loss: 0.9300
# Epoch 8/100, Training Loss: 0.8821
# Epoch 9/100, Training Loss: 0.8548
# Epoch 10/100, Training Loss: 0.8783
# Epoch 11/100, Training Loss: 0.8131
# Epoch 12/100, Training Loss: 0.8335
# Epoch 13/100, Training Loss: 0.8590
# Epoch 14/100, Training Loss: 0.8312
# Epoch 15/100, Training Loss: 0.7812
# Epoch 16/100, Training Loss: 0.8449
# Epoch 17/100, Training Loss: 0.7980
# Epoch 18/100, Training Loss: 0.7924
# Epoch 19/100, Training Loss: 0.7678
# Epoch 20/100, Training Loss: 0.7342
# Epoch 21/100, Training Loss: 0.7179
# Epoch 22/100, Training Loss: 0.7304
# Epoch 23/100, Training Loss: 0.7203
# Epoch 24/100, Training Loss: 0.7328
# Epoch 25/100, Training Loss: 0.7142
# Epoch 26/100, Training Loss: 0.7154
# Epoch 27/100, Training Loss: 0.7122
# Epoch 28/100, Training Loss: 0.6757
# Epoch 29/100, Training Loss: 0.7202
# Epoch 30/100, Training Loss: 0.6967
# Epoch 31/100, Training Loss: 0.7251
# Epoch 32/100, Training Loss: 0.6801
# Epoch 33/100, Training Loss: 0.7025
# Epoch 34/100, Training Loss: 0.6987
# Epoch 35/100, Training Loss: 0.7158
# Epoch 36/100, Training Loss: 0.7110
# Epoch 37/100, Training Loss: 0.6967
# Epoch 38/100, Training Loss: 0.6540
# Epoch 39/100, Training Loss: 0.7016
# Epoch 40/100, Training Loss: 0.7059
# Epoch 41/100, Training Loss: 0.6886
# Epoch 42/100, Training Loss: 0.6792
# Epoch 43/100, Training Loss: 0.6666
# Epoch 44/100, Training Loss: 0.6947
# Epoch 45/100, Training Loss: 0.7137
# Epoch 46/100, Training Loss: 0.6998
# Epoch 47/100, Training Loss: 0.6654
# Epoch 48/100, Training Loss: 0.7013
# Epoch 49/100, Training Loss: 0.6854
# Epoch 50/100, Training Loss: 0.6640
# Epoch 51/100, Training Loss: 0.6632
# Epoch 52/100, Training Loss: 0.6564
# Epoch 53/100, Training Loss: 0.6561
# Epoch 54/100, Training Loss: 0.6660
# Epoch 55/100, Training Loss: 0.6549
# Epoch 56/100, Training Loss: 0.6770
# Epoch 57/100, Training Loss: 0.6738
# Epoch 58/100, Training Loss: 0.6826
# Epoch 59/100, Training Loss: 0.6850
# Epoch 60/100, Training Loss: 0.6832
# Epoch 61/100, Training Loss: 0.6820
# Epoch 62/100, Training Loss: 0.6582
# Epoch 63/100, Training Loss: 0.6561
# Epoch 64/100, Training Loss: 0.6841
# Epoch 65/100, Training Loss: 0.6833
# Epoch 66/100, Training Loss: 0.6553
# Epoch 67/100, Training Loss: 0.6632
# Epoch 68/100, Training Loss: 0.6841
# Epoch 69/100, Training Loss: 0.6699
# Epoch 70/100, Training Loss: 0.6582
# Epoch 71/100, Training Loss: 0.6842
# Epoch 72/100, Training Loss: 0.6688
# Epoch 73/100, Training Loss: 0.6924
# Epoch 74/100, Training Loss: 0.6708
# Epoch 75/100, Training Loss: 0.6740
# Epoch 76/100, Training Loss: 0.6471
# Epoch 77/100, Training Loss: 0.6715
# Epoch 78/100, Training Loss: 0.7191
# Epoch 79/100, Training Loss: 0.6779
# Epoch 80/100, Training Loss: 0.7002
# Epoch 81/100, Training Loss: 0.6959
# Epoch 82/100, Training Loss: 0.6546
# Epoch 83/100, Training Loss: 0.6799
# Epoch 84/100, Training Loss: 0.6841
# Epoch 85/100, Training Loss: 0.6723
# Epoch 86/100, Training Loss: 0.6846
# Epoch 87/100, Training Loss: 0.6851
# Epoch 88/100, Training Loss: 0.6730
# Epoch 89/100, Training Loss: 0.6478
# Epoch 90/100, Training Loss: 0.6670
# Epoch 91/100, Training Loss: 0.7164
# Epoch 92/100, Training Loss: 0.6701
# Epoch 93/100, Training Loss: 0.6886
# Epoch 94/100, Training Loss: 0.6798
# Epoch 95/100, Training Loss: 0.6685
# Epoch 96/100, Training Loss: 0.6707
# Epoch 97/100, Training Loss: 0.6696
# Epoch 98/100, Training Loss: 0.6711
# Epoch 99/100, Training Loss: 0.6567
# Epoch 100/100, Training Loss: 0.7041
# Validation Loss: 0.7610
# Model 2, Fold 0: Validation Loss = 0.7610
# Best overall model index: 0 with average validation loss 0.5740
# Retraining best model on full dataset...
# Epoch 1/100, Training Loss: 1.5069
# Epoch 2/100, Training Loss: 1.0869
# Epoch 3/100, Training Loss: 0.7947
# Epoch 4/100, Training Loss: 0.6650
# Epoch 5/100, Training Loss: 0.6234
# Epoch 6/100, Training Loss: 0.5261
# Epoch 7/100, Training Loss: 0.5060
# Epoch 8/100, Training Loss: 0.4863
# Epoch 9/100, Training Loss: 0.4321
# Epoch 10/100, Training Loss: 0.4554
# Epoch 11/100, Training Loss: 0.4420
# Epoch 12/100, Training Loss: 0.3929
# Epoch 13/100, Training Loss: 0.3837
# Epoch 14/100, Training Loss: 0.3991
# Epoch 15/100, Training Loss: 0.3671
# Epoch 16/100, Training Loss: 0.3698
# Epoch 17/100, Training Loss: 0.3831
# Epoch 18/100, Training Loss: 0.3927
# Epoch 19/100, Training Loss: 0.3140
# Epoch 20/100, Training Loss: 0.3538
# Epoch 21/100, Training Loss: 0.3473
# Epoch 22/100, Training Loss: 0.3349
# Epoch 23/100, Training Loss: 0.3550
# Epoch 24/100, Training Loss: 0.3387
# Epoch 25/100, Training Loss: 0.3461
# Epoch 26/100, Training Loss: 0.3191
# Epoch 27/100, Training Loss: 0.3198
# Epoch 28/100, Training Loss: 0.3429
# Epoch 29/100, Training Loss: 0.3094
# Epoch 30/100, Training Loss: 0.3118
# Epoch 31/100, Training Loss: 0.3205
# Epoch 32/100, Training Loss: 0.3195
# Epoch 33/100, Training Loss: 0.3233
# Epoch 34/100, Training Loss: 0.3147
# Epoch 35/100, Training Loss: 0.2953
# Epoch 36/100, Training Loss: 0.2978
# Epoch 37/100, Training Loss: 0.2851
# Epoch 38/100, Training Loss: 0.2932
# Epoch 39/100, Training Loss: 0.2874
# Epoch 40/100, Training Loss: 0.3134
# Epoch 41/100, Training Loss: 0.3107
# Epoch 42/100, Training Loss: 0.2948
# Epoch 43/100, Training Loss: 0.2894
# Epoch 44/100, Training Loss: 0.2491
# Epoch 45/100, Training Loss: 0.2902
# Epoch 46/100, Training Loss: 0.3166
# Epoch 47/100, Training Loss: 0.3143
# Epoch 48/100, Training Loss: 0.2807
# Epoch 49/100, Training Loss: 0.2943
# Epoch 50/100, Training Loss: 0.2984
# Epoch 51/100, Training Loss: 0.3175
# Epoch 52/100, Training Loss: 0.2672
# Epoch 53/100, Training Loss: 0.2895
# Epoch 54/100, Training Loss: 0.2670
# Epoch 55/100, Training Loss: 0.3148
# Epoch 56/100, Training Loss: 0.3191
# Epoch 57/100, Training Loss: 0.3117
# Epoch 58/100, Training Loss: 0.2991
# Epoch 59/100, Training Loss: 0.2741
# Epoch 60/100, Training Loss: 0.3043
# Epoch 61/100, Training Loss: 0.3069
# Epoch 62/100, Training Loss: 0.2940
# Epoch 63/100, Training Loss: 0.2706
# Epoch 64/100, Training Loss: 0.2675
# Epoch 65/100, Training Loss: 0.2984
# Epoch 66/100, Training Loss: 0.2957
# Epoch 67/100, Training Loss: 0.2867
# Epoch 68/100, Training Loss: 0.3075
# Epoch 69/100, Training Loss: 0.3146
# Epoch 70/100, Training Loss: 0.3013
# Epoch 71/100, Training Loss: 0.2875
# Epoch 72/100, Training Loss: 0.2945
# Epoch 73/100, Training Loss: 0.3190
# Epoch 74/100, Training Loss: 0.2839
# Epoch 75/100, Training Loss: 0.2816
# Epoch 76/100, Training Loss: 0.2978
# Epoch 77/100, Training Loss: 0.3275
# Epoch 78/100, Training Loss: 0.3259
# Epoch 79/100, Training Loss: 0.3065
# Epoch 80/100, Training Loss: 0.2942
# Epoch 81/100, Training Loss: 0.2994
# Epoch 82/100, Training Loss: 0.3017
# Epoch 83/100, Training Loss: 0.3122
# Epoch 84/100, Training Loss: 0.3206
# Epoch 85/100, Training Loss: 0.2934
# Epoch 86/100, Training Loss: 0.3222
# Epoch 87/100, Training Loss: 0.3086
# Epoch 88/100, Training Loss: 0.2741
# Epoch 89/100, Training Loss: 0.3034
# Epoch 90/100, Training Loss: 0.3089
# Epoch 91/100, Training Loss: 0.2863
# Epoch 92/100, Training Loss: 0.2671
# Epoch 93/100, Training Loss: 0.3402
# Epoch 94/100, Training Loss: 0.2911
# Epoch 95/100, Training Loss: 0.2862
# Epoch 96/100, Training Loss: 0.2544
# Epoch 97/100, Training Loss: 0.2929
# Epoch 98/100, Training Loss: 0.3165
# Epoch 99/100, Training Loss: 0.3005
# Epoch 100/100, Training Loss: 0.3162
# Best overall model validation loss: 0.5740

# %%
# 2. Best model per fold (select one candidate per fold without retraining)
final_models_per_fold, val_loss_per_fold = validate(
    models, 
    loss, 
    Xtr, Ytr,
    loss_val=loss,
    method="CV",
    train_val_split=0.5,
    opt_kwargs=opt_config,
    hyper_kwargs=hyper_args,
    choose_best_model="per fold",
    retrain=False
)
print(f"Best per-fold model validation losses: {val_loss_per_fold}")
# Out:
# Epoch 1/100, Training Loss: 1.6193
# Epoch 2/100, Training Loss: 1.3622
# Epoch 3/100, Training Loss: 1.2419
# Epoch 4/100, Training Loss: 1.1741
# Epoch 5/100, Training Loss: 1.0940
# Epoch 6/100, Training Loss: 1.0105
# Epoch 7/100, Training Loss: 1.0154
# Epoch 8/100, Training Loss: 0.8964
# Epoch 9/100, Training Loss: 0.8507
# Epoch 10/100, Training Loss: 0.8303
# Epoch 11/100, Training Loss: 0.8149
# Epoch 12/100, Training Loss: 0.7472
# Epoch 13/100, Training Loss: 0.7756
# Epoch 14/100, Training Loss: 0.7480
# Epoch 15/100, Training Loss: 0.6656
# Epoch 16/100, Training Loss: 0.7476
# Epoch 17/100, Training Loss: 0.6428
# Epoch 18/100, Training Loss: 0.6211
# Epoch 19/100, Training Loss: 0.6527
# Epoch 20/100, Training Loss: 0.6185
# Epoch 21/100, Training Loss: 0.6242
# Epoch 22/100, Training Loss: 0.6193
# Epoch 23/100, Training Loss: 0.6645
# Epoch 24/100, Training Loss: 0.5843
# Epoch 25/100, Training Loss: 0.5980
# Epoch 26/100, Training Loss: 0.6001
# Epoch 27/100, Training Loss: 0.5720
# Epoch 28/100, Training Loss: 0.5385
# Epoch 29/100, Training Loss: 0.5149
# Epoch 30/100, Training Loss: 0.6612
# Epoch 31/100, Training Loss: 0.5205
# Epoch 32/100, Training Loss: 0.5664
# Epoch 33/100, Training Loss: 0.4965
# Epoch 34/100, Training Loss: 0.5460
# Epoch 35/100, Training Loss: 0.5533
# Epoch 36/100, Training Loss: 0.5447
# Epoch 37/100, Training Loss: 0.5353
# Epoch 38/100, Training Loss: 0.5563
# Epoch 39/100, Training Loss: 0.5306
# Epoch 40/100, Training Loss: 0.4731
# Epoch 41/100, Training Loss: 0.5185
# Epoch 42/100, Training Loss: 0.6169
# Epoch 43/100, Training Loss: 0.5036
# Epoch 44/100, Training Loss: 0.5645
# Epoch 45/100, Training Loss: 0.5049
# Epoch 46/100, Training Loss: 0.4839
# Epoch 47/100, Training Loss: 0.5801
# Epoch 48/100, Training Loss: 0.4825
# Epoch 49/100, Training Loss: 0.5403
# Epoch 50/100, Training Loss: 0.4948
# Epoch 51/100, Training Loss: 0.5452
# Epoch 52/100, Training Loss: 0.4413
# Epoch 53/100, Training Loss: 0.4794
# Epoch 54/100, Training Loss: 0.5059
# Epoch 55/100, Training Loss: 0.5614
# Epoch 56/100, Training Loss: 0.4885
# Epoch 57/100, Training Loss: 0.5461
# Epoch 58/100, Training Loss: 0.5258
# Epoch 59/100, Training Loss: 0.5235
# Epoch 60/100, Training Loss: 0.5290
# Epoch 61/100, Training Loss: 0.5256
# Epoch 62/100, Training Loss: 0.5015
# Epoch 63/100, Training Loss: 0.5245
# Epoch 64/100, Training Loss: 0.5533
# Epoch 65/100, Training Loss: 0.5447
# Epoch 66/100, Training Loss: 0.5016
# Epoch 67/100, Training Loss: 0.5467
# Epoch 68/100, Training Loss: 0.5322
# Epoch 69/100, Training Loss: 0.4997
# Epoch 70/100, Training Loss: 0.5343
# Epoch 71/100, Training Loss: 0.5487
# Epoch 72/100, Training Loss: 0.5181
# Epoch 73/100, Training Loss: 0.5578
# Epoch 74/100, Training Loss: 0.5766
# Epoch 75/100, Training Loss: 0.5169
# Epoch 76/100, Training Loss: 0.5727
# Epoch 77/100, Training Loss: 0.5556
# Epoch 78/100, Training Loss: 0.5109
# Epoch 79/100, Training Loss: 0.5296
# Epoch 80/100, Training Loss: 0.4986
# Epoch 81/100, Training Loss: 0.4817
# Epoch 82/100, Training Loss: 0.5419
# Epoch 83/100, Training Loss: 0.5850
# Epoch 84/100, Training Loss: 0.5435
# Epoch 85/100, Training Loss: 0.5661
# Epoch 86/100, Training Loss: 0.5389
# Epoch 87/100, Training Loss: 0.5338
# Epoch 88/100, Training Loss: 0.5253
# Epoch 89/100, Training Loss: 0.5471
# Epoch 90/100, Training Loss: 0.5003
# Epoch 91/100, Training Loss: 0.4793
# Epoch 92/100, Training Loss: 0.5138
# Epoch 93/100, Training Loss: 0.5042
# Epoch 94/100, Training Loss: 0.5523
# Epoch 95/100, Training Loss: 0.5118
# Epoch 96/100, Training Loss: 0.4909
# Epoch 97/100, Training Loss: 0.5267
# Epoch 98/100, Training Loss: 0.4701
# Epoch 99/100, Training Loss: 0.6138
# Epoch 100/100, Training Loss: 0.5362
# Validation Loss: 0.7563
# Model 0, Fold 0: Validation Loss = 0.7563
# Epoch 1/100, Training Loss: 1.5986
# Epoch 2/100, Training Loss: 1.3233
# Epoch 3/100, Training Loss: 1.2239
# Epoch 4/100, Training Loss: 1.1065
# Epoch 5/100, Training Loss: 1.0582
# Epoch 6/100, Training Loss: 0.9645
# Epoch 7/100, Training Loss: 0.8764
# Epoch 8/100, Training Loss: 0.7761
# Epoch 9/100, Training Loss: 0.7191
# Epoch 10/100, Training Loss: 0.6593
# Epoch 11/100, Training Loss: 0.6195
# Epoch 12/100, Training Loss: 0.5830
# Epoch 13/100, Training Loss: 0.4901
# Epoch 14/100, Training Loss: 0.4540
# Epoch 15/100, Training Loss: 0.4564
# Epoch 16/100, Training Loss: 0.4027
# Epoch 17/100, Training Loss: 0.3828
# Epoch 18/100, Training Loss: 0.3510
# Epoch 19/100, Training Loss: 0.3703
# Epoch 20/100, Training Loss: 0.3246
# Epoch 21/100, Training Loss: 0.3457
# Epoch 22/100, Training Loss: 0.3374
# Epoch 23/100, Training Loss: 0.3359
# Epoch 24/100, Training Loss: 0.3115
# Epoch 25/100, Training Loss: 0.2686
# Epoch 26/100, Training Loss: 0.2450
# Epoch 27/100, Training Loss: 0.2709
# Epoch 28/100, Training Loss: 0.2897
# Epoch 29/100, Training Loss: 0.2910
# Epoch 30/100, Training Loss: 0.2468
# Epoch 31/100, Training Loss: 0.2360
# Epoch 32/100, Training Loss: 0.2459
# Epoch 33/100, Training Loss: 0.2417
# Epoch 34/100, Training Loss: 0.1780
# Epoch 35/100, Training Loss: 0.2323
# Epoch 36/100, Training Loss: 0.2701
# Epoch 37/100, Training Loss: 0.2396
# Epoch 38/100, Training Loss: 0.1926
# Epoch 39/100, Training Loss: 0.2327
# Epoch 40/100, Training Loss: 0.2074
# Epoch 41/100, Training Loss: 0.2048
# Epoch 42/100, Training Loss: 0.2327
# Epoch 43/100, Training Loss: 0.1993
# Epoch 44/100, Training Loss: 0.2337
# Epoch 45/100, Training Loss: 0.1479
# Epoch 46/100, Training Loss: 0.2161
# Epoch 47/100, Training Loss: 0.2068
# Epoch 48/100, Training Loss: 0.1722
# Epoch 49/100, Training Loss: 0.1592
# Epoch 50/100, Training Loss: 0.2214
# Epoch 51/100, Training Loss: 0.2145
# Epoch 52/100, Training Loss: 0.2003
# Epoch 53/100, Training Loss: 0.2178
# Epoch 54/100, Training Loss: 0.2120
# Epoch 55/100, Training Loss: 0.1856
# Epoch 56/100, Training Loss: 0.2214
# Epoch 57/100, Training Loss: 0.1868
# Epoch 58/100, Training Loss: 0.2340
# Epoch 59/100, Training Loss: 0.1617
# Epoch 60/100, Training Loss: 0.2016
# Epoch 61/100, Training Loss: 0.2033
# Epoch 62/100, Training Loss: 0.2127
# Epoch 63/100, Training Loss: 0.2056
# Epoch 64/100, Training Loss: 0.2296
# Epoch 65/100, Training Loss: 0.2618
# Epoch 66/100, Training Loss: 0.2322
# Epoch 67/100, Training Loss: 0.1941
# Epoch 68/100, Training Loss: 0.2045
# Epoch 69/100, Training Loss: 0.2075
# Epoch 70/100, Training Loss: 0.2042
# Epoch 71/100, Training Loss: 0.2050
# Epoch 72/100, Training Loss: 0.2369
# Epoch 73/100, Training Loss: 0.2140
# Epoch 74/100, Training Loss: 0.2139
# Epoch 75/100, Training Loss: 0.2046
# Epoch 76/100, Training Loss: 0.2116
# Epoch 77/100, Training Loss: 0.2562
# Epoch 78/100, Training Loss: 0.3008
# Epoch 79/100, Training Loss: 0.2200
# Epoch 80/100, Training Loss: 0.2184
# Epoch 81/100, Training Loss: 0.2436
# Epoch 82/100, Training Loss: 0.2016
# Epoch 83/100, Training Loss: 0.2022
# Epoch 84/100, Training Loss: 0.2483
# Epoch 85/100, Training Loss: 0.2066
# Epoch 86/100, Training Loss: 0.2013
# Epoch 87/100, Training Loss: 0.1806
# Epoch 88/100, Training Loss: 0.2368
# Epoch 89/100, Training Loss: 0.2097
# Epoch 90/100, Training Loss: 0.2365
# Epoch 91/100, Training Loss: 0.2412
# Epoch 92/100, Training Loss: 0.1764
# Epoch 93/100, Training Loss: 0.2277
# Epoch 94/100, Training Loss: 0.1866
# Epoch 95/100, Training Loss: 0.1979
# Epoch 96/100, Training Loss: 0.2109
# Epoch 97/100, Training Loss: 0.1878
# Epoch 98/100, Training Loss: 0.2244
# Epoch 99/100, Training Loss: 0.1869
# Epoch 100/100, Training Loss: 0.1848
# Validation Loss: 0.5835
# Model 0, Fold 1: Validation Loss = 0.5835
# Epoch 1/100, Training Loss: 1.1777
# Epoch 2/100, Training Loss: 1.0857
# Epoch 3/100, Training Loss: 0.9710
# Epoch 4/100, Training Loss: 0.9285
# Epoch 5/100, Training Loss: 0.8378
# Epoch 6/100, Training Loss: 0.8022
# Epoch 7/100, Training Loss: 0.6968
# Epoch 8/100, Training Loss: 0.6490
# Epoch 9/100, Training Loss: 0.6731
# Epoch 10/100, Training Loss: 0.6154
# Epoch 11/100, Training Loss: 0.5527
# Epoch 12/100, Training Loss: 0.5578
# Epoch 13/100, Training Loss: 0.6168
# Epoch 14/100, Training Loss: 0.4959
# Epoch 15/100, Training Loss: 0.5278
# Epoch 16/100, Training Loss: 0.4643
# Epoch 17/100, Training Loss: 0.5031
# Epoch 18/100, Training Loss: 0.4948
# Epoch 19/100, Training Loss: 0.4695
# Epoch 20/100, Training Loss: 0.4132
# Epoch 21/100, Training Loss: 0.4436
# Epoch 22/100, Training Loss: 0.4597
# Epoch 23/100, Training Loss: 0.3732
# Epoch 24/100, Training Loss: 0.4043
# Epoch 25/100, Training Loss: 0.3561
# Epoch 26/100, Training Loss: 0.3782
# Epoch 27/100, Training Loss: 0.3576
# Epoch 28/100, Training Loss: 0.3859
# Epoch 29/100, Training Loss: 0.4290
# Epoch 30/100, Training Loss: 0.4228
# Epoch 31/100, Training Loss: 0.3583
# Epoch 32/100, Training Loss: 0.3948
# Epoch 33/100, Training Loss: 0.3645
# Epoch 34/100, Training Loss: 0.3461
# Epoch 35/100, Training Loss: 0.3837
# Epoch 36/100, Training Loss: 0.4026
# Epoch 37/100, Training Loss: 0.3652
# Epoch 38/100, Training Loss: 0.3578
# Epoch 39/100, Training Loss: 0.3390
# Epoch 40/100, Training Loss: 0.3727
# Epoch 41/100, Training Loss: 0.3620
# Epoch 42/100, Training Loss: 0.3790
# Epoch 43/100, Training Loss: 0.3177
# Epoch 44/100, Training Loss: 0.3550
# Epoch 45/100, Training Loss: 0.3557
# Epoch 46/100, Training Loss: 0.3345
# Epoch 47/100, Training Loss: 0.3571
# Epoch 48/100, Training Loss: 0.3240
# Epoch 49/100, Training Loss: 0.3786
# Epoch 50/100, Training Loss: 0.3604
# Epoch 51/100, Training Loss: 0.3219
# Epoch 52/100, Training Loss: 0.3131
# Epoch 53/100, Training Loss: 0.3510
# Epoch 54/100, Training Loss: 0.3704
# Epoch 55/100, Training Loss: 0.3164
# Epoch 56/100, Training Loss: 0.3626
# Epoch 57/100, Training Loss: 0.3710
# Epoch 58/100, Training Loss: 0.3006
# Epoch 59/100, Training Loss: 0.3734
# Epoch 60/100, Training Loss: 0.3355
# Epoch 61/100, Training Loss: 0.3243
# Epoch 62/100, Training Loss: 0.3346
# Epoch 63/100, Training Loss: 0.3454
# Epoch 64/100, Training Loss: 0.3441
# Epoch 65/100, Training Loss: 0.3622
# Epoch 66/100, Training Loss: 0.3933
# Epoch 67/100, Training Loss: 0.2923
# Epoch 68/100, Training Loss: 0.3180
# Epoch 69/100, Training Loss: 0.3133
# Epoch 70/100, Training Loss: 0.3333
# Epoch 71/100, Training Loss: 0.3130
# Epoch 72/100, Training Loss: 0.3331
# Epoch 73/100, Training Loss: 0.3092
# Epoch 74/100, Training Loss: 0.3282
# Epoch 75/100, Training Loss: 0.3718
# Epoch 76/100, Training Loss: 0.3560
# Epoch 77/100, Training Loss: 0.3696
# Epoch 78/100, Training Loss: 0.3238
# Epoch 79/100, Training Loss: 0.3518
# Epoch 80/100, Training Loss: 0.3446
# Epoch 81/100, Training Loss: 0.3338
# Epoch 82/100, Training Loss: 0.3635
# Epoch 83/100, Training Loss: 0.3715
# Epoch 84/100, Training Loss: 0.3700
# Epoch 85/100, Training Loss: 0.3341
# Epoch 86/100, Training Loss: 0.3424
# Epoch 87/100, Training Loss: 0.3749
# Epoch 88/100, Training Loss: 0.3319
# Epoch 89/100, Training Loss: 0.3801
# Epoch 90/100, Training Loss: 0.3513
# Epoch 91/100, Training Loss: 0.3623
# Epoch 92/100, Training Loss: 0.3755
# Epoch 93/100, Training Loss: 0.3041
# Epoch 94/100, Training Loss: 0.3523
# Epoch 95/100, Training Loss: 0.3791
# Epoch 96/100, Training Loss: 0.3484
# Epoch 97/100, Training Loss: 0.3473
# Epoch 98/100, Training Loss: 0.3543
# Epoch 99/100, Training Loss: 0.3781
# Epoch 100/100, Training Loss: 0.2846
# Validation Loss: 0.6291
# Model 1, Fold 0: Validation Loss = 0.6291
# Epoch 1/100, Training Loss: 1.1802
# Epoch 2/100, Training Loss: 1.1126
# Epoch 3/100, Training Loss: 0.9770
# Epoch 4/100, Training Loss: 0.8880
# Epoch 5/100, Training Loss: 0.8373
# Epoch 6/100, Training Loss: 0.8115
# Epoch 7/100, Training Loss: 0.8015
# Epoch 8/100, Training Loss: 0.7122
# Epoch 9/100, Training Loss: 0.7369
# Epoch 10/100, Training Loss: 0.6946
# Epoch 11/100, Training Loss: 0.6618
# Epoch 12/100, Training Loss: 0.6320
# Epoch 13/100, Training Loss: 0.5912
# Epoch 14/100, Training Loss: 0.6406
# Epoch 15/100, Training Loss: 0.5983
# Epoch 16/100, Training Loss: 0.5641
# Epoch 17/100, Training Loss: 0.5229
# Epoch 18/100, Training Loss: 0.5652
# Epoch 19/100, Training Loss: 0.5613
# Epoch 20/100, Training Loss: 0.5423
# Epoch 21/100, Training Loss: 0.4696
# Epoch 22/100, Training Loss: 0.4999
# Epoch 23/100, Training Loss: 0.4981
# Epoch 24/100, Training Loss: 0.4297
# Epoch 25/100, Training Loss: 0.4707
# Epoch 26/100, Training Loss: 0.4808
# Epoch 27/100, Training Loss: 0.4838
# Epoch 28/100, Training Loss: 0.4961
# Epoch 29/100, Training Loss: 0.4685
# Epoch 30/100, Training Loss: 0.4956
# Epoch 31/100, Training Loss: 0.4502
# Epoch 32/100, Training Loss: 0.4712
# Epoch 33/100, Training Loss: 0.4676
# Epoch 34/100, Training Loss: 0.4037
# Epoch 35/100, Training Loss: 0.4439
# Epoch 36/100, Training Loss: 0.4406
# Epoch 37/100, Training Loss: 0.4411
# Epoch 38/100, Training Loss: 0.4424
# Epoch 39/100, Training Loss: 0.4530
# Epoch 40/100, Training Loss: 0.3996
# Epoch 41/100, Training Loss: 0.4678
# Epoch 42/100, Training Loss: 0.4307
# Epoch 43/100, Training Loss: 0.3960
# Epoch 44/100, Training Loss: 0.4459
# Epoch 45/100, Training Loss: 0.4375
# Epoch 46/100, Training Loss: 0.4359
# Epoch 47/100, Training Loss: 0.4191
# Epoch 48/100, Training Loss: 0.3805
# Epoch 49/100, Training Loss: 0.4476
# Epoch 50/100, Training Loss: 0.4657
# Epoch 51/100, Training Loss: 0.4132
# Epoch 52/100, Training Loss: 0.4065
# Epoch 53/100, Training Loss: 0.4618
# Epoch 54/100, Training Loss: 0.4357
# Epoch 55/100, Training Loss: 0.4596
# Epoch 56/100, Training Loss: 0.3982
# Epoch 57/100, Training Loss: 0.4468
# Epoch 58/100, Training Loss: 0.4133
# Epoch 59/100, Training Loss: 0.4470
# Epoch 60/100, Training Loss: 0.4149
# Epoch 61/100, Training Loss: 0.4113
# Epoch 62/100, Training Loss: 0.4061
# Epoch 63/100, Training Loss: 0.3889
# Epoch 64/100, Training Loss: 0.3789
# Epoch 65/100, Training Loss: 0.4059
# Epoch 66/100, Training Loss: 0.4109
# Epoch 67/100, Training Loss: 0.4212
# Epoch 68/100, Training Loss: 0.4110
# Epoch 69/100, Training Loss: 0.4142
# Epoch 70/100, Training Loss: 0.4663
# Epoch 71/100, Training Loss: 0.4076
# Epoch 72/100, Training Loss: 0.4101
# Epoch 73/100, Training Loss: 0.4303
# Epoch 74/100, Training Loss: 0.4289
# Epoch 75/100, Training Loss: 0.4408
# Epoch 76/100, Training Loss: 0.4592
# Epoch 77/100, Training Loss: 0.4278
# Epoch 78/100, Training Loss: 0.4021
# Epoch 79/100, Training Loss: 0.3703
# Epoch 80/100, Training Loss: 0.4202
# Epoch 81/100, Training Loss: 0.4111
# Epoch 82/100, Training Loss: 0.3977
# Epoch 83/100, Training Loss: 0.3764
# Epoch 84/100, Training Loss: 0.4400
# Epoch 85/100, Training Loss: 0.4071
# Epoch 86/100, Training Loss: 0.4020
# Epoch 87/100, Training Loss: 0.3819
# Epoch 88/100, Training Loss: 0.4422
# Epoch 89/100, Training Loss: 0.4057
# Epoch 90/100, Training Loss: 0.4523
# Epoch 91/100, Training Loss: 0.4554
# Epoch 92/100, Training Loss: 0.4025
# Epoch 93/100, Training Loss: 0.4252
# Epoch 94/100, Training Loss: 0.4145
# Epoch 95/100, Training Loss: 0.4170
# Epoch 96/100, Training Loss: 0.4060
# Epoch 97/100, Training Loss: 0.4050
# Epoch 98/100, Training Loss: 0.3849
# Epoch 99/100, Training Loss: 0.4131
# Epoch 100/100, Training Loss: 0.4550
# Validation Loss: 0.7575
# Model 1, Fold 1: Validation Loss = 0.7575
# Epoch 1/100, Training Loss: 1.1627
# Epoch 2/100, Training Loss: 1.0178
# Epoch 3/100, Training Loss: 1.0747
# Epoch 4/100, Training Loss: 1.0137
# Epoch 5/100, Training Loss: 1.0301
# Epoch 6/100, Training Loss: 0.9367
# Epoch 7/100, Training Loss: 0.9358
# Epoch 8/100, Training Loss: 0.8533
# Epoch 9/100, Training Loss: 0.9444
# Epoch 10/100, Training Loss: 1.0228
# Epoch 11/100, Training Loss: 0.9390
# Epoch 12/100, Training Loss: 0.8653
# Epoch 13/100, Training Loss: 0.8269
# Epoch 14/100, Training Loss: 0.8315
# Epoch 15/100, Training Loss: 0.8700
# Epoch 16/100, Training Loss: 0.8966
# Epoch 17/100, Training Loss: 0.8874
# Epoch 18/100, Training Loss: 0.8177
# Epoch 19/100, Training Loss: 0.8309
# Epoch 20/100, Training Loss: 0.8315
# Epoch 21/100, Training Loss: 0.8241
# Epoch 22/100, Training Loss: 0.8070
# Epoch 23/100, Training Loss: 0.8389
# Epoch 24/100, Training Loss: 0.7978
# Epoch 25/100, Training Loss: 0.7674
# Epoch 26/100, Training Loss: 0.7634
# Epoch 27/100, Training Loss: 0.7811
# Epoch 28/100, Training Loss: 0.8056
# Epoch 29/100, Training Loss: 0.7867
# Epoch 30/100, Training Loss: 0.7934
# Epoch 31/100, Training Loss: 0.7960
# Epoch 32/100, Training Loss: 0.7504
# Epoch 33/100, Training Loss: 0.7702
# Epoch 34/100, Training Loss: 0.7917
# Epoch 35/100, Training Loss: 0.7853
# Epoch 36/100, Training Loss: 0.7331
# Epoch 37/100, Training Loss: 0.7629
# Epoch 38/100, Training Loss: 0.7854
# Epoch 39/100, Training Loss: 0.7935
# Epoch 40/100, Training Loss: 0.7545
# Epoch 41/100, Training Loss: 0.7572
# Epoch 42/100, Training Loss: 0.7782
# Epoch 43/100, Training Loss: 0.7729
# Epoch 44/100, Training Loss: 0.7609
# Epoch 45/100, Training Loss: 0.7181
# Epoch 46/100, Training Loss: 0.7665
# Epoch 47/100, Training Loss: 0.7382
# Epoch 48/100, Training Loss: 0.7666
# Epoch 49/100, Training Loss: 0.7725
# Epoch 50/100, Training Loss: 0.7253
# Epoch 51/100, Training Loss: 0.7740
# Epoch 52/100, Training Loss: 0.7335
# Epoch 53/100, Training Loss: 0.7815
# Epoch 54/100, Training Loss: 0.7301
# Epoch 55/100, Training Loss: 0.7721
# Epoch 56/100, Training Loss: 0.7424
# Epoch 57/100, Training Loss: 0.7796
# Epoch 58/100, Training Loss: 0.7546
# Epoch 59/100, Training Loss: 0.7867
# Epoch 60/100, Training Loss: 0.7341
# Epoch 61/100, Training Loss: 0.7579
# Epoch 62/100, Training Loss: 0.7709
# Epoch 63/100, Training Loss: 0.7825
# Epoch 64/100, Training Loss: 0.7660
# Epoch 65/100, Training Loss: 0.7727
# Epoch 66/100, Training Loss: 0.7847
# Epoch 67/100, Training Loss: 0.7040
# Epoch 68/100, Training Loss: 0.7565
# Epoch 69/100, Training Loss: 0.7662
# Epoch 70/100, Training Loss: 0.7781
# Epoch 71/100, Training Loss: 0.7661
# Epoch 72/100, Training Loss: 0.7687
# Epoch 73/100, Training Loss: 0.7287
# Epoch 74/100, Training Loss: 0.7923
# Epoch 75/100, Training Loss: 0.7902
# Epoch 76/100, Training Loss: 0.7447
# Epoch 77/100, Training Loss: 0.7903
# Epoch 78/100, Training Loss: 0.7517
# Epoch 79/100, Training Loss: 0.8099
# Epoch 80/100, Training Loss: 0.7404
# Epoch 81/100, Training Loss: 0.7178
# Epoch 82/100, Training Loss: 0.7773
# Epoch 83/100, Training Loss: 0.7652
# Epoch 84/100, Training Loss: 0.7515
# Epoch 85/100, Training Loss: 0.7621
# Epoch 86/100, Training Loss: 0.7974
# Epoch 87/100, Training Loss: 0.7698
# Epoch 88/100, Training Loss: 0.7644
# Epoch 89/100, Training Loss: 0.8015
# Epoch 90/100, Training Loss: 0.7830
# Epoch 91/100, Training Loss: 0.7379
# Epoch 92/100, Training Loss: 0.7493
# Epoch 93/100, Training Loss: 0.7583
# Epoch 94/100, Training Loss: 0.7990
# Epoch 95/100, Training Loss: 0.7854
# Epoch 96/100, Training Loss: 0.7313
# Epoch 97/100, Training Loss: 0.7925
# Epoch 98/100, Training Loss: 0.7481
# Epoch 99/100, Training Loss: 0.7781
# Epoch 100/100, Training Loss: 0.7591
# Validation Loss: 0.7739
# Model 2, Fold 0: Validation Loss = 0.7739
# Epoch 1/100, Training Loss: 1.1436
# Epoch 2/100, Training Loss: 1.0149
# Epoch 3/100, Training Loss: 1.0499
# Epoch 4/100, Training Loss: 1.0933
# Epoch 5/100, Training Loss: 1.0148
# Epoch 6/100, Training Loss: 0.9148
# Epoch 7/100, Training Loss: 0.9314
# Epoch 8/100, Training Loss: 0.9116
# Epoch 9/100, Training Loss: 0.8956
# Epoch 10/100, Training Loss: 0.8953
# Epoch 11/100, Training Loss: 0.8545
# Epoch 12/100, Training Loss: 0.8636
# Epoch 13/100, Training Loss: 0.8535
# Epoch 14/100, Training Loss: 0.8668
# Epoch 15/100, Training Loss: 0.8555
# Epoch 16/100, Training Loss: 0.8585
# Epoch 17/100, Training Loss: 0.8421
# Epoch 18/100, Training Loss: 0.8463
# Epoch 19/100, Training Loss: 0.8296
# Epoch 20/100, Training Loss: 0.8470
# Epoch 21/100, Training Loss: 0.8234
# Epoch 22/100, Training Loss: 0.8171
# Epoch 23/100, Training Loss: 0.8045
# Epoch 24/100, Training Loss: 0.8345
# Epoch 25/100, Training Loss: 0.8238
# Epoch 26/100, Training Loss: 0.7777
# Epoch 27/100, Training Loss: 0.7741
# Epoch 28/100, Training Loss: 0.7767
# Epoch 29/100, Training Loss: 0.7717
# Epoch 30/100, Training Loss: 0.7700
# Epoch 31/100, Training Loss: 0.7937
# Epoch 32/100, Training Loss: 0.7494
# Epoch 33/100, Training Loss: 0.7339
# Epoch 34/100, Training Loss: 0.7224
# Epoch 35/100, Training Loss: 0.7909
# Epoch 36/100, Training Loss: 0.7515
# Epoch 37/100, Training Loss: 0.7516
# Epoch 38/100, Training Loss: 0.8030
# Epoch 39/100, Training Loss: 0.7563
# Epoch 40/100, Training Loss: 0.7364
# Epoch 41/100, Training Loss: 0.7719
# Epoch 42/100, Training Loss: 0.7618
# Epoch 43/100, Training Loss: 0.7703
# Epoch 44/100, Training Loss: 0.7232
# Epoch 45/100, Training Loss: 0.7842
# Epoch 46/100, Training Loss: 0.7605
# Epoch 47/100, Training Loss: 0.7634
# Epoch 48/100, Training Loss: 0.7553
# Epoch 49/100, Training Loss: 0.7331
# Epoch 50/100, Training Loss: 0.7632
# Epoch 51/100, Training Loss: 0.7180
# Epoch 52/100, Training Loss: 0.7584
# Epoch 53/100, Training Loss: 0.7927
# Epoch 54/100, Training Loss: 0.7254
# Epoch 55/100, Training Loss: 0.7180
# Epoch 56/100, Training Loss: 0.7499
# Epoch 57/100, Training Loss: 0.7590
# Epoch 58/100, Training Loss: 0.7243
# Epoch 59/100, Training Loss: 0.7226
# Epoch 60/100, Training Loss: 0.7833
# Epoch 61/100, Training Loss: 0.7388
# Epoch 62/100, Training Loss: 0.7483
# Epoch 63/100, Training Loss: 0.7125
# Epoch 64/100, Training Loss: 0.7541
# Epoch 65/100, Training Loss: 0.7257
# Epoch 66/100, Training Loss: 0.7205
# Epoch 67/100, Training Loss: 0.7534
# Epoch 68/100, Training Loss: 0.7133
# Epoch 69/100, Training Loss: 0.7153
# Epoch 70/100, Training Loss: 0.7613
# Epoch 71/100, Training Loss: 0.7308
# Epoch 72/100, Training Loss: 0.7330
# Epoch 73/100, Training Loss: 0.7432
# Epoch 74/100, Training Loss: 0.7260
# Epoch 75/100, Training Loss: 0.7203
# Epoch 76/100, Training Loss: 0.7141
# Epoch 77/100, Training Loss: 0.7507
# Epoch 78/100, Training Loss: 0.7327
# Epoch 79/100, Training Loss: 0.7376
# Epoch 80/100, Training Loss: 0.7350
# Epoch 81/100, Training Loss: 0.7065
# Epoch 82/100, Training Loss: 0.7972
# Epoch 83/100, Training Loss: 0.7446
# Epoch 84/100, Training Loss: 0.7325
# Epoch 85/100, Training Loss: 0.7241
# Epoch 86/100, Training Loss: 0.7547
# Epoch 87/100, Training Loss: 0.7399
# Epoch 88/100, Training Loss: 0.7839
# Epoch 89/100, Training Loss: 0.7569
# Epoch 90/100, Training Loss: 0.7291
# Epoch 91/100, Training Loss: 0.7674
# Epoch 92/100, Training Loss: 0.7006
# Epoch 93/100, Training Loss: 0.7586
# Epoch 94/100, Training Loss: 0.7124
# Epoch 95/100, Training Loss: 0.7374
# Epoch 96/100, Training Loss: 0.7555
# Epoch 97/100, Training Loss: 0.7704
# Epoch 98/100, Training Loss: 0.7419
# Epoch 99/100, Training Loss: 0.7103
# Epoch 100/100, Training Loss: 0.7478
# Validation Loss: 0.8376
# Model 2, Fold 1: Validation Loss = 0.8376
# Best model per fold selected with losses: [0.6290837526321411, 0.58354252576828]
# Best per-fold model validation losses: [0.6290837526321411, 0.58354252576828]

# %%
#plt.scatter(feature(Y[X[:,0]==2]),feature(Yint[X[:,0]==2]));
plt.scatter(feature(Y[X[:,0]==2]),feature(Yint[X[:,0]==2])-feature(Y[X[:,0]==2]));
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 #plt.scatter(feature(Y[X[:,0]==2]),feature(Yint[X[:,0]==2]));
# ----> 2 plt.scatter(feature(Y[X[:,0]==2]),feature(Yint[X[:,0]==2])-feature(Y[X[:,0]==2]));
#
# NameError: name 'feature' is not defined

# %%
# Predicting counterfactuals+differences
for f in final_models_per_fold:
    f.transformer.logdet = False
final_model_overall.transformer.logdet = False
    
# Predicting counterfactuals+differences
def feature(y):
    return torch.log(1+torch.exp(-y))

# def feature(y):
#    return y
Yint1pred = final_models_per_fold[1].cocycle(Xint1,X1,Y1).detach()
Yint2pred = final_models_per_fold[0].cocycle(Xint2,X2,Y2).detach()
Yintpred_split = torch.concatenate((Yint1pred,Yint2pred))
Yintpred = final_model_overall.cocycle(Xint,X,Y).detach()

counterfactual_diffs = feature(Yint[X[:,0]==2])-feature(Y[X[:,0]==2])
counterfactual_diffpreds = feature(Yintpred[X[:,0]==2])-feature(Y[X[:,0]==2])
counterfactual_diffpreds_split = feature(Yintpred_split[X[:,0]==2])-feature(Y[X[:,0]==2])

# %%
((counterfactual_diffs - counterfactual_diffpreds_split).abs()**2).mean()**0.5,((counterfactual_diffs - counterfactual_diffpreds).abs()**2).mean()**0.5
# Out:
# (tensor(0.0934), tensor(0.1276))

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# Update matplotlib rcParams for higher font size and resolution
mpl.rcParams.update({
    'font.size': 60,         # Increase font size (default is usually 10)
    'figure.figsize': (20,16),  # Figure size remains the same as before
    'figure.dpi': 100        # Higher DPI for better fidelity
})

# Compute the KSD values
KSD = kolmogorov_distance(counterfactual_diffs, counterfactual_diffpreds)

# Plug-in based estimator
fig, ax = plt.subplots()
sns.kdeplot(counterfactual_diffs[:, 0], alpha=0.33, fill=True, ax=ax, label="True", lw = 5)
sns.kdeplot(counterfactual_diffpreds[:, 0], alpha=0.33, fill=True, ax=ax, label="Estimated", lw = 5)
ax.set_title("Causal NFs (Tail-Adaptive Base)")
plt.xlabel(r"$Y^{\pi*} - Y^\pi$")
ax.legend(loc = "upper left")
# Add KSD label for the plug-in estimator
ax.text(0.05, 0.55, f"KSD = {KSD:.2f}", transform=ax.transAxes, verticalalignment='top')
plt.grid(True)
plt.tight_layout()
fig.savefig("SCM_BD_counterfactual_dist_pi_TA", bbox_inches = "tight")
plt.show()

# %%
# Constructing KSD
KSD = kolmogorov_distance(counterfactual_diffs,counterfactual_diffpreds)
KSDsplit = kolmogorov_distance(counterfactual_diffs,counterfactual_diffpreds_split)
print(KSD)
print(KSDsplit)
# Out:
# 0.9347310126582278
# 0.6218354430379747
