# %% [markdown]
# # Independent vs. Non-independent performance testing

# %%
import torch
from torch.distributions import Distribution
import torch.nn as nn
from torch.distributions import Normal, Laplace, Bernoulli, Gamma,Cauchy
from causalflows.flows import CausalFlow
from typing import Callable
from zuko.flows import UnconditionalDistribution
from sklearn.model_selection import KFold
import copy
from torch.utils.data import DataLoader, TensorDataset
from architectures import get_stock_transforms
from csuite import SCMS, SCM_DIMS, SCM_MASKS
from causal_cocycle.causalflow_helper import select_and_train_flow, sample_do, sample_cf
from causal_cocycle.helper_functions import ks_statistic, wasserstein1_repeat, rmse

# %%
scm = SCMS['chain5_linear']
dims = SCM_DIMS['chain5_linear']
# ----------------------------------------
# 1) Define sample size and SCM dimension
# ----------------------------------------
N = 1000  # number of samples
# For a 5‐chain, d = 5 implicitly in scm

# --------------------------------------------------
# 2) Build noise distributions and transforms
# --------------------------------------------------

# (a) U₁ ∼ N(0,1)
dist_u1 = Normal(0,1)

# (b) “Base” for (U₂,…,U₅) is also N(0,1), but we will sample shape (N,4)
dist_base = Normal(0,1)

# (c) tf_u1: identity map on raw1 (shape (N,) → (N,1))
tf_u1 = lambda raw1: raw1.view(-1, 1)

# (d) tf_rest: affine map on raw_rest ∈ ℝ⁴ to induce correlation among U₂…U₅
rho = 0.0
Σ = (1-rho) * torch.eye(4) + rho * torch.ones(4, 4)
L = torch.linalg.cholesky(Σ)  # L is lower‐triangular, shape (4,4)

# We want U_rest = raw_rest @ Lᵀ
tf_rest = lambda raw_rest: raw_rest @ L.t()

# Package them into lists of length 2
noise_dists      = [dist_u1, dist_base]
noise_transforms = [tf_u1,   tf_rest]

# --------------------------------------------------
# 3) Draw data from the 5‐chain linear SCM
# --------------------------------------------------
#    - No intervention (intervention_node=None)
#    - return_u=True so we also get back the U matrix of shape (N,5)

X_full, U_full = scm(
    N=N,
    seed=42,
    intervention_node=None,
    intervention_value=None,
    return_u=True,
    noise_dists=noise_dists,
    noise_transforms=noise_transforms
)

# X has shape (N, 5), U_full has shape (N, 5)
# U_full[:,0] = U₁, U_full[:,1] = U₂, ..., U_full[:,4] = U₅

print("X.shape =", X_full.shape)
print("U_full.shape =", U_full.shape)

# --------------------------------------------------
# 4) Quick sanity check: empirical correlation among U₂ and U₃
# --------------------------------------------------
U2 = U_full[:, 1]
U3 = U_full[:, 2]
emp_corr_23 = torch.corrcoef(torch.stack([U2, U3]))[0,1].item()
print(f"Empirical corr(U₂, U₃) ≈ {emp_corr_23:.3f}  (target ρ = {rho})")
# Out:
# X.shape = torch.Size([1000, 5])
# U_full.shape = torch.Size([1000, 5])
# Empirical corr(U₂, U₃) ≈ -0.014  (target ρ = 0.0)

# %% [markdown]
# # Training flow model

# %%
num_epochs = 1000
k_folds = 2
batch_size = 64
lr = 1e-2
transforms = get_stock_transforms(x_dim=0, y_dim=dims)  # returns a list of 4 different MAF instances
Base = Normal
base = UnconditionalDistribution(
    Base, loc=torch.zeros(dims), scale=torch.ones(dims), buffer=True
)
flows = [CausalFlow(transform=maf, base=base)
         for maf in transforms
        ]
# CV + retrain across all transforms
best_flow, test_nll, best_idx, cv_scores = select_and_train_flow(
    flows, X_full, train_fraction=1.0, k_folds=k_folds,
    num_epochs=num_epochs, batch_size=batch_size, lr=lr,
    device=X_full.device
)

# %%
# ───────────────────────────────────────────────────────────────
# 1. Re-generate observational data (X_full = [X1, Y1, ..., Y4])
# ───────────────────────────────────────────────────────────────
N = 10000
X_obs_full, _ = scm(
    N=N,
    seed=0,
    intervention_node=None,
    return_u=True,
    noise_dists=noise_dists,
    noise_transforms=noise_transforms
)

X_obs = X_obs_full[:, :1]     # (N,1)
Y_obs = X_obs_full[:, 1:]     # (N,4)

# ───────────────────────────────────────────────────────────────
# 2. Generate ground-truth interventional data under do(X1 = c)
# ───────────────────────────────────────────────────────────────
c = 0.0
X_int_full = scm(
    N=N,
    seed=0,
    intervention_node=1,
    intervention_value=c,
    return_u=False,
    noise_dists=noise_dists,
    noise_transforms=noise_transforms
)
Y_true_int = X_int_full[:, 1:]  # (N,4)

# ───────────────────────────────────────────────────────────────
# 3. Generate model interventional samples using sample_do
# ───────────────────────────────────────────────────────────────
device = X_obs.device
flow_model = best_flow.to(device)

with torch.no_grad():
    X_model_int = sample_do(
        flow=best_flow,
        index=0,
        intervention_fn=lambda old: torch.full_like(old, c),
        sample_shape=torch.Size([N])
    )
Y_model_int = X_model_int[:, 1:]

# ───────────────────────────────────────────────────────────────
# 4. Compute marginal KS statistics
# ───────────────────────────────────────────────────────────────
ks_vals = []
for j in range(4):
    ks_j = ks_statistic(Y_model_int[:, j].cpu(), Y_true_int[:, j].cpu())
    ks_vals.append(ks_j)
print("Interventional KS per dimension:", ks_vals)

# ───────────────────────────────────────────────────────────────
# 5. Generate counterfactual predictions
# ───────────────────────────────────────────────────────────────
Z_obs = X_obs_full.to(device)
with torch.no_grad():
    Z_cf = sample_cf(
        flow=best_flow,
        x_obs=Z_obs,
        index=0,
        intervention_fn=lambda old: torch.full_like(old, c)
    )
Y_cf_pred = Z_cf[:, 1:]

# Get true counterfactuals for these same samples
Z_cf_true = scm(
    N=N,
    seed=0,  # same seed as earlier for consistency
    intervention_node=1,
    intervention_value=c,
    return_u=False,
    noise_dists=noise_dists,
    noise_transforms=noise_transforms
).to(device)
Y_cf_true = Z_cf_true[:, 1:]

# ───────────────────────────────────────────────────────────────
# 6. Compute RMSE per dimension
# ───────────────────────────────────────────────────────────────
rmse_vals = []
for j in range(4):
    rmse_j = torch.sqrt(((Y_cf_pred[:, j] - Y_cf_true[:, j]) ** 2).nanmean()).item()
    rmse_vals.append(rmse_j)
print("Counterfactual RMSE per dimension:", rmse_vals)
# Out:
# Interventional KS per dimension: [0.018599987030029297, 0.1550999879837036, 0.11640000343322754, 0.0974000096321106]
# Counterfactual RMSE per dimension: [0.007982463575899601, 0.003497605910524726, 0.051112715154886246, 0.1640557199716568]

# %%
cv_scores
# Out:
# [8.52140998840332, 9.243063926696777, 12.75081491470337, 11.118023872375488]

# %% [markdown]
# ## Training Cocycle Models

# %%
# Split into context X_ctx (shape (N,1)) and Y (shape (N,4)):
X_ctx = X_full[:, 0:1]   # 1‐dimensional context
Y_obs = X_full[:, 1:]    # 4‐dimensional output

# 2) Import the stock autoregressive transforms for a 1→4 conditional flow

# Each MaskedAutoregressiveTransform expects:
#   • features = y_dim = 4
#   • context  = x_dim = 1
transforms = get_stock_transforms(x_dim=1, y_dim=4)  # returns a list of 4 different MAF instances

# 3) Wrap each AR transform into a 1‐layer ZukoCocycleModel
from causal_cocycle.model_new import ZukoCocycleModel

# If you want to cross‐validate over all 4 architectures, build a list:
cocycle_models = [
    ZukoCocycleModel(nn.ModuleList(maf))  
    for maf in transforms
]
# Alternatively, to pick just the first architecture:
# cocycle_model = ZukoCocycleModel(nn.ModuleList([transforms[0]]))
model0 = cocycle_models[2]

from torch.utils.data import random_split

# 4) Build a CMMD-V loss via CocycleLossFactory
from causal_cocycle.loss_factory import CocycleLossFactory
from causal_cocycle.kernels import gaussian_kernel

# We supply two Gaussian kernels (one on X, one on U):
kernel = [gaussian_kernel(), gaussian_kernel()]
loss_factory = CocycleLossFactory(kernel)

# We need to “tune” the kernels’ lengthscales on training data.
# Split X_ctx / Y_obs into train / val
X_train = X_ctx
Y_train = Y_obs

# Build the CMMD-V loss, which will internally set lengthscales via median heuristic on (X_train,Y_train)
cmmdv_loss = loss_factory.build_loss("CMMD_V", X_train, Y_train, subsamples=10000)

# 5) Call optimise(...)
from causal_cocycle.optimise_new import optimise

# Example hyperparameters—feel free to adjust as desired:
learn_rate       = 1e-3
epochs           = 1000
weight_decay     = 0.0
batch_size       = 64
val_batch_size   = 256
scheduler        = False
schedule_milestone = 10
lr_mult          = 0.90
print_           = True
plot             = False
likelihood_param_opt = False
likelihood_param_lr  = 0.01

# Finally, run training. We supply both train and val sets so optimise can compute validation loss each epoch:
best_model, history = optimise(
    model            = model0,
    loss_tr          = cmmdv_loss,
    inputs           = X_train,
    outputs          = Y_train,
    inputs_val       = None,
    outputs_val      = None,
    learn_rate       = learn_rate,
    epochs           = epochs,
    weight_decay     = weight_decay,
    batch_size       = batch_size,
    val_batch_size   = val_batch_size,
    scheduler        = scheduler,
    schedule_milestone = schedule_milestone,
    lr_mult          = lr_mult,
    print_           = print_,
    plot             = plot,
    likelihood_param_opt = likelihood_param_opt,
    likelihood_param_lr  = likelihood_param_lr,
    loss_val         = None  # no separate “loss_val” function needed, since CMMD-V is symmetric
)
# Out:
# Epoch 1/1000, Training Loss: -0.4279
# Epoch 2/1000, Training Loss: -0.4169
# Epoch 3/1000, Training Loss: -0.4347
# Epoch 4/1000, Training Loss: -0.4793
# Epoch 5/1000, Training Loss: -0.4791
# Epoch 6/1000, Training Loss: -0.5147
# Epoch 7/1000, Training Loss: -0.5290
# Epoch 8/1000, Training Loss: -0.5600
# Epoch 9/1000, Training Loss: -0.5818
# Epoch 10/1000, Training Loss: -0.6013
# Epoch 11/1000, Training Loss: -0.6205
# Epoch 12/1000, Training Loss: -0.6151
# Epoch 13/1000, Training Loss: -0.6289
# Epoch 14/1000, Training Loss: -0.6443
# Epoch 82/1000, Training Loss: -0.8342
# Epoch 83/1000, Training Loss: -0.8281
# Epoch 84/1000, Training Loss: -0.8165
# Epoch 85/1000, Training Loss: -0.8208
# Epoch 86/1000, Training Loss: -0.8263
# Epoch 87/1000, Training Loss: -0.8250
# Epoch 88/1000, Training Loss: -0.8238
# Epoch 89/1000, Training Loss: -0.8182
# Epoch 90/1000, Training Loss: -0.8289
# Epoch 91/1000, Training Loss: -0.8214
# Epoch 92/1000, Training Loss: -0.8308
# Epoch 93/1000, Training Loss: -0.8225
# Epoch 94/1000, Training Loss: -0.8197
# Epoch 95/1000, Training Loss: -0.8278
# Epoch 96/1000, Training Loss: -0.8292
# Epoch 97/1000, Training Loss: -0.8201
# Epoch 98/1000, Training Loss: -0.8208
# Epoch 99/1000, Training Loss: -0.8167
# Epoch 100/1000, Training Loss: -0.8260
# Epoch 101/1000, Training Loss: -0.8237
# Epoch 102/1000, Training Loss: -0.8217
# Epoch 103/1000, Training Loss: -0.8249
# Epoch 104/1000, Training Loss: -0.8201
# Epoch 105/1000, Training Loss: -0.8258
# Epoch 106/1000, Training Loss: -0.8272
# Epoch 107/1000, Training Loss: -0.8174
# Epoch 108/1000, Training Loss: -0.8237
# Epoch 109/1000, Training Loss: -0.8295
# Epoch 110/1000, Training Loss: -0.8286
# Epoch 111/1000, Training Loss: -0.8206
# Epoch 112/1000, Training Loss: -0.8191
# Epoch 113/1000, Training Loss: -0.8322
# Epoch 114/1000, Training Loss: -0.8261
# Epoch 115/1000, Training Loss: -0.8177
# Epoch 116/1000, Training Loss: -0.8247
# Epoch 117/1000, Training Loss: -0.8229
# Epoch 118/1000, Training Loss: -0.8199
# Epoch 119/1000, Training Loss: -0.8268
# Epoch 120/1000, Training Loss: -0.8281
# Epoch 121/1000, Training Loss: -0.8220
# Epoch 122/1000, Training Loss: -0.8261
# Epoch 123/1000, Training Loss: -0.8187
# Epoch 124/1000, Training Loss: -0.8282
# Epoch 125/1000, Training Loss: -0.8224
# Epoch 126/1000, Training Loss: -0.8142
# Epoch 127/1000, Training Loss: -0.8290
# Epoch 128/1000, Training Loss: -0.8284
# Epoch 129/1000, Training Loss: -0.8260
# Epoch 130/1000, Training Loss: -0.8302
# Epoch 131/1000, Training Loss: -0.8224
# Epoch 132/1000, Training Loss: -0.8216
# Epoch 133/1000, Training Loss: -0.8207
# Epoch 134/1000, Training Loss: -0.8220
# Epoch 135/1000, Training Loss: -0.8216
# Epoch 136/1000, Training Loss: -0.8279
# Epoch 137/1000, Training Loss: -0.8396
# Epoch 138/1000, Training Loss: -0.8130
# Epoch 139/1000, Training Loss: -0.8279
# Epoch 140/1000, Training Loss: -0.8138
# Epoch 141/1000, Training Loss: -0.8287
# Epoch 142/1000, Training Loss: -0.8289
# Epoch 143/1000, Training Loss: -0.8307
# Epoch 144/1000, Training Loss: -0.8253
# Epoch 145/1000, Training Loss: -0.8196
# Epoch 146/1000, Training Loss: -0.8321
# Epoch 147/1000, Training Loss: -0.8302
# Epoch 148/1000, Training Loss: -0.8243
# Epoch 216/1000, Training Loss: -0.8307
# Epoch 217/1000, Training Loss: -0.8264
# Epoch 218/1000, Training Loss: -0.8297
# Epoch 219/1000, Training Loss: -0.8350
# Epoch 220/1000, Training Loss: -0.8179
# Epoch 221/1000, Training Loss: -0.8282
# Epoch 222/1000, Training Loss: -0.8382
# Epoch 223/1000, Training Loss: -0.8258
# Epoch 224/1000, Training Loss: -0.8200
# Epoch 225/1000, Training Loss: -0.8183
# Epoch 226/1000, Training Loss: -0.8368
# Epoch 227/1000, Training Loss: -0.8238
# Epoch 228/1000, Training Loss: -0.8230
# Epoch 229/1000, Training Loss: -0.8299
# Epoch 230/1000, Training Loss: -0.8220
# Epoch 231/1000, Training Loss: -0.8243
# Epoch 232/1000, Training Loss: -0.8324
# Epoch 233/1000, Training Loss: -0.8229
# Epoch 234/1000, Training Loss: -0.8298
# Epoch 235/1000, Training Loss: -0.8202
# Epoch 236/1000, Training Loss: -0.8194
# Epoch 237/1000, Training Loss: -0.8229
# Epoch 238/1000, Training Loss: -0.8186
# Epoch 239/1000, Training Loss: -0.8304
# Epoch 240/1000, Training Loss: -0.8266
# Epoch 241/1000, Training Loss: -0.8385
# Epoch 242/1000, Training Loss: -0.8201
# Epoch 243/1000, Training Loss: -0.8257
# Epoch 244/1000, Training Loss: -0.8315
# Epoch 245/1000, Training Loss: -0.8366
# Epoch 246/1000, Training Loss: -0.8219
# Epoch 247/1000, Training Loss: -0.8210
# Epoch 248/1000, Training Loss: -0.8315
# Epoch 249/1000, Training Loss: -0.8207
# Epoch 250/1000, Training Loss: -0.8190
# Epoch 251/1000, Training Loss: -0.8281
# Epoch 252/1000, Training Loss: -0.8280
# Epoch 253/1000, Training Loss: -0.8330
# Epoch 254/1000, Training Loss: -0.8343
# Epoch 255/1000, Training Loss: -0.8188
# Epoch 256/1000, Training Loss: -0.8226
# Epoch 257/1000, Training Loss: -0.8280
# Epoch 258/1000, Training Loss: -0.8303
# Epoch 259/1000, Training Loss: -0.8259
# Epoch 260/1000, Training Loss: -0.8157
# Epoch 261/1000, Training Loss: -0.8268
# Epoch 262/1000, Training Loss: -0.8281
# Epoch 263/1000, Training Loss: -0.8187
# Epoch 264/1000, Training Loss: -0.8229
# Epoch 265/1000, Training Loss: -0.8268
# Epoch 266/1000, Training Loss: -0.8352
# Epoch 267/1000, Training Loss: -0.8306
# Epoch 268/1000, Training Loss: -0.8328
# Epoch 269/1000, Training Loss: -0.8131
# Epoch 270/1000, Training Loss: -0.8269
# Epoch 271/1000, Training Loss: -0.8206
# Epoch 272/1000, Training Loss: -0.8194
# Epoch 273/1000, Training Loss: -0.8335
# Epoch 274/1000, Training Loss: -0.8219
# Epoch 275/1000, Training Loss: -0.8251
# Epoch 276/1000, Training Loss: -0.8261
# Epoch 277/1000, Training Loss: -0.8232
# Epoch 278/1000, Training Loss: -0.8332
# Epoch 279/1000, Training Loss: -0.8328
# Epoch 280/1000, Training Loss: -0.8237
# Epoch 281/1000, Training Loss: -0.8248
# Epoch 282/1000, Training Loss: -0.8273
# Epoch 283/1000, Training Loss: -0.8278
# Epoch 284/1000, Training Loss: -0.8331
# Epoch 285/1000, Training Loss: -0.8211
# Epoch 286/1000, Training Loss: -0.8222
# Epoch 287/1000, Training Loss: -0.8271
# Epoch 288/1000, Training Loss: -0.8224
# Epoch 289/1000, Training Loss: -0.8292
# Epoch 290/1000, Training Loss: -0.8203
# Epoch 291/1000, Training Loss: -0.8258
# Epoch 292/1000, Training Loss: -0.8199
# Epoch 293/1000, Training Loss: -0.8289
# Epoch 294/1000, Training Loss: -0.8356
# Epoch 295/1000, Training Loss: -0.8326
# Epoch 296/1000, Training Loss: -0.8263
# Epoch 297/1000, Training Loss: -0.8206
# Epoch 298/1000, Training Loss: -0.8222
# Epoch 299/1000, Training Loss: -0.8346
# Epoch 300/1000, Training Loss: -0.8252
# Epoch 301/1000, Training Loss: -0.8209
# Epoch 302/1000, Training Loss: -0.8294
# Epoch 303/1000, Training Loss: -0.8247
# Epoch 304/1000, Training Loss: -0.8217
# Epoch 305/1000, Training Loss: -0.8228
# Epoch 306/1000, Training Loss: -0.8273
# Epoch 307/1000, Training Loss: -0.8229
# Epoch 308/1000, Training Loss: -0.8174
# Epoch 309/1000, Training Loss: -0.8200
# Epoch 310/1000, Training Loss: -0.8464
# Epoch 311/1000, Training Loss: -0.8310
# Epoch 312/1000, Training Loss: -0.8269
# Epoch 313/1000, Training Loss: -0.8310
# Epoch 314/1000, Training Loss: -0.8225
# Epoch 315/1000, Training Loss: -0.8233
# Epoch 316/1000, Training Loss: -0.8236
# Epoch 317/1000, Training Loss: -0.8263
# Epoch 318/1000, Training Loss: -0.8335
# Epoch 319/1000, Training Loss: -0.8185
# Epoch 320/1000, Training Loss: -0.8268
# Epoch 321/1000, Training Loss: -0.8388
# Epoch 322/1000, Training Loss: -0.8250
# Epoch 323/1000, Training Loss: -0.8322
# Epoch 324/1000, Training Loss: -0.8206
# Epoch 325/1000, Training Loss: -0.8281
# Epoch 326/1000, Training Loss: -0.8255
# Epoch 327/1000, Training Loss: -0.8258
# Epoch 328/1000, Training Loss: -0.8257
# Epoch 329/1000, Training Loss: -0.8230
# Epoch 330/1000, Training Loss: -0.8333
# Epoch 331/1000, Training Loss: -0.8311
# Epoch 332/1000, Training Loss: -0.8147
# Epoch 333/1000, Training Loss: -0.8236
# Epoch 334/1000, Training Loss: -0.8303
# Epoch 335/1000, Training Loss: -0.8313
# Epoch 336/1000, Training Loss: -0.8276
# Epoch 337/1000, Training Loss: -0.8167
# Epoch 338/1000, Training Loss: -0.8253
# Epoch 339/1000, Training Loss: -0.8247
# Epoch 340/1000, Training Loss: -0.8342
# Epoch 341/1000, Training Loss: -0.8263
# Epoch 342/1000, Training Loss: -0.8301
# Epoch 343/1000, Training Loss: -0.8298
# Epoch 344/1000, Training Loss: -0.8259
# Epoch 345/1000, Training Loss: -0.8254
# Epoch 346/1000, Training Loss: -0.8226
# Epoch 347/1000, Training Loss: -0.8257
# Epoch 348/1000, Training Loss: -0.8251
# Epoch 349/1000, Training Loss: -0.8336
# Epoch 350/1000, Training Loss: -0.8237
# Epoch 351/1000, Training Loss: -0.8262
# Epoch 352/1000, Training Loss: -0.8218
# Epoch 353/1000, Training Loss: -0.8294
# Epoch 354/1000, Training Loss: -0.8309
# Epoch 355/1000, Training Loss: -0.8335
# Epoch 356/1000, Training Loss: -0.8322
# Epoch 357/1000, Training Loss: -0.8296
# Epoch 358/1000, Training Loss: -0.8250
# Epoch 359/1000, Training Loss: -0.8331
# Epoch 360/1000, Training Loss: -0.8270
# Epoch 361/1000, Training Loss: -0.8224
# Epoch 362/1000, Training Loss: -0.8242
# Epoch 363/1000, Training Loss: -0.8245
# Epoch 364/1000, Training Loss: -0.8254
# Epoch 365/1000, Training Loss: -0.8235
# Epoch 366/1000, Training Loss: -0.8247
# Epoch 367/1000, Training Loss: -0.8283
# Epoch 368/1000, Training Loss: -0.8263
# Epoch 369/1000, Training Loss: -0.8272
# Epoch 370/1000, Training Loss: -0.8333
# Epoch 371/1000, Training Loss: -0.8286
# Epoch 372/1000, Training Loss: -0.8306
# Epoch 373/1000, Training Loss: -0.8241
# Epoch 374/1000, Training Loss: -0.8239
# Epoch 375/1000, Training Loss: -0.8282
# Epoch 376/1000, Training Loss: -0.8261
# Epoch 377/1000, Training Loss: -0.8279
# Epoch 378/1000, Training Loss: -0.8164
# Epoch 379/1000, Training Loss: -0.8247
# Epoch 380/1000, Training Loss: -0.8266
# Epoch 381/1000, Training Loss: -0.8294
# Epoch 382/1000, Training Loss: -0.8279
# Epoch 383/1000, Training Loss: -0.8294
# Epoch 384/1000, Training Loss: -0.8220
# Epoch 385/1000, Training Loss: -0.8347
# Epoch 386/1000, Training Loss: -0.8284
# Epoch 387/1000, Training Loss: -0.8186
# Epoch 388/1000, Training Loss: -0.8277
# Epoch 389/1000, Training Loss: -0.8286
# Epoch 390/1000, Training Loss: -0.8270
# Epoch 391/1000, Training Loss: -0.8186
# Epoch 392/1000, Training Loss: -0.8257
# Epoch 393/1000, Training Loss: -0.8230
# Epoch 394/1000, Training Loss: -0.8275
# Epoch 395/1000, Training Loss: -0.8214
# Epoch 396/1000, Training Loss: -0.8349
# Epoch 397/1000, Training Loss: -0.8228
# Epoch 398/1000, Training Loss: -0.8274
# Epoch 399/1000, Training Loss: -0.8237
# Epoch 400/1000, Training Loss: -0.8309
# Epoch 401/1000, Training Loss: -0.8321
# Epoch 402/1000, Training Loss: -0.8296
# Epoch 403/1000, Training Loss: -0.8306
# Epoch 404/1000, Training Loss: -0.8258
# Epoch 405/1000, Training Loss: -0.8225
# Epoch 406/1000, Training Loss: -0.8334
# Epoch 407/1000, Training Loss: -0.8200
# Epoch 408/1000, Training Loss: -0.8237
# Epoch 409/1000, Training Loss: -0.8266
# Epoch 410/1000, Training Loss: -0.8263
# Epoch 411/1000, Training Loss: -0.8325
# Epoch 412/1000, Training Loss: -0.8290
# Epoch 413/1000, Training Loss: -0.8346
# Epoch 414/1000, Training Loss: -0.8345
# Epoch 415/1000, Training Loss: -0.8341
# Epoch 416/1000, Training Loss: -0.8215
# Epoch 484/1000, Training Loss: -0.8335
# Epoch 485/1000, Training Loss: -0.8210
# Epoch 486/1000, Training Loss: -0.8251
# Epoch 487/1000, Training Loss: -0.8295
# Epoch 488/1000, Training Loss: -0.8228
# Epoch 489/1000, Training Loss: -0.8165
# Epoch 490/1000, Training Loss: -0.8309
# Epoch 491/1000, Training Loss: -0.8244
# Epoch 492/1000, Training Loss: -0.8329
# Epoch 493/1000, Training Loss: -0.8246
# Epoch 494/1000, Training Loss: -0.8247
# Epoch 495/1000, Training Loss: -0.8306
# Epoch 496/1000, Training Loss: -0.8300
# Epoch 497/1000, Training Loss: -0.8263
# Epoch 498/1000, Training Loss: -0.8217
# Epoch 499/1000, Training Loss: -0.8188
# Epoch 500/1000, Training Loss: -0.8317
# Epoch 501/1000, Training Loss: -0.8305
# Epoch 502/1000, Training Loss: -0.8216
# Epoch 503/1000, Training Loss: -0.8334
# Epoch 504/1000, Training Loss: -0.8276
# Epoch 505/1000, Training Loss: -0.8257
# Epoch 506/1000, Training Loss: -0.8264
# Epoch 507/1000, Training Loss: -0.8208
# Epoch 508/1000, Training Loss: -0.8208
# Epoch 509/1000, Training Loss: -0.8313
# Epoch 510/1000, Training Loss: -0.8274
# Epoch 511/1000, Training Loss: -0.8283
# Epoch 512/1000, Training Loss: -0.8277
# Epoch 513/1000, Training Loss: -0.8314
# Epoch 514/1000, Training Loss: -0.8270
# Epoch 515/1000, Training Loss: -0.8297
# Epoch 516/1000, Training Loss: -0.8307
# Epoch 517/1000, Training Loss: -0.8264
# Epoch 518/1000, Training Loss: -0.8237
# Epoch 519/1000, Training Loss: -0.8253
# Epoch 520/1000, Training Loss: -0.8268
# Epoch 521/1000, Training Loss: -0.8200
# Epoch 522/1000, Training Loss: -0.8218
# Epoch 523/1000, Training Loss: -0.8207
# Epoch 524/1000, Training Loss: -0.8342
# Epoch 525/1000, Training Loss: -0.8235
# Epoch 526/1000, Training Loss: -0.8255
# Epoch 527/1000, Training Loss: -0.8187
# Epoch 528/1000, Training Loss: -0.8333
# Epoch 529/1000, Training Loss: -0.8251
# Epoch 530/1000, Training Loss: -0.8242
# Epoch 531/1000, Training Loss: -0.8283
# Epoch 532/1000, Training Loss: -0.8314
# Epoch 533/1000, Training Loss: -0.8254
# Epoch 534/1000, Training Loss: -0.8285
# Epoch 535/1000, Training Loss: -0.8394
# Epoch 536/1000, Training Loss: -0.8313
# Epoch 537/1000, Training Loss: -0.8238
# Epoch 538/1000, Training Loss: -0.8260
# Epoch 539/1000, Training Loss: -0.8219
# Epoch 540/1000, Training Loss: -0.8266
# Epoch 541/1000, Training Loss: -0.8353
# Epoch 542/1000, Training Loss: -0.8255
# Epoch 543/1000, Training Loss: -0.8360
# Epoch 544/1000, Training Loss: -0.8242
# Epoch 545/1000, Training Loss: -0.8261
# Epoch 546/1000, Training Loss: -0.8320
# Epoch 547/1000, Training Loss: -0.8303
# Epoch 548/1000, Training Loss: -0.8267
# Epoch 549/1000, Training Loss: -0.8313
# Epoch 550/1000, Training Loss: -0.8302
# Epoch 551/1000, Training Loss: -0.8307
# Epoch 552/1000, Training Loss: -0.8329
# Epoch 553/1000, Training Loss: -0.8298
# Epoch 554/1000, Training Loss: -0.8248
# Epoch 555/1000, Training Loss: -0.8236
# Epoch 556/1000, Training Loss: -0.8296
# Epoch 557/1000, Training Loss: -0.8275
# Epoch 558/1000, Training Loss: -0.8249
# Epoch 559/1000, Training Loss: -0.8296
# Epoch 560/1000, Training Loss: -0.8277
# Epoch 561/1000, Training Loss: -0.8285
# Epoch 562/1000, Training Loss: -0.8323
# Epoch 563/1000, Training Loss: -0.8315
# Epoch 564/1000, Training Loss: -0.8313
# Epoch 565/1000, Training Loss: -0.8310
# Epoch 566/1000, Training Loss: -0.8319
# Epoch 567/1000, Training Loss: -0.8235
# Epoch 568/1000, Training Loss: -0.8277
# Epoch 569/1000, Training Loss: -0.8321
# Epoch 570/1000, Training Loss: -0.8291
# Epoch 571/1000, Training Loss: -0.8315
# Epoch 572/1000, Training Loss: -0.8261
# Epoch 573/1000, Training Loss: -0.8300
# Epoch 574/1000, Training Loss: -0.8273
# Epoch 575/1000, Training Loss: -0.8334
# Epoch 576/1000, Training Loss: -0.8204
# Epoch 577/1000, Training Loss: -0.8185
# Epoch 578/1000, Training Loss: -0.8221
# Epoch 579/1000, Training Loss: -0.8231
# Epoch 580/1000, Training Loss: -0.8242
# Epoch 581/1000, Training Loss: -0.8119
# Epoch 582/1000, Training Loss: -0.8272
# Epoch 583/1000, Training Loss: -0.8324
# Epoch 584/1000, Training Loss: -0.8289
# Epoch 585/1000, Training Loss: -0.8262
# Epoch 586/1000, Training Loss: -0.8272
# Epoch 587/1000, Training Loss: -0.8318
# Epoch 588/1000, Training Loss: -0.8330
# Epoch 589/1000, Training Loss: -0.8322
# Epoch 590/1000, Training Loss: -0.8189
# Epoch 591/1000, Training Loss: -0.8292
# Epoch 592/1000, Training Loss: -0.8321
# Epoch 593/1000, Training Loss: -0.8265
# Epoch 594/1000, Training Loss: -0.8326
# Epoch 595/1000, Training Loss: -0.8288
# Epoch 596/1000, Training Loss: -0.8256
# Epoch 597/1000, Training Loss: -0.8270
# Epoch 598/1000, Training Loss: -0.8204
# Epoch 599/1000, Training Loss: -0.8286
# Epoch 600/1000, Training Loss: -0.8188
# Epoch 601/1000, Training Loss: -0.8279
# Epoch 602/1000, Training Loss: -0.8245
# Epoch 603/1000, Training Loss: -0.8340
# Epoch 604/1000, Training Loss: -0.8233
# Epoch 605/1000, Training Loss: -0.8225
# Epoch 606/1000, Training Loss: -0.8279
# Epoch 607/1000, Training Loss: -0.8265
# Epoch 608/1000, Training Loss: -0.8271
# Epoch 609/1000, Training Loss: -0.8277
# Epoch 610/1000, Training Loss: -0.8326
# Epoch 611/1000, Training Loss: -0.8339
# Epoch 612/1000, Training Loss: -0.8336
# Epoch 613/1000, Training Loss: -0.8286
# Epoch 614/1000, Training Loss: -0.8375
# Epoch 615/1000, Training Loss: -0.8225
# Epoch 616/1000, Training Loss: -0.8299
# Epoch 617/1000, Training Loss: -0.8264
# Epoch 618/1000, Training Loss: -0.8377
# Epoch 619/1000, Training Loss: -0.8213
# Epoch 620/1000, Training Loss: -0.8366
# Epoch 621/1000, Training Loss: -0.8299
# Epoch 622/1000, Training Loss: -0.8290
# Epoch 623/1000, Training Loss: -0.8262
# Epoch 624/1000, Training Loss: -0.8219
# Epoch 625/1000, Training Loss: -0.8319
# Epoch 626/1000, Training Loss: -0.8258
# Epoch 627/1000, Training Loss: -0.8222
# Epoch 628/1000, Training Loss: -0.8232
# Epoch 629/1000, Training Loss: -0.8258
# Epoch 630/1000, Training Loss: -0.8265
# Epoch 631/1000, Training Loss: -0.8334
# Epoch 632/1000, Training Loss: -0.8413
# Epoch 633/1000, Training Loss: -0.8292
# Epoch 634/1000, Training Loss: -0.8188
# Epoch 635/1000, Training Loss: -0.8266
# Epoch 636/1000, Training Loss: -0.8316
# Epoch 637/1000, Training Loss: -0.8216
# Epoch 638/1000, Training Loss: -0.8344
# Epoch 639/1000, Training Loss: -0.8348
# Epoch 640/1000, Training Loss: -0.8317
# Epoch 641/1000, Training Loss: -0.8281
# Epoch 642/1000, Training Loss: -0.8358
# Epoch 643/1000, Training Loss: -0.8271
# Epoch 644/1000, Training Loss: -0.8287
# Epoch 645/1000, Training Loss: -0.8377
# Epoch 646/1000, Training Loss: -0.8164
# Epoch 647/1000, Training Loss: -0.8171
# Epoch 648/1000, Training Loss: -0.8295
# Epoch 649/1000, Training Loss: -0.8299
# Epoch 650/1000, Training Loss: -0.8245
# Epoch 651/1000, Training Loss: -0.8232
# Epoch 652/1000, Training Loss: -0.8239
# Epoch 653/1000, Training Loss: -0.8213
# Epoch 654/1000, Training Loss: -0.8225
# Epoch 655/1000, Training Loss: -0.8189
# Epoch 656/1000, Training Loss: -0.8294
# Epoch 657/1000, Training Loss: -0.8328
# Epoch 658/1000, Training Loss: -0.8272
# Epoch 659/1000, Training Loss: -0.8283
# Epoch 660/1000, Training Loss: -0.8241
# Epoch 661/1000, Training Loss: -0.8198
# Epoch 662/1000, Training Loss: -0.8226
# Epoch 663/1000, Training Loss: -0.8184
# Epoch 664/1000, Training Loss: -0.8280
# Epoch 665/1000, Training Loss: -0.8222
# Epoch 666/1000, Training Loss: -0.8283
# Epoch 667/1000, Training Loss: -0.8216
# Epoch 668/1000, Training Loss: -0.8301
# Epoch 669/1000, Training Loss: -0.8359
# Epoch 670/1000, Training Loss: -0.8253
# Epoch 671/1000, Training Loss: -0.8288
# Epoch 672/1000, Training Loss: -0.8252
# Epoch 673/1000, Training Loss: -0.8250
# Epoch 674/1000, Training Loss: -0.8278
# Epoch 675/1000, Training Loss: -0.8271
# Epoch 676/1000, Training Loss: -0.8321
# Epoch 677/1000, Training Loss: -0.8275
# Epoch 678/1000, Training Loss: -0.8308
# Epoch 679/1000, Training Loss: -0.8334
# Epoch 680/1000, Training Loss: -0.8290
# Epoch 681/1000, Training Loss: -0.8252
# Epoch 682/1000, Training Loss: -0.8269
# Epoch 683/1000, Training Loss: -0.8350
# Epoch 684/1000, Training Loss: -0.8264
# Epoch 685/1000, Training Loss: -0.8317
# Epoch 686/1000, Training Loss: -0.8202
# Epoch 687/1000, Training Loss: -0.8295
# Epoch 688/1000, Training Loss: -0.8183
# Epoch 689/1000, Training Loss: -0.8248
# Epoch 690/1000, Training Loss: -0.8339
# Epoch 691/1000, Training Loss: -0.8346
# Epoch 692/1000, Training Loss: -0.8286
# Epoch 693/1000, Training Loss: -0.8265
# Epoch 694/1000, Training Loss: -0.8244
# Epoch 695/1000, Training Loss: -0.8340
# Epoch 696/1000, Training Loss: -0.8140
# Epoch 697/1000, Training Loss: -0.8369
# Epoch 698/1000, Training Loss: -0.8290
# Epoch 699/1000, Training Loss: -0.8315
# Epoch 700/1000, Training Loss: -0.8257
# Epoch 701/1000, Training Loss: -0.8198
# Epoch 702/1000, Training Loss: -0.8252
# Epoch 703/1000, Training Loss: -0.8302
# Epoch 704/1000, Training Loss: -0.8378
# Epoch 705/1000, Training Loss: -0.8341
# Epoch 706/1000, Training Loss: -0.8311
# Epoch 707/1000, Training Loss: -0.8263
# Epoch 708/1000, Training Loss: -0.8223
# Epoch 709/1000, Training Loss: -0.8232
# Epoch 710/1000, Training Loss: -0.8302
# Epoch 711/1000, Training Loss: -0.8304
# Epoch 712/1000, Training Loss: -0.8375
# Epoch 713/1000, Training Loss: -0.8293
# Epoch 714/1000, Training Loss: -0.8309
# Epoch 715/1000, Training Loss: -0.8205
# Epoch 716/1000, Training Loss: -0.8262
# Epoch 717/1000, Training Loss: -0.8242
# Epoch 718/1000, Training Loss: -0.8221
# Epoch 719/1000, Training Loss: -0.8273
# Epoch 720/1000, Training Loss: -0.8251
# Epoch 721/1000, Training Loss: -0.8347
# Epoch 722/1000, Training Loss: -0.8249
# Epoch 723/1000, Training Loss: -0.8229
# Epoch 724/1000, Training Loss: -0.8311
# Epoch 725/1000, Training Loss: -0.8191
# Epoch 726/1000, Training Loss: -0.8386
# Epoch 727/1000, Training Loss: -0.8206
# Epoch 728/1000, Training Loss: -0.8339
# Epoch 729/1000, Training Loss: -0.8172
# Epoch 730/1000, Training Loss: -0.8223
# Epoch 731/1000, Training Loss: -0.8260
# Epoch 732/1000, Training Loss: -0.8269
# Epoch 733/1000, Training Loss: -0.8243
# Epoch 734/1000, Training Loss: -0.8323
# Epoch 735/1000, Training Loss: -0.8260
# Epoch 736/1000, Training Loss: -0.8324
# Epoch 737/1000, Training Loss: -0.8296
# Epoch 738/1000, Training Loss: -0.8269
# Epoch 739/1000, Training Loss: -0.8260
# Epoch 740/1000, Training Loss: -0.8310
# Epoch 741/1000, Training Loss: -0.8348
# Epoch 742/1000, Training Loss: -0.8320
# Epoch 743/1000, Training Loss: -0.8286
# Epoch 744/1000, Training Loss: -0.8303
# Epoch 745/1000, Training Loss: -0.8226
# Epoch 746/1000, Training Loss: -0.8220
# Epoch 747/1000, Training Loss: -0.8287
# Epoch 748/1000, Training Loss: -0.8247
# Epoch 749/1000, Training Loss: -0.8294
# Epoch 750/1000, Training Loss: -0.8290
# Epoch 751/1000, Training Loss: -0.8282
# Epoch 752/1000, Training Loss: -0.8271
# Epoch 753/1000, Training Loss: -0.8251
# Epoch 754/1000, Training Loss: -0.8311
# Epoch 755/1000, Training Loss: -0.8206
# Epoch 756/1000, Training Loss: -0.8399
# Epoch 757/1000, Training Loss: -0.8200
# Epoch 758/1000, Training Loss: -0.8277
# Epoch 759/1000, Training Loss: -0.8178
# Epoch 760/1000, Training Loss: -0.8282
# Epoch 761/1000, Training Loss: -0.8270
# Epoch 762/1000, Training Loss: -0.8343
# Epoch 763/1000, Training Loss: -0.8321
# Epoch 764/1000, Training Loss: -0.8241
# Epoch 765/1000, Training Loss: -0.8259
# Epoch 766/1000, Training Loss: -0.8222
# Epoch 767/1000, Training Loss: -0.8286
# Epoch 768/1000, Training Loss: -0.8233
# Epoch 769/1000, Training Loss: -0.8295
# Epoch 770/1000, Training Loss: -0.8284
# Epoch 771/1000, Training Loss: -0.8271
# Epoch 772/1000, Training Loss: -0.8215
# Epoch 773/1000, Training Loss: -0.8339
# Epoch 774/1000, Training Loss: -0.8287
# Epoch 775/1000, Training Loss: -0.8213
# Epoch 776/1000, Training Loss: -0.8238
# Epoch 777/1000, Training Loss: -0.8252
# Epoch 778/1000, Training Loss: -0.8359
# Epoch 779/1000, Training Loss: -0.8242
# Epoch 780/1000, Training Loss: -0.8222
# Epoch 781/1000, Training Loss: -0.8304
# Epoch 782/1000, Training Loss: -0.8215
# Epoch 783/1000, Training Loss: -0.8320
# Epoch 784/1000, Training Loss: -0.8263
# Epoch 785/1000, Training Loss: -0.8305
# Epoch 786/1000, Training Loss: -0.8331
# Epoch 787/1000, Training Loss: -0.8258
# Epoch 788/1000, Training Loss: -0.8382
# Epoch 789/1000, Training Loss: -0.8224
# Epoch 790/1000, Training Loss: -0.8215
# Epoch 791/1000, Training Loss: -0.8254
# Epoch 792/1000, Training Loss: -0.8236
# Epoch 793/1000, Training Loss: -0.8311
# Epoch 794/1000, Training Loss: -0.8288
# Epoch 795/1000, Training Loss: -0.8265
# Epoch 796/1000, Training Loss: -0.8294
# Epoch 797/1000, Training Loss: -0.8185
# Epoch 798/1000, Training Loss: -0.8296
# Epoch 799/1000, Training Loss: -0.8314
# Epoch 800/1000, Training Loss: -0.8294
# Epoch 801/1000, Training Loss: -0.8217
# Epoch 802/1000, Training Loss: -0.8224
# Epoch 803/1000, Training Loss: -0.8253
# Epoch 804/1000, Training Loss: -0.8300
# Epoch 805/1000, Training Loss: -0.8281
# Epoch 806/1000, Training Loss: -0.8331
# Epoch 807/1000, Training Loss: -0.8233
# Epoch 808/1000, Training Loss: -0.8261
# Epoch 809/1000, Training Loss: -0.8263
# Epoch 810/1000, Training Loss: -0.8264
# Epoch 811/1000, Training Loss: -0.8349
# Epoch 812/1000, Training Loss: -0.8150
# Epoch 813/1000, Training Loss: -0.8340
# Epoch 814/1000, Training Loss: -0.8253
# Epoch 815/1000, Training Loss: -0.8317
# Epoch 816/1000, Training Loss: -0.8234
# Epoch 817/1000, Training Loss: -0.8249
# Epoch 818/1000, Training Loss: -0.8196
# Epoch 819/1000, Training Loss: -0.8216
# Epoch 820/1000, Training Loss: -0.8337
# Epoch 821/1000, Training Loss: -0.8187
# Epoch 822/1000, Training Loss: -0.8223
# Epoch 823/1000, Training Loss: -0.8244
# Epoch 824/1000, Training Loss: -0.8333
# Epoch 825/1000, Training Loss: -0.8292
# Epoch 826/1000, Training Loss: -0.8271
# Epoch 827/1000, Training Loss: -0.8313
# Epoch 828/1000, Training Loss: -0.8294
# Epoch 829/1000, Training Loss: -0.8340
# Epoch 830/1000, Training Loss: -0.8220
# Epoch 831/1000, Training Loss: -0.8252
# Epoch 832/1000, Training Loss: -0.8236
# Epoch 833/1000, Training Loss: -0.8316
# Epoch 834/1000, Training Loss: -0.8239
# Epoch 835/1000, Training Loss: -0.8294
# Epoch 836/1000, Training Loss: -0.8195
# Epoch 837/1000, Training Loss: -0.8330
# Epoch 838/1000, Training Loss: -0.8256
# Epoch 839/1000, Training Loss: -0.8265
# Epoch 840/1000, Training Loss: -0.8243
# Epoch 841/1000, Training Loss: -0.8235
# Epoch 842/1000, Training Loss: -0.8193
# Epoch 843/1000, Training Loss: -0.8267
# Epoch 844/1000, Training Loss: -0.8216
# Epoch 845/1000, Training Loss: -0.8307
# Epoch 846/1000, Training Loss: -0.8307
# Epoch 847/1000, Training Loss: -0.8363
# Epoch 848/1000, Training Loss: -0.8300
# Epoch 849/1000, Training Loss: -0.8284
# Epoch 850/1000, Training Loss: -0.8285
# Epoch 851/1000, Training Loss: -0.8327
# Epoch 852/1000, Training Loss: -0.8244
# Epoch 853/1000, Training Loss: -0.8233
# Epoch 854/1000, Training Loss: -0.8273
# Epoch 855/1000, Training Loss: -0.8251
# Epoch 856/1000, Training Loss: -0.8257
# Epoch 857/1000, Training Loss: -0.8268
# Epoch 858/1000, Training Loss: -0.8236
# Epoch 859/1000, Training Loss: -0.8279
# Epoch 860/1000, Training Loss: -0.8276
# Epoch 861/1000, Training Loss: -0.8194
# Epoch 862/1000, Training Loss: -0.8320
# Epoch 863/1000, Training Loss: -0.8284
# Epoch 864/1000, Training Loss: -0.8314
# Epoch 865/1000, Training Loss: -0.8258
# Epoch 866/1000, Training Loss: -0.8235
# Epoch 867/1000, Training Loss: -0.8231
# Epoch 868/1000, Training Loss: -0.8314
# Epoch 869/1000, Training Loss: -0.8267
# Epoch 870/1000, Training Loss: -0.8217
# Epoch 871/1000, Training Loss: -0.8288
# Epoch 872/1000, Training Loss: -0.8347
# Epoch 873/1000, Training Loss: -0.8257
# Epoch 874/1000, Training Loss: -0.8302
# Epoch 875/1000, Training Loss: -0.8140
# Epoch 876/1000, Training Loss: -0.8343
# Epoch 877/1000, Training Loss: -0.8200
# Epoch 878/1000, Training Loss: -0.8373
# Epoch 879/1000, Training Loss: -0.8176
# Epoch 880/1000, Training Loss: -0.8293
# Epoch 881/1000, Training Loss: -0.8181
# Epoch 882/1000, Training Loss: -0.8308
# Epoch 883/1000, Training Loss: -0.8238
# Epoch 884/1000, Training Loss: -0.8330
# Epoch 885/1000, Training Loss: -0.8302
# Epoch 886/1000, Training Loss: -0.8296
# Epoch 887/1000, Training Loss: -0.8290
# Epoch 888/1000, Training Loss: -0.8313
# Epoch 889/1000, Training Loss: -0.8324
# Epoch 890/1000, Training Loss: -0.8327
# Epoch 891/1000, Training Loss: -0.8257
# Epoch 892/1000, Training Loss: -0.8249
# Epoch 893/1000, Training Loss: -0.8369
# Epoch 894/1000, Training Loss: -0.8331
# Epoch 895/1000, Training Loss: -0.8244
# Epoch 896/1000, Training Loss: -0.8248
# Epoch 897/1000, Training Loss: -0.8250
# Epoch 898/1000, Training Loss: -0.8298
# Epoch 899/1000, Training Loss: -0.8331
# Epoch 900/1000, Training Loss: -0.8313
# Epoch 901/1000, Training Loss: -0.8392
# Epoch 902/1000, Training Loss: -0.8240
# Epoch 903/1000, Training Loss: -0.8315
# Epoch 904/1000, Training Loss: -0.8340
# Epoch 905/1000, Training Loss: -0.8301
# Epoch 906/1000, Training Loss: -0.8274
# Epoch 907/1000, Training Loss: -0.8287
# Epoch 908/1000, Training Loss: -0.8410
# Epoch 909/1000, Training Loss: -0.8284
# Epoch 910/1000, Training Loss: -0.8297
# Epoch 911/1000, Training Loss: -0.8252
# Epoch 912/1000, Training Loss: -0.8227
# Epoch 913/1000, Training Loss: -0.8150
# Epoch 914/1000, Training Loss: -0.8260
# Epoch 915/1000, Training Loss: -0.8266
# Epoch 916/1000, Training Loss: -0.8299
# Epoch 917/1000, Training Loss: -0.8321
# Epoch 918/1000, Training Loss: -0.8271
# Epoch 919/1000, Training Loss: -0.8289
# Epoch 920/1000, Training Loss: -0.8381
# Epoch 921/1000, Training Loss: -0.8259
# Epoch 922/1000, Training Loss: -0.8238
# Epoch 923/1000, Training Loss: -0.8291
# Epoch 924/1000, Training Loss: -0.8244
# Epoch 925/1000, Training Loss: -0.8306
# Epoch 926/1000, Training Loss: -0.8153
# Epoch 927/1000, Training Loss: -0.8311
# Epoch 928/1000, Training Loss: -0.8206
# Epoch 929/1000, Training Loss: -0.8138
# Epoch 930/1000, Training Loss: -0.8307
# Epoch 931/1000, Training Loss: -0.8231
# Epoch 932/1000, Training Loss: -0.8338
# Epoch 933/1000, Training Loss: -0.8243
# Epoch 934/1000, Training Loss: -0.8294
# Epoch 935/1000, Training Loss: -0.8219
# Epoch 936/1000, Training Loss: -0.8375
# Epoch 937/1000, Training Loss: -0.8345
# Epoch 938/1000, Training Loss: -0.8236
# Epoch 939/1000, Training Loss: -0.8248
# Epoch 940/1000, Training Loss: -0.8244
# Epoch 941/1000, Training Loss: -0.8234
# Epoch 942/1000, Training Loss: -0.8205
# Epoch 943/1000, Training Loss: -0.8217
# Epoch 944/1000, Training Loss: -0.8235
# Epoch 945/1000, Training Loss: -0.8308
# Epoch 946/1000, Training Loss: -0.8359
# Epoch 947/1000, Training Loss: -0.8233
# Epoch 948/1000, Training Loss: -0.8238
# Epoch 949/1000, Training Loss: -0.8350
# Epoch 950/1000, Training Loss: -0.8289
# Epoch 951/1000, Training Loss: -0.8231
# Epoch 952/1000, Training Loss: -0.8235
# Epoch 953/1000, Training Loss: -0.8242
# Epoch 954/1000, Training Loss: -0.8305
# Epoch 955/1000, Training Loss: -0.8401
# Epoch 956/1000, Training Loss: -0.8223
# Epoch 957/1000, Training Loss: -0.8281
# Epoch 958/1000, Training Loss: -0.8247
# Epoch 959/1000, Training Loss: -0.8244
# Epoch 960/1000, Training Loss: -0.8209
# Epoch 961/1000, Training Loss: -0.8182
# Epoch 962/1000, Training Loss: -0.8319
# Epoch 963/1000, Training Loss: -0.8213
# Epoch 964/1000, Training Loss: -0.8286
# Epoch 965/1000, Training Loss: -0.8250
# Epoch 966/1000, Training Loss: -0.8291
# Epoch 967/1000, Training Loss: -0.8180
# Epoch 968/1000, Training Loss: -0.8366
# Epoch 969/1000, Training Loss: -0.8205
# Epoch 970/1000, Training Loss: -0.8303
# Epoch 971/1000, Training Loss: -0.8199
# Epoch 972/1000, Training Loss: -0.8281
# Epoch 973/1000, Training Loss: -0.8279
# Epoch 974/1000, Training Loss: -0.8294
# Epoch 975/1000, Training Loss: -0.8280
# Epoch 976/1000, Training Loss: -0.8206
# Epoch 977/1000, Training Loss: -0.8240
# Epoch 978/1000, Training Loss: -0.8246
# Epoch 979/1000, Training Loss: -0.8234
# Epoch 980/1000, Training Loss: -0.8217
# Epoch 981/1000, Training Loss: -0.8222
# Epoch 982/1000, Training Loss: -0.8348
# Epoch 983/1000, Training Loss: -0.8329
# Epoch 984/1000, Training Loss: -0.8254
# Epoch 985/1000, Training Loss: -0.8264
# Epoch 986/1000, Training Loss: -0.8214
# Epoch 987/1000, Training Loss: -0.8228
# Epoch 988/1000, Training Loss: -0.8213
# Epoch 989/1000, Training Loss: -0.8276
# Epoch 990/1000, Training Loss: -0.8285
# Epoch 991/1000, Training Loss: -0.8278
# Epoch 992/1000, Training Loss: -0.8371
# Epoch 993/1000, Training Loss: -0.8226
# Epoch 994/1000, Training Loss: -0.8233
# Epoch 995/1000, Training Loss: -0.8281
# Epoch 996/1000, Training Loss: -0.8223
# Epoch 997/1000, Training Loss: -0.8227
# Epoch 998/1000, Training Loss: -0.8318
# Epoch 999/1000, Training Loss: -0.8169
# Epoch 1000/1000, Training Loss: -0.8319

# %%
import torch
from torch.distributions import Normal

# ──────────────────────────────────────────────────────────────────────────────
# 1) Re‐generate “observational” data (no intervention)
# ──────────────────────────────────────────────────────────────────────────────
N = 10000

# draw N observations (no do‐intervention)
X_obs_full,U_obs = scm(
    N=N,
    seed=0,
    intervention_node=None,
    return_u=True,            # we do not need U here
    noise_dists=noise_dists,
    noise_transforms=noise_transforms
)
X_obs = X_obs_full[:, :1]   # (N,1)
Y_obs = X_obs_full[:, 1:]   # (N,4)


# ──────────────────────────────────────────────────────────────────────────────
# 2) Draw “true interventional” data by calling the SCM with intervention_node=1
# ──────────────────────────────────────────────────────────────────────────────
c = 0.0
X_int_full, U_int = scm(
    N=N,
    seed=0,                     # fresh seed (independent of the observational draw)
    intervention_node=1,        # hard‐set X₁ = c
    intervention_value=c,
    return_u=True,
    noise_dists=noise_dists,
    noise_transforms=noise_transforms
)
Y_true_int = X_int_full[:, 1:]  # shape (N,4)


# ──────────────────────────────────────────────────────────────────────────────
# 3) Use the trained cocycle model to predict counterfactuals under do(X₁ = c)
# ──────────────────────────────────────────────────────────────────────────────
#    Y_pred_int[i] = f( x_do = c,  f^{-1}( x_obs[i],  Y_obs[i] ) )

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
best_model = model0.to(device)       # your trained ZukoCocycleModel
x_obs      = X_obs.to(device)        # (N,1)
y_obs      = Y_obs.to(device)        # (N,4)
x_do       = torch.full_like(x_obs, c)  # (N,1), all entries = c

with torch.no_grad():
    Y_pred_int = best_model.cocycle(x_do, x_obs, y_obs)  # (N,4)

Y_pred_int_cpu = Y_pred_int.cpu()
Y_true_int_cpu = Y_true_int.cpu()


# ──────────────────────────────────────────────────────────────────────────────
# 4) Compute marginal KS‐distance for each output dimension j = 0..3
# ──────────────────────────────────────────────────────────────────────────────

ks_vals = []
for j in range(Y_true_int_cpu.size(1)):  # 4 dims
    ks_j = ks_statistic(Y_pred_int_cpu[:, j], Y_true_int_cpu[:, j])
    ks_vals.append(ks_j)

print("KS distances (hard intervention) per dimension:", ks_vals)


# ──────────────────────────────────────────────────────────────────────────────
# 5) Compute counterfactual RMSE (per output dimension)
# ──────────────────────────────────────────────────────────────────────────────
rmse_vals = []
for j in range(Y_true_int_cpu.size(1)):
    diff   = Y_pred_int_cpu[:, j] - Y_true_int_cpu[:, j]
    rmse_j = torch.sqrt((diff ** 2).mean()).item()
    rmse_vals.append(rmse_j)

print("Counterfactual RMSE (hard intervention) per dimension:", rmse_vals)
# Out:
# KS distances (hard intervention) per dimension: [0.0340999960899353, 0.0317000150680542, 0.045399993658065796, 0.035800039768218994]
# Counterfactual RMSE (hard intervention) per dimension: [0.17734958231449127, 0.3007647693157196, 0.5304532647132874, 0.5358552932739258]

# %%
# 1) Grab the first MAF in your flow:
maf = model0.transforms[0]   # this is a MaskedAutoregressiveTransform

# 2) The very first layer inside that MAF’s conditioner is actually a MaskedLinear.
#    In most Zuko versions, it lives under `maf.hyper[0]`, so:
masked_linear = maf.hyper[0]     # type: zuko.flows.autoregressive.MaskedLinear

# 3) The raw weight parameter is:
raw_W = masked_linear.weight     # shape = (4, 5)
#    and the associated mask is:
mask  = masked_linear.mask       # same shape = (4, 5)

print("raw_W (un‐masked parameter):")
print(raw_W)

print("\nmask (0/1 binary tensor):")
print(mask)

# 4) If you multiply them, you get the actual weight used during forward:
effective_W = raw_W * mask
print("\neffective_W = raw_W * mask (i.e. the masked‐out values):")
print(effective_W)
# Out:
# raw_W (un‐masked parameter):
# Parameter containing:
# tensor([[ 8.0902e-02, -4.2480e-01,  1.0662e-01, -2.3866e-01,  2.2698e-01],
#         [ 5.1630e-02, -3.2764e-01, -2.2654e-01,  3.4222e-01, -4.6735e-01],
#         [ 3.6205e-01, -3.1706e-01,  3.0608e-01,  1.5165e-01, -3.6487e-01],
#         [ 2.8724e-01,  1.2983e-01, -2.0013e-01, -2.0294e-01, -6.0159e-02],
.0000e+00, -0.0000e+00,  0.0000e+00, -0.0000e+00, -1.3768e-01],
#         [ 6.2584e-02, -0.0000e+00,  0.0000e+00, -0.0000e+00,  3.1093e-01],
#         [-2.5170e-01, -4.2308e-01,  0.0000e+00, -0.0000e+00, -1.1241e-03],
#         [-2.7227e-01, -2.2855e-01, -4.1098e-01,  0.0000e+00, -2.4652e-01],
#         [ 0.0000e+00, -0.0000e+00,  0.0000e+00, -0.0000e+00, -2.7534e-01],
#         [ 2.2506e-02,  0.0000e+00,  0.0000e+00, -0.0000e+00, -2.4648e-02],
#         [ 1.7784e-01,  1.2674e-02, -0.0000e+00,  0.0000e+00,  2.5189e-01],
#         [-2.7212e-01,  2.1396e-01,  3.9414e-01, -0.0000e+00,  3.3033e-02],
#         [ 0.0000e+00, -0.0000e+00,  0.0000e+00, -0.0000e+00,  4.8893e-01],
#         [-2.3098e-01, -0.0000e+00,  0.0000e+00,  0.0000e+00,  6.1276e-01],
#         [-1.2293e-01,  7.8697e-02, -0.0000e+00,  0.0000e+00, -5.2886e-01],
#         [ 2.6318e-01, -5.5810e-01, -2.3803e-01,  0.0000e+00, -1.9609e-01],
#         [-0.0000e+00, -0.0000e+00,  0.0000e+00, -0.0000e+00, -3.2595e-01],
#         [ 2.1215e-02, -0.0000e+00, -0.0000e+00,  0.0000e+00, -7.0056e-02],
#         [-1.7687e-01,  7.4982e-02,  0.0000e+00,  0.0000e+00, -4.6923e-01],
#         [-8.0935e-03,  2.0988e-01,  3.0565e-01, -0.0000e+00, -3.0361e-01],
#         [-0.0000e+00, -0.0000e+00,  0.0000e+00,  0.0000e+00, -4.4098e-01],
#         [-4.0254e-02,  0.0000e+00,  0.0000e+00,  0.0000e+00, -5.3975e-01],
#         [-3.6441e-02, -2.6927e-01,  0.0000e+00, -0.0000e+00,  5.4660e-01],
#         [ 3.4168e-02,  1.2523e-01, -2.8164e-01,  0.0000e+00,  1.1972e-01],
#         [-0.0000e+00,  0.0000e+00, -0.0000e+00,  0.0000e+00, -5.9041e-01],
#         [-1.9174e-01,  0.0000e+00, -0.0000e+00,  0.0000e+00,  2.3603e-01],
#         [ 3.1857e-04,  9.3513e-02, -0.0000e+00, -0.0000e+00, -1.6984e-01],
#         [ 6.5215e-02,  1.6544e-01,  1.0125e-02, -0.0000e+00,  9.3861e-02],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00, -4.0876e-01],
#         [-2.3572e-01,  0.0000e+00, -0.0000e+00, -0.0000e+00, -4.4701e-01],
#         [ 5.8842e-02, -8.0384e-02,  0.0000e+00, -0.0000e+00, -1.1172e-01],
#         [-2.1367e-01,  1.8136e-01,  2.8784e-01,  0.0000e+00,  5.8461e-02]],
#        grad_fn=<MulBackward0>)

# %%
# Multi-cocycle Training

# %%
import torch
import torch.nn as nn
from torch.utils.data import random_split, TensorDataset
from causal_cocycle.model_new import ZukoCocycleModel
from causal_cocycle.loss_factory import CocycleLossFactory
from causal_cocycle.kernels import gaussian_kernel
from causal_cocycle.optimise_new import optimise
from architectures import get_stock_transforms

# -----------------------------
# Step 1: Setup from full data
# -----------------------------
# Full data matrix (N, 5), e.g. from chain5
N, d = X_full.shape
assert d == 5
X_full = X_full.to("cuda" if torch.cuda.is_available() else "cpu")

# We will train 4 cocycle models: each V_j | V_{<j}, for j=1..4
models = []
losses = []
factory = CocycleLossFactory([gaussian_kernel(), gaussian_kernel()])
subsamples = 1000

# ------------------------------------------
# Step 2: Construct model/loss per coordinate
# ------------------------------------------
for j in range(1, d):
    x_ctx = X_full[:, :j]         # V_{<j}
    y_out = X_full[:, j:j+1]      # V_j

    # split train/val
    dataset = TensorDataset(x_ctx, y_out)
    n_train = int(1 * N)
    n_val = N - n_train
    train_ds, val_ds = random_split(dataset, [n_train, n_val], generator=torch.Generator().manual_seed(0))
    X_train = torch.stack([train_ds[i][0] for i in range(n_train)])
    Y_train = torch.stack([train_ds[i][1] for i in range(n_train)])

    # Make transform and model
    maf = get_stock_transforms(x_dim=j, y_dim=1)[2]
    model = ZukoCocycleModel(nn.ModuleList(maf)).to(X_full.device)
    models.append(model)

    # Tune kernel and get CMMD-V loss
    loss_j = factory.build_loss("CMMD_V", X_train, Y_train, subsamples=subsamples)
    losses.append(loss_j)

# ------------------------------------------
# Step 3: Define aggregate loss over models
# ------------------------------------------
class CMMDMultiLoss(nn.Module):
    def __init__(self, models, losses):
        super().__init__()
        self.models = models
        self.losses = losses

    def forward(self, _, inputs, outputs):
        loss_total = 0.0
        for j, (model, loss) in enumerate(zip(self.models, self.losses)):
            x_j = inputs[:, :j+1]       # context: V_{<j+1}
            y_j = outputs[:, j:j+1]     # target:  V_{j+1}
            loss_total += loss(model, x_j, y_j)
        return loss_total

# ------------------------------------------
# Step 4: Training
# ------------------------------------------
multi_loss = CMMDMultiLoss(models, losses)
composite_model = nn.ModuleList(models)

best_model, history = optimise(
    model              = composite_model,
    loss_tr            = multi_loss,
    inputs             = X_full[:, :d-1],  # V_{<d}
    outputs            = X_full[:, 1:],    # V_1 to V_4
    inputs_val         = None,
    outputs_val        = None,
    learn_rate         = 1e-2,
    epochs             = 500,
    weight_decay       = 0.0,
    batch_size         = 64,
    val_batch_size     = 256,
    scheduler          = False,
    schedule_milestone = 10,
    lr_mult            = 0.90,
    print_             = True,
    plot               = False,
    likelihood_param_opt = False,
    likelihood_param_lr  = 0.01,
    loss_val           = None
)
# Out:
# Epoch 1/500, Training Loss: -2.0410
# Epoch 2/500, Training Loss: -2.6992
# Epoch 3/500, Training Loss: -3.0456
# Epoch 4/500, Training Loss: -3.0979
# Epoch 5/500, Training Loss: -3.1252
# Epoch 6/500, Training Loss: -3.1520
# Epoch 7/500, Training Loss: -3.1277
# Epoch 8/500, Training Loss: -3.1515
# Epoch 9/500, Training Loss: -3.1833
# Epoch 10/500, Training Loss: -3.1683
# Epoch 11/500, Training Loss: -3.1481
# Epoch 12/500, Training Loss: -3.1753
# Epoch 13/500, Training Loss: -3.1549
# Epoch 14/500, Training Loss: -3.1967
# Epoch 15/500, Training Loss: -3.1921
# Epoch 16/500, Training Loss: -3.1882
# Epoch 17/500, Training Loss: -3.1739
# Epoch 18/500, Training Loss: -3.1663
# Epoch 19/500, Training Loss: -3.1849
# Epoch 20/500, Training Loss: -3.1972
# Epoch 21/500, Training Loss: -3.1926
# Epoch 22/500, Training Loss: -3.2005
# Epoch 23/500, Training Loss: -3.1932
# Epoch 24/500, Training Loss: -3.1966
# Epoch 25/500, Training Loss: -3.1852
# Epoch 26/500, Training Loss: -3.1805
# Epoch 27/500, Training Loss: -3.2081
# Epoch 28/500, Training Loss: -3.2227
# Epoch 29/500, Training Loss: -3.1881
# Epoch 30/500, Training Loss: -3.2254
# Epoch 451/500, Training Loss: -3.2913
# Epoch 452/500, Training Loss: -3.2865
# Epoch 453/500, Training Loss: -3.2768
# Epoch 454/500, Training Loss: -3.2883
# Epoch 455/500, Training Loss: -3.2901
# Epoch 456/500, Training Loss: -3.2826
# Epoch 457/500, Training Loss: -3.2571
# Epoch 458/500, Training Loss: -3.2743
# Epoch 459/500, Training Loss: -3.2790
# Epoch 460/500, Training Loss: -3.2890
# Epoch 461/500, Training Loss: -3.2764
# Epoch 462/500, Training Loss: -3.2870
# Epoch 463/500, Training Loss: -3.2653
# Epoch 464/500, Training Loss: -3.2710
# Epoch 465/500, Training Loss: -3.2866
# Epoch 466/500, Training Loss: -3.2840
# Epoch 467/500, Training Loss: -3.2813
# Epoch 468/500, Training Loss: -3.2758
# Epoch 469/500, Training Loss: -3.2454
# Epoch 470/500, Training Loss: -3.2578
# Epoch 471/500, Training Loss: -3.2775
# Epoch 472/500, Training Loss: -3.2854
# Epoch 473/500, Training Loss: -3.2770
# Epoch 474/500, Training Loss: -3.2878
# Epoch 475/500, Training Loss: -3.2669
# Epoch 476/500, Training Loss: -3.2937
# Epoch 477/500, Training Loss: -3.3032
# Epoch 478/500, Training Loss: -3.2842
# Epoch 479/500, Training Loss: -3.3006
# Epoch 480/500, Training Loss: -3.2496
# Epoch 481/500, Training Loss: -3.2604
# Epoch 482/500, Training Loss: -3.2718
# Epoch 483/500, Training Loss: -3.2930
# Epoch 484/500, Training Loss: -3.2718
# Epoch 485/500, Training Loss: -3.2740
# Epoch 486/500, Training Loss: -3.2754
# Epoch 487/500, Training Loss: -3.2733
# Epoch 488/500, Training Loss: -3.2870
# Epoch 489/500, Training Loss: -3.2916
# Epoch 490/500, Training Loss: -3.2577
# Epoch 491/500, Training Loss: -3.2618
# Epoch 492/500, Training Loss: -3.2761
# Epoch 493/500, Training Loss: -3.2867
# Epoch 494/500, Training Loss: -3.2815
# Epoch 495/500, Training Loss: -3.2750
# Epoch 496/500, Training Loss: -3.2985
# Epoch 497/500, Training Loss: -3.2645
# Epoch 498/500, Training Loss: -3.2826
# Epoch 499/500, Training Loss: -3.2769
# Epoch 500/500, Training Loss: -3.2707

# %%
import torch
from torch.distributions import Normal

# 1) Re-generate observational and interventional data
N = 5000
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# observational data (X₁,...,X₅)
X_obs_full, U = scm(
    N=N, seed=0, intervention_node=None, return_u=True,
    noise_dists=noise_dists, noise_transforms=noise_transforms
)
X_obs_full = X_obs_full.to(device)

# interventional (true) data under do(X₁ = c)
c = 0.0
X_true_cf_full, U_cf = scm(
    N=N, seed=0, intervention_node=1, intervention_value=c,
    return_u=True, noise_dists=noise_dists, noise_transforms=noise_transforms
)
Y_true_cf = X_true_cf_full[:, 1:]  # (N, 4)

# 2) Predict counterfactuals from models
models = [f.to(device) for f in models]  # trained cocycle models per coordinate

# Intervention: set X₁ = c
X_obs_cf = X_obs_full.clone()
X_obs_cf[:, 0] = c   # hard intervention on V₀

# Sequentially reconstruct (V₁,...,V₄) using the trained cocycles
predicted_cf = torch.zeros((N, 4), device=device)

for j, model in enumerate(models):
    # Build context using previously predicted counterfactuals
    if j == 0:
        x_new = X_obs_cf[:, :1]                     # just the intervened x₁
        x_old = X_obs_full[:, :1]
    else:
        x_new = torch.cat([X_obs_cf[:, :1], predicted_cf[:, :j]], dim=1)  # updated context
        x_old = torch.cat([X_obs_full[:, :1], X_obs_full[:, 1:1+j]], dim=1)

    y_old = X_obs_full[:, j+1:j+2]  # observed y_j

    with torch.no_grad():
        y_pred = model.cocycle(x_new, x_old, y_old)

    predicted_cf[:, j:j+1] = y_pred  # store for use in future iterations

# 3) Compute KS distances
def ks_statistic(a: torch.Tensor, b: torch.Tensor) -> float:
    a, b = a.flatten(), b.flatten()
    a_s, _ = torch.sort(a)
    b_s, _ = torch.sort(b)
    all_vals = torch.cat([a_s, b_s]).unique()
    cdf_a = torch.bucketize(all_vals, a_s, right=True).float() / a_s.numel()
    cdf_b = torch.bucketize(all_vals, b_s, right=True).float() / b_s.numel()
    return (torch.abs(cdf_a - cdf_b).max()).item()

ks_vals = [
    ks_statistic(predicted_cf[:, j].cpu(), Y_true_cf[:, j].cpu())
    for j in range(4)
]
print("KS distances (hard intervention) per dimension:", ks_vals)

# 4) Compute RMSE
rmse_vals = [
    torch.sqrt(((predicted_cf[:, j] - Y_true_cf[:, j])**2).mean()).item()
    for j in range(4)
]
print("Counterfactual RMSE (hard intervention) per dimension:", rmse_vals)
# Out:
# KS distances (hard intervention) per dimension: [0.0690000057220459, 0.12020003795623779, 0.1340000033378601, 0.13679999113082886]
# Counterfactual RMSE (hard intervention) per dimension: [0.26215505599975586, 1.0929704904556274, 1.2617816925048828, 1.7701361179351807]

# %%
for i in range(4):
    print(models[i].transforms[0].hyper[0].weight)
    print(torch.linalg.solve(X_full[:,:i+1].T @ X_full[:,:i+1], X_full[:,:i+1].T @ X_full[:,i+1:i+2]))
# Out:
# Parameter containing:
# tensor([[ 3.4044e-01],
#         [-5.4944e-01],
#         [-3.7757e-01],
#         [ 1.4378e-01],
#         [-1.2887e-01],
#         [ 4.0049e-01],
#         [ 1.3131e-03],
#         [ 2.6580e-01],
#         [-1.2055e-01],
#         [ 2.3000e-03],
#         [ 4.8790e-02],
#         [-7.7819e-01],
#         [-1.3907e-01],
#         [ 6.3595e-01],
#         [-2.2286e-02],
#         [ 1.8039e-01],
#         [ 1.9533e-01],
#         [-1.5045e-01],
#         [ 4.8664e-01],
#         [-9.8210e-02],
#         [ 4.8804e-01],
#         [ 3.3773e-03],
#         [-2.4974e-01],
#         [-1.9627e-01],
#         [ 6.7053e-01],
#         [ 8.0588e-01],
#         [-4.0051e-01],
#         [-9.2777e-03],
#         [-2.4872e-01],
#         [ 2.4762e-01],
#         [-8.1879e-02],
#         [-8.3429e-04],
#         [ 5.4720e-01],
#         [ 4.5696e-01],
#         [-3.0364e-05],
#         [ 2.1999e-02],
#         [ 2.5275e-02],
#         [-3.2750e-01],
#         [-5.8912e-05],
#         [ 3.4219e-01],
#         [-5.9961e-03],
#         [-4.5564e-01],
#         [ 3.0340e-01],
#         [ 2.7271e-01],
#         [-7.4342e-01],
#         [ 3.8240e-02],
#         [-3.0915e-04],
#         [-2.0736e-01],
#         [-6.3714e-01],
#         [-1.5437e-01],
#         [ 5.4040e-01],
#         [-2.1401e-01],
#         [-3.3837e-01],
#         [ 2.2607e-01],
#         [ 2.0100e-01],
#         [ 1.4679e-02],
#         [ 3.2058e-01],
#         [ 8.2038e-02],
#         [ 3.1112e-02],
#         [ 1.7212e-01],
#         [ 7.2744e-02],
#         [-5.4347e-01],
#         [-9.9589e-03],
#         [ 2.8869e-01]], requires_grad=True)
# tensor([[10.0279]])
# Parameter containing:
# tensor([[-1.7658, -0.4968],
#         [ 0.1425, -0.0039],
#         [-1.9997,  0.2593],
#         [-0.1338,  0.0173],
#         [-0.0917,  0.2474],
#         [ 0.9128, -0.0899],
#         [ 0.1316, -0.0400],
#         [ 0.3649, -0.0246],
#         [-0.5225,  0.2329],
#         [ 0.9041, -0.0781],
#         [-2.7526,  0.4422],
#         [-0.7940,  0.0711],
#         [ 0.2960, -0.0193],
#         [ 0.3366, -0.0383],
#         [ 0.4736, -0.0476],
#         [-0.2128, -0.0113],
#         [ 0.3676,  0.5381],
#         [-1.0610,  0.1125],
#         [-0.1166,  0.0035],
#         [-0.8254,  0.0883],
#         [-0.0883, -0.0272],
#         [-0.2693,  0.0256],
#         [-0.7387,  0.0757],
#         [-0.7559,  0.0771],
#         [ 0.4197, -0.0421],
#         [ 0.1258, -0.0151],
#         [-0.3049,  0.0125],
#         [ 0.1045, -0.0392],
#         [ 0.3679, -0.0585],
#         [ 0.6498, -0.0510],
#         [-0.0064, -0.0064],
#         [-0.4408,  0.0444],
#         [-0.9687,  0.0964],
#         [ 0.1612, -0.0108],
#         [-0.2663,  0.0726],
#         [ 2.4416, -0.2796],
#         [-1.0966,  0.1103],
#         [ 2.5152, -0.2198],
#         [ 1.0400, -0.1437],
#         [-0.2478,  0.0328],
#         [ 1.0084, -0.0877],
#         [ 0.5700, -0.0164],
#         [ 0.6190, -0.5694],
#         [-0.2257,  0.0112],
#         [-0.9604,  0.1139],
#         [ 2.9382, -0.1346],
#         [ 0.7189, -0.0905],
#         [-1.5884, -0.2048],
#         [ 0.7506, -0.0752],
#         [-2.5095,  0.3948],
#         [-0.0845,  0.0347],
#         [-0.2508,  0.0294],
#         [ 0.2397, -0.1339],
#         [-0.9212,  0.0861],
#         [-2.8619,  0.2157],
#         [ 1.3261, -0.1422],
#         [ 0.2961, -0.0455],
#         [ 0.2330, -0.0484],
#         [-0.9233,  0.0982],
#         [ 0.0737, -0.0087],
#         [-0.6287,  0.0463],
#         [-0.2627,  0.0352],
#         [-0.9446,  0.0910],
#         [ 2.6799, -0.2240]], requires_grad=True)
# tensor([[-0.3124],
#         [ 0.2799]])
# Parameter containing:
# tensor([[ 9.7035e-01, -7.9296e-02, -2.3606e-01],
#         [-4.4162e-01,  5.4136e-02,  3.7575e-02],
#         [ 2.2657e+00,  6.4063e-02, -1.1111e-01],
