# %%
# Imports
import torch
from dask_jobqueue import SLURMCluster
from distributed import Client
from run_cocycles_mixed_bd import run_experiment
from csuite_mixed import SCMS

# %%
seeds = 10
nsamples = 2000
corr = 0.0
use_dag = False
#scms = ["generate_backdoor_linear", "generate_backdoor_nonlinear"]
scms = list(SCMS.keys())

# %%
cluster = SLURMCluster(
    n_workers=0,
    memory="20GB",
    processes=1,
    cores=1,
    scheduler_options={
        "dashboard_address": ":10092",
        "allowed_failures": 10
    },
    job_cpu=1,
    walltime="24:0:0",
)
cluster.adapt(minimum=0, maximum=200)
client = Client(cluster)

# %%
futures = []
for scm in scms:
    for seed in range(seeds):
        f = client.submit(run_experiment, 
                          sc_name = scm,
                          seed = seed,
                          N = nsamples)
        futures += [f]

# %%
futures
# Out:
# [<Future: pending, key: run_experiment-3362964763ac2ae2fc6d28c3cfcdb493>,
#  <Future: pending, key: run_experiment-5baea4556e32d3e9aab4d7a0824a8f64>,
#  <Future: pending, key: run_experiment-e0ac5e4c1f7f9d7cdf812df2ea106a79>,
#  <Future: pending, key: run_experiment-4094a0f978e6cda34e93117b8d243d53>,
#  <Future: pending, key: run_experiment-eb7cc4727b1e3cfa6b2240a82325584a>,
#  <Future: pending, key: run_experiment-9ecc7b5ab923b5fec1536f13f0bc2cdd>,
#  <Future: pending, key: run_experiment-624a471d2ee519fe791c3bfc0fa8c48a>,
#  <Future: pending, key: run_experiment-ccfb272383c7069ba1e9c4a10f8adfc2>,
#  <Future: pending, key: run_experiment-bcdc519a2a9499dcef1f29b33d47d5f3>,
#  <Future: pending, key: run_experiment-05aa9c8bfacec8afae7ed15a47ad6945>,
#  <Future: pending, key: run_experiment-e1a6e990f8b486f498ac36b5c29b3050>,
#  <Future: pending, key: run_experiment-7777489ec35df26d0ee2fca13eb28cde>,
#  <Future: pending, key: run_experiment-15f312f895b5ab65d26dd05064a94c8a>,
#  <Future: pending, key: run_experiment-5e03386a77f7d96cf259a3ca5df76530>,
#  <Future: pending, key: run_experiment-ae2a427137e301bac0f42cb811835276>,
#  <Future: pending, key: run_experiment-cac1fadc2c938f6e8bc24959bf2db071>,
#  <Future: pending, key: run_experiment-177967514822e918c16dc03c6f125c80>,
#  <Future: pending, key: run_experiment-d8ca8911a02c2272e8bc83bc3438b9ad>,
#  <Future: pending, key: run_experiment-5e4169813fae24d05ebc8956f9f4810a>,
#  <Future: pending, key: run_experiment-b2be525f1851bf586b12353c15c7663c>,
#  <Future: pending, key: run_experiment-d2692dbb4bcdd4467ee17da4b06df04d>,
#  <Future: pending, key: run_experiment-54bad3a00aac96294c368dcc77774e80>,
#  <Future: pending, key: run_experiment-5d0ab2d859f23c7f56071c6e9eda5ca9>,
#  <Future: pending, key: run_experiment-3abbdcc7f410e9faa5a0896ef5274590>,
#  <Future: pending, key: run_experiment-8124b44905e8bbe5da49cb56ebe4e5c5>,
#  <Future: pending, key: run_experiment-9f1ad2ae7d0a7833d1ee1490cf1c5d6d>,
#  <Future: pending, key: run_experiment-837b9a33f194bdb70a53c5556bfad7b5>,
#  <Future: pending, key: run_experiment-3ecd0564068c41f2dd3b48b23e3eda71>,
#  <Future: pending, key: run_experiment-fac28b63a1365e91f213d9ecccf1d2a2>,
#  <Future: pending, key: run_experiment-0988080164506e29d0e7a012ca7c3bc4>,
#  <Future: pending, key: run_experiment-c83f16aa68ed5f763b1d7b28cf1c4010>,
#  <Future: pending, key: run_experiment-f19ef9b6d220698ee1785744e4b0333b>,
#  <Future: pending, key: run_experiment-11cfebf106f909f20a82651c1ab83e09>,
#  <Future: pending, key: run_experiment-7b629f2cbe2f1a5e0d5db24ab7d3e7d4>,
#  <Future: pending, key: run_experiment-4fbdf9b9654bb6a2cbdf334905434a67>,
#  <Future: pending, key: run_experiment-305e05e0deafb237c1b51863c93ddc5e>,
#  <Future: pending, key: run_experiment-dc0fbd377279a7e91319d224e887c4bf>,
#  <Future: pending, key: run_experiment-a8c5f920ef2e3720bdcc00965e3c4b3e>,
#  <Future: pending, key: run_experiment-1a0e20e4ec230b55892c427fb13480f2>,
#  <Future: pending, key: run_experiment-d82fdbe08a139e946c5942fe75733bb5>,
#  <Future: pending, key: run_experiment-122e7260c0dfb233b568f99154259266>,
#  <Future: pending, key: run_experiment-4af6c9b1ce12816b4b0ac2b4144b021f>,
#  <Future: pending, key: run_experiment-6679d648b93a895232f8d2a5fc27f5ad>,
#  <Future: pending, key: run_experiment-41e5e21e2cb1f0d35be8470c0ebdcee3>,
#  <Future: pending, key: run_experiment-bb7113e3af4fbf8d0fd51ec85110cfb2>,
#  <Future: pending, key: run_experiment-52dcc7013b0c7638c2b2f5f12d75ed35>,
#  <Future: pending, key: run_experiment-e365c026eb079c7389551efc28ba9e2f>,
#  <Future: pending, key: run_experiment-211cfb1fdf492e221035ddda373f8330>,
#  <Future: pending, key: run_experiment-10f2f0c0137316aedad984cdf960b5e1>,
#  <Future: pending, key: run_experiment-9e3f3087383139311453995b3f05f261>,
#  <Future: pending, key: run_experiment-d0bc3ee7469a0a5e8d3d5c0a726cf5f1>,
#  <Future: pending, key: run_experiment-1ff2516d87c390d75c2756c7f5ce1250>,
#  <Future: pending, key: run_experiment-77d0e5a21c21b7847f5c6f37756061de>,
#  <Future: pending, key: run_experiment-688a849b610154c3a37ebb9bf48fd4ff>,
#  <Future: pending, key: run_experiment-969de253fa42d4ad98d68e62b501106e>,
#  <Future: pending, key: run_experiment-b5a3780f27f92488eb98e145b49d630d>,
#  <Future: pending, key: run_experiment-ec7c49277daab0d69c83fb45ba6817f7>,
#  <Future: pending, key: run_experiment-3b03078906e90b9d0c509b11aca6861b>,
#  <Future: pending, key: run_experiment-2d3ec120e19dc53ab5c841ce100e2b0e>,
#  <Future: pending, key: run_experiment-0d46e3215fb8ec53df9d5fe4144a08da>,
#  <Future: pending, key: run_experiment-907fa8082ffe91a85d599267ead1ce54>,
#  <Future: pending, key: run_experiment-9af0e77f1e69aab7b10131441177b307>,
#  <Future: pending, key: run_experiment-a7ace7ba9ade7aea7b64a95427419615>,
#  <Future: pending, key: run_experiment-33f38d624e2a6ab49eb45914bb238672>,
#  <Future: pending, key: run_experiment-0ed92bcca06d3d543f76e02bcad7e690>,
#  <Future: pending, key: run_experiment-571f046355a1ebe04d62d67af6e15080>,
#  <Future: pending, key: run_experiment-42e4103d6840b8df166ea0222fe29471>,
#  <Future: pending, key: run_experiment-0d494756f83198b8ec0292fe37110fbb>,
#  <Future: pending, key: run_experiment-ce1b6c0069e036b71de44a26ddf68182>,
#  <Future: pending, key: run_experiment-e252d9113b32e89c7cca41af6c985f62>,
#  <Future: pending, key: run_experiment-5baacd399329fabb2c49664b0a716bc4>,
#  <Future: pending, key: run_experiment-c119236eb055e680b6d795920b5bc3fb>,
#  <Future: pending, key: run_experiment-1c0ea2724ed6e30418407b26e78e339a>,
#  <Future: pending, key: run_experiment-ff565e4ed4a9b3a725e1b77dfddc7f52>,
#  <Future: pending, key: run_experiment-923224cf8f8e04a03e7bcca96a87d5ed>,
#  <Future: pending, key: run_experiment-571d2ff82632d6941e654e8500b95daf>,
#  <Future: pending, key: run_experiment-9512a77f140e97e75968ec31aecdcaaa>,
#  <Future: pending, key: run_experiment-d3a29d10664c4ad4ec91fe049da22fd2>,
#  <Future: pending, key: run_experiment-91aee7b12cf6e758a9d7148071b3087a>,
#  <Future: pending, key: run_experiment-2430015b2a5ccb873c06c1ac4f38789d>]

# %%
results = client.gather(futures)

# %%
client.close()
cluster.close()
# Out:
# 2025-08-04 18:36:38,584 - distributed.deploy.adaptive_core - INFO - Adaptive stop

# %%
torch.save(f = "cocycles_csuite_mixed_bd_results_n={0}_trials={1}.pt".format(nsamples, seeds), obj = results)

# %%
results
# Out:
# [{'Cocycle_CMMD_V': {'KS_CF': [0.017319999635219574],
#    'KS_int': [0.00980997085571289],
#    'W1_CF': [tensor(0.0362)],
#    'W1_int': [tensor(5.2528)],
#    'RMSE_CF': [0.02856098860502243],
#    'index': 0},
#   'scm': '2var_linear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.01774001121520996],
#    'KS_int': [0.01873999834060669],
#    'W1_CF': [tensor(0.0293)],
#    'W1_int': [tensor(5.9715)],
#    'RMSE_CF': [0.006178176496177912],
#    'index': 0},
#   'scm': '2var_linear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.031049996614456177],
#    'KS_int': [0.031109988689422607],
#    'W1_CF': [tensor(0.0500)],
#    'W1_int': [tensor(23.0024)],
#    'RMSE_CF': [0.022575797513127327],
#    'index': 0},
#   'scm': '2var_linear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.03466999530792236],
#    'KS_int': [0.014109998941421509],
#    'W1_CF': [tensor(0.0564)],
#    'W1_int': [tensor(10.2295)],
#    'RMSE_CF': [0.02167327143251896],
#    'index': 0},
#   'scm': '2var_linear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.03233999013900757],
#    'KS_int': [0.01723998785018921],
#    'W1_CF': [tensor(0.0482)],
#    'W1_int': [tensor(24.0341)],
#    'RMSE_CF': [0.013026750646531582],
#    'index': 0},
#   'scm': '2var_linear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.020220041275024414],
#    'KS_int': [0.026459991931915283],
#    'W1_CF': [tensor(0.0396)],
#    'W1_int': [tensor(8.0667)],
#    'RMSE_CF': [0.06910019367933273],
#    'index': 0},
#   'scm': '2var_linear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.015799999237060547],
#    'KS_int': [0.019979998469352722],
#    'W1_CF': [tensor(0.0210)],
#    'W1_int': [tensor(6.5936)],
#    'RMSE_CF': [0.0035716318525373936],
#    'index': 0},
#   'scm': '2var_linear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.029219985008239746],
#    'KS_int': [0.025829970836639404],
#    'W1_CF': [tensor(0.0438)],
#    'W1_int': [tensor(9.4230)],
#    'RMSE_CF': [0.037465665489435196],
#    'index': 0},
#   'scm': '2var_linear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.02643001079559326],
#    'KS_int': [0.018230020999908447],
#    'W1_CF': [tensor(0.0461)],
#    'W1_int': [tensor(6.7624)],
#    'RMSE_CF': [0.027902968227863312],
#    'index': 0},
#   'scm': '2var_linear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.014160007238388062],
#    'KS_int': [0.022240042686462402],
#    'W1_CF': [tensor(0.0171)],
#    'W1_int': [tensor(8.2968)],
#    'RMSE_CF': [0.013795607723295689],
#    'index': 0},
#   'scm': '2var_linear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.09089004993438721],
#    'KS_int': [0.05415999889373779],
#    'W1_CF': [tensor(0.0801)],
#    'W1_int': [tensor(5.3037)],
#    'RMSE_CF': [0.10746145248413086],
#    'index': 1},
#   'scm': '2var_nonlinear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.06235000491142273],
#    'KS_int': [0.021270036697387695],
#    'W1_CF': [tensor(0.0398)],
#    'W1_int': [tensor(5.9810)],
#    'RMSE_CF': [0.04727650433778763],
#    'index': 1},
#   'scm': '2var_nonlinear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.040229976177215576],
#    'KS_int': [0.016599997878074646],
#    'W1_CF': [tensor(0.0238)],
#    'W1_int': [tensor(22.9908)],
#    'RMSE_CF': [0.05700582265853882],
#    'index': 1},
#   'scm': '2var_nonlinear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.1470000147819519],
#    'KS_int': [0.06047999858856201],
#    'W1_CF': [tensor(0.1283)],
#    'W1_int': [tensor(10.2687)],
#    'RMSE_CF': [0.135428786277771],
#    'index': 1},
#   'scm': '2var_nonlinear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.11199000477790833],
#    'KS_int': [0.02706998586654663],
#    'W1_CF': [tensor(0.0628)],
#    'W1_int': [tensor(24.0378)],
#    'RMSE_CF': [0.11047785729169846],
#    'index': 1},
#   'scm': '2var_nonlinear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.1054999977350235],
#    'KS_int': [0.025189995765686035],
#    'W1_CF': [tensor(0.0615)],
#    'W1_int': [tensor(8.0607)],
#    'RMSE_CF': [0.11754227429628372],
#    'index': 1},
#   'scm': '2var_nonlinear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.08749999850988388],
#    'KS_int': [0.013949990272521973],
#    'W1_CF': [tensor(0.0334)],
#    'W1_int': [tensor(6.5942)],
#    'RMSE_CF': [0.058360155671834946],
#    'index': 1},
#   'scm': '2var_nonlinear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.07210001349449158],
#    'KS_int': [0.034759968519210815],
#    'W1_CF': [tensor(0.0630)],
#    'W1_int': [tensor(9.4477)],
#    'RMSE_CF': [0.08319822698831558],
#    'index': 1},
#   'scm': '2var_nonlinear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.07597000896930695],
#    'KS_int': [0.021970003843307495],
#    'W1_CF': [tensor(0.0412)],
#    'W1_int': [tensor(6.7817)],
#    'RMSE_CF': [0.0967954620718956],
#    'index': 1},
#   'scm': '2var_nonlinear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.06700000166893005],
#    'KS_int': [0.01587998867034912],
#    'W1_CF': [tensor(0.0449)],
#    'W1_int': [tensor(8.2765)],
#    'RMSE_CF': [0.07195588946342468],
#    'index': 1},
#   'scm': '2var_nonlinear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.02649998664855957],
#    'KS_int': [0.05381998419761658],
#    'W1_CF': [tensor(0.3085)],
#    'W1_int': [tensor(5.3325)],
#    'RMSE_CF': [0.23346970975399017],
#    'index': 0},
#   'scm': 'triangle_linear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.04119999706745148],
#    'KS_int': [0.10543003678321838],
#    'W1_CF': [tensor(0.3681)],
#    'W1_int': [tensor(6.3146)],
#    'RMSE_CF': [0.5845545530319214],
#    'index': 0},
#   'scm': 'triangle_linear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.07523998618125916],
#    'KS_int': [0.16961997747421265],
#    'W1_CF': [tensor(0.8153)],
#    'W1_int': [tensor(23.3899)],
#    'RMSE_CF': [0.7451619505882263],
#    'index': 0},
#   'scm': 'triangle_linear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.037849992513656616],
#    'KS_int': [0.038960039615631104],
#    'W1_CF': [tensor(0.3588)],
#    'W1_int': [tensor(10.2786)],
#    'RMSE_CF': [0.1825728714466095],
#    'index': 0},
#   'scm': 'triangle_linear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.03342999517917633],
#    'KS_int': [0.09977999329566956],
#    'W1_CF': [tensor(0.2650)],
#    'W1_int': [tensor(24.2203)],
#    'RMSE_CF': [0.4110555052757263],
#    'index': 0},
#   'scm': 'triangle_linear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.04430001974105835],
#    'KS_int': [0.13033002614974976],
#    'W1_CF': [tensor(0.4521)],
#    'W1_int': [tensor(8.4254)],
#    'RMSE_CF': [0.4882426857948303],
#    'index': 0},
#   'scm': 'triangle_linear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.025339998304843903],
#    'KS_int': [0.057069987058639526],
#    'W1_CF': [tensor(0.1902)],
#    'W1_int': [tensor(6.7510)],
#    'RMSE_CF': [0.24301329255104065],
#    'index': 0},
#   'scm': 'triangle_linear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.027019992470741272],
#    'KS_int': [0.0920799970626831],
#    'W1_CF': [tensor(0.2461)],
#    'W1_int': [tensor(9.6377)],
#    'RMSE_CF': [0.43192243576049805],
#    'index': 0},
#   'scm': 'triangle_linear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.024949967861175537],
#    'KS_int': [0.07846000790596008],
#    'W1_CF': [tensor(0.2508)],
#    'W1_int': [tensor(7.0216)],
#    'RMSE_CF': [0.39817267656326294],
#    'index': 0},
#   'scm': 'triangle_linear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.023270010948181152],
#    'KS_int': [0.05327001214027405],
#    'W1_CF': [tensor(0.2481)],
#    'W1_int': [tensor(8.4201)],
#    'RMSE_CF': [0.18595299124717712],
#    'index': 0},
#   'scm': 'triangle_linear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.3530700206756592],
#    'KS_int': [0.33486002683639526],
#    'W1_CF': [tensor(47.6396)],
#    'W1_int': [tensor(52.4300)],
#    'RMSE_CF': [162.81829833984375],
#    'index': 1},
#   'scm': 'triangle_nonlinear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.4046199917793274],
#    'KS_int': [0.38479000329971313],
#    'W1_CF': [tensor(49.2259)],
#    'W1_int': [tensor(55.5431)],
#    'RMSE_CF': [118.56339263916016],
#    'index': 1},
#   'scm': 'triangle_nonlinear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.30959999561309814],
#    'KS_int': [0.29065001010894775],
#    'W1_CF': [tensor(43.9343)],
#    'W1_int': [tensor(63.5692)],
#    'RMSE_CF': [120.81828308105469],
#    'index': 1},
#   'scm': 'triangle_nonlinear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.2458200454711914],
#    'KS_int': [0.2520100474357605],
#    'W1_CF': [tensor(38.7955)],
#    'W1_int': [tensor(48.4031)],
#    'RMSE_CF': [116.85118865966797],
#    'index': 2},
#   'scm': 'triangle_nonlinear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.36963003873825073],
#    'KS_int': [0.3499799966812134],
#    'W1_CF': [tensor(46.6959)],
#    'W1_int': [tensor(69.8375)],
#    'RMSE_CF': [107.11530303955078],
#    'index': 1},
#   'scm': 'triangle_nonlinear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.23829001188278198],
#    'KS_int': [0.23605000972747803],
#    'W1_CF': [tensor(40.3939)],
#    'W1_int': [tensor(48.3050)],
#    'RMSE_CF': [92.12493133544922],
#    'index': 1},
#   'scm': 'triangle_nonlinear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.33965998888015747],
#    'KS_int': [0.3289799690246582],
#    'W1_CF': [tensor(46.5431)],
#    'W1_int': [tensor(53.0236)],
#    'RMSE_CF': [110.26505279541016],
#    'index': 1},
#   'scm': 'triangle_nonlinear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.4060800075531006],
#    'KS_int': [0.3804299831390381],
#    'W1_CF': [tensor(48.6639)],
#    'W1_int': [tensor(56.3620)],
#    'RMSE_CF': [112.39775848388672],
#    'index': 1},
#   'scm': 'triangle_nonlinear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.13669002056121826],
#    'KS_int': [0.1332399845123291],
#    'W1_CF': [tensor(29.4442)],
#    'W1_int': [tensor(34.4204)],
#    'RMSE_CF': [121.54817199707031],
#    'index': 1},
#   'scm': 'triangle_nonlinear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.2786099910736084],
#    'KS_int': [0.2636899948120117],
#    'W1_CF': [tensor(42.3822)],
#    'W1_int': [tensor(47.3976)],
#    'RMSE_CF': [96.92259216308594],
#    'index': 1},
#   'scm': 'triangle_nonlinear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.014820009469985962],
#    'KS_int': [0.009840011596679688],
#    'W1_CF': [tensor(0.0453)],
#    'W1_int': [tensor(1.3131)],
#    'RMSE_CF': [0.00723487650975585],
#    'index': 0},
#   'scm': 'fork_linear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.024399995803833008],
#    'KS_int': [0.02907000482082367],
#    'W1_CF': [tensor(0.0658)],
#    'W1_int': [tensor(1.4973)],
#    'RMSE_CF': [0.03531857952475548],
#    'index': 0},
#   'scm': 'fork_linear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.02765001356601715],
#    'KS_int': [0.035110000520944595],
#    'W1_CF': [tensor(0.0905)],
#    'W1_int': [tensor(5.7505)],
#    'RMSE_CF': [0.06210632994771004],
#    'index': 0},
#   'scm': 'fork_linear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.031209975481033325],
#    'KS_int': [0.013610005378723145],
#    'W1_CF': [tensor(0.0804)],
#    'W1_int': [tensor(2.5574)],
#    'RMSE_CF': [0.012765973806381226],
#    'index': 0},
#   'scm': 'fork_linear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.027620017528533936],
#    'KS_int': [0.025379985570907593],
#    'W1_CF': [tensor(0.0657)],
#    'W1_int': [tensor(6.0103)],
#    'RMSE_CF': [0.0177006833255291],
#    'index': 0},
#   'scm': 'fork_linear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.01969999074935913],
#    'KS_int': [0.026050031185150146],
#    'W1_CF': [tensor(0.0548)],
#    'W1_int': [tensor(2.0152)],
#    'RMSE_CF': [0.016335345804691315],
#    'index': 0},
#   'scm': 'fork_linear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.01557999849319458],
#    'KS_int': [0.01953999698162079],
#    'W1_CF': [tensor(0.0398)],
#    'W1_int': [tensor(1.6481)],
#    'RMSE_CF': [0.014909758232533932],
#    'index': 0},
#   'scm': 'fork_linear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.02324998378753662],
#    'KS_int': [0.03199999779462814],
#    'W1_CF': [tensor(0.0702)],
#    'W1_int': [tensor(2.3605)],
#    'RMSE_CF': [0.04806989058852196],
#    'index': 0},
#   'scm': 'fork_linear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.021130025386810303],
#    'KS_int': [0.030400000512599945],
#    'W1_CF': [tensor(0.0689)],
#    'W1_int': [tensor(1.6932)],
#    'RMSE_CF': [0.03787891939282417],
#    'index': 0},
#   'scm': 'fork_linear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.027509987354278564],
#    'KS_int': [0.02410000003874302],
#    'W1_CF': [tensor(0.0525)],
#    'W1_int': [tensor(2.0723)],
#    'RMSE_CF': [0.03288739547133446],
#    'index': 0},
#   'scm': 'fork_linear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.0705299973487854],
#    'KS_int': [0.15230000019073486],
#    'W1_CF': [tensor(0.4563)],
#    'W1_int': [tensor(5.7673)],
#    'RMSE_CF': [1.481014370918274],
#    'index': 1},
#   'scm': 'fork_nonlinear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.10900002717971802],
#    'KS_int': [0.164000004529953],
#    'W1_CF': [tensor(0.7986)],
#    'W1_int': [tensor(6.5972)],
#    'RMSE_CF': [1.6965539455413818],
#    'index': 1},
#   'scm': 'fork_nonlinear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.10750001668930054],
#    'KS_int': [0.21654000878334045],
#    'W1_CF': [tensor(0.8646)],
#    'W1_int': [tensor(23.5651)],
#    'RMSE_CF': [0.9663022756576538],
#    'index': 1},
#   'scm': 'fork_nonlinear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.21150000393390656],
#    'KS_int': [0.32287001609802246],
#    'W1_CF': [tensor(1.0153)],
#    'W1_int': [tensor(11.0246)],
#    'RMSE_CF': [1.096954584121704],
#    'index': 1},
#   'scm': 'fork_nonlinear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.11749999970197678],
#    'KS_int': [0.08799000084400177],
#    'W1_CF': [tensor(0.2692)],
#    'W1_int': [tensor(24.1284)],
#    'RMSE_CF': [0.7061309218406677],
#    'index': 1},
#   'scm': 'fork_nonlinear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.11500000208616257],
#    'KS_int': [0.10954999923706055],
#    'W1_CF': [tensor(0.4501)],
#    'W1_int': [tensor(8.2423)],
#    'RMSE_CF': [1.0377353429794312],
#    'index': 1},
#   'scm': 'fork_nonlinear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.09650000184774399],
#    'KS_int': [0.09590999782085419],
#    'W1_CF': [tensor(0.4366)],
#    'W1_int': [tensor(6.7983)],
#    'RMSE_CF': [0.5020654201507568],
#    'index': 1},
#   'scm': 'fork_nonlinear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.17499999701976776],
#    'KS_int': [0.23884999752044678],
#    'W1_CF': [tensor(0.5949)],
#    'W1_int': [tensor(9.9789)],
#    'RMSE_CF': [1.328285813331604],
#    'index': 1},
#   'scm': 'fork_nonlinear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.14749999344348907],
#    'KS_int': [0.21893000602722168],
#    'W1_CF': [tensor(0.8216)],
#    'W1_int': [tensor(7.0428)],
#    'RMSE_CF': [1.2029504776000977],
#    'index': 1},
#   'scm': 'fork_nonlinear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.27300000190734863],
#    'KS_int': [0.312610000371933],
#    'W1_CF': [tensor(1.1023)],
#    'W1_int': [tensor(8.7545)],
#    'RMSE_CF': [1.4020646810531616],
#    'index': 1},
#   'scm': 'fork_nonlinear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.02399003505706787],
#    'KS_int': [0.0184900164604187],
#    'W1_CF': [tensor(0.1001)],
#    'W1_int': [tensor(5.2612)],
#    'RMSE_CF': [0.03737843409180641],
#    'index': 0},
#   'scm': 'chain5_linear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.02665001153945923],
#    'KS_int': [0.08639000356197357],
#    'W1_CF': [tensor(0.1407)],
#    'W1_int': [tensor(6.0985)],
#    'RMSE_CF': [0.2871016263961792],
#    'index': 0},
#   'scm': 'chain5_linear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.028730005025863647],
#    'KS_int': [0.031700000166893005],
#    'W1_CF': [tensor(0.2045)],
#    'W1_int': [tensor(23.0054)],
#    'RMSE_CF': [0.14683789014816284],
#    'index': 0},
#   'scm': 'chain5_linear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.03705999255180359],
#    'KS_int': [0.019380003213882446],
#    'W1_CF': [tensor(0.2055)],
#    'W1_int': [tensor(10.2438)],
#    'RMSE_CF': [0.06399297714233398],
#    'index': 0},
#   'scm': 'chain5_linear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.019870012998580933],
#    'KS_int': [0.05522999167442322],
#    'W1_CF': [tensor(0.1079)],
#    'W1_int': [tensor(24.0782)],
#    'RMSE_CF': [0.13643425703048706],
#    'index': 0},
#   'scm': 'chain5_linear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.029729992151260376],
#    'KS_int': [0.02927999198436737],
#    'W1_CF': [tensor(0.1900)],
#    'W1_int': [tensor(8.0485)],
#    'RMSE_CF': [0.07412274926900864],
#    'index': 0},
#   'scm': 'chain5_linear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.018519997596740723],
#    'KS_int': [0.014800012111663818],
#    'W1_CF': [tensor(0.0884)],
#    'W1_int': [tensor(6.5910)],
#    'RMSE_CF': [0.034843944013118744],
#    'index': 0},
#   'scm': 'chain5_linear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.009130001068115234],
#    'KS_int': [0.02902001142501831],
#    'W1_CF': [tensor(0.0707)],
#    'W1_int': [tensor(9.4297)],
#    'RMSE_CF': [0.016341939568519592],
#    'index': 0},
#   'scm': 'chain5_linear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.024919986724853516],
#    'KS_int': [0.02114000916481018],
#    'W1_CF': [tensor(0.1540)],
#    'W1_int': [tensor(6.7644)],
#    'RMSE_CF': [0.06521162390708923],
#    'index': 0},
#   'scm': 'chain5_linear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.009560048580169678],
#    'KS_int': [0.026489973068237305],
#    'W1_CF': [tensor(0.0463)],
#    'W1_int': [tensor(8.3083)],
#    'RMSE_CF': [0.025047404691576958],
#    'index': 0},
#   'scm': 'chain5_linear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.2785000205039978],
#    'KS_int': [0.10565999150276184],
#    'W1_CF': [tensor(7073.8457)],
#    'W1_int': [tensor(5.8609)],
#    'RMSE_CF': [82.12356567382812],
#    'index': 1},
#   'scm': 'chain5_nonlinear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.31950002908706665],
#    'KS_int': [0.07697001099586487],
#    'W1_CF': [tensor(901.7663)],
#    'W1_int': [tensor(5.9038)],
#    'RMSE_CF': [16.970312118530273],
#    'index': 1},
#   'scm': 'chain5_nonlinear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.31449997425079346],
#    'KS_int': [0.10297000408172607],
#    'W1_CF': [tensor(3.0285)],
#    'W1_int': [tensor(23.8029)],
#    'RMSE_CF': [14.976053237915039],
#    'index': 1},
#   'scm': 'chain5_nonlinear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.2879999876022339],
#    'KS_int': [0.0749099999666214],
#    'W1_CF': [tensor(5.0706)],
#    'W1_int': [tensor(8.7492)],
#    'RMSE_CF': [52.82508850097656],
#    'index': 1},
#   'scm': 'chain5_nonlinear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.3855000138282776],
#    'KS_int': [0.12585999071598053],
#    'W1_CF': [tensor(18.7521)],
#    'W1_int': [tensor(24.1946)],
#    'RMSE_CF': [38.875160217285156],
#    'index': 1},
#   'scm': 'chain5_nonlinear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.31849998235702515],
#    'KS_int': [0.09898000955581665],
#    'W1_CF': [tensor(9.0636)],
#    'W1_int': [tensor(17.2911)],
#    'RMSE_CF': [764.3692016601562],
#    'index': 1},
#   'scm': 'chain5_nonlinear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.3615000247955322],
#    'KS_int': [0.08706000447273254],
#    'W1_CF': [tensor(6.8245)],
#    'W1_int': [tensor(6.7605)],
#    'RMSE_CF': [15.461688995361328],
#    'index': 1},
#   'scm': 'chain5_nonlinear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.3149999976158142],
#    'KS_int': [0.07454001903533936],
#    'W1_CF': [tensor(216.3716)],
#    'W1_int': [tensor(10.9318)],
#    'RMSE_CF': [70.94656372070312],
#    'index': 1},
#   'scm': 'chain5_nonlinear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.3330000042915344],
#    'KS_int': [0.1104000061750412],
#    'W1_CF': [tensor(10.8006)],
#    'W1_int': [tensor(6.9771)],
#    'RMSE_CF': [3.2859156131744385],
#    'index': 1},
#   'scm': 'chain5_nonlinear'},
#  {'Cocycle_CMMD_V': {'KS_CF': [0.14553996920585632],
#    'KS_int': [0.06394999474287033],
#    'W1_CF': [tensor(22.6437)],
#    'W1_int': [tensor(8.6333)],
#    'RMSE_CF': [9.638975143432617],
#    'index': 1},
#   'scm': 'chain5_nonlinear'}]
