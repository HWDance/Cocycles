# %%
# Imports
import pandas as pd
import numpy as np
import doubleml as dml
from doubleml.datasets import fetch_401K

import torch
import os
import time
from functools import partial

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

# Causal_cocycle imports
from causal_cocycle.kernels_new import GaussianKernel
from causal_cocycle.distribution_estimation import ConditionalExpectationRegressor  # :contentReference[oaicite:5]{index=5}
from causal_cocycle.regression_functionals import NWFunctional
from causal_cocycle.loss_factory import CocycleLossFactory
from causal_cocycle.kernels import gaussian_kernel
from causal_cocycle.conditioners_new import RFConditioner,NWConditioner  # NWConditioner defined earlier
from causal_cocycle.transformers_new import KREpsLayer  # Your KR transformer layer
from causal_cocycle.model_new import CocycleModel   # Your CocycleModel class
from e401k_cocycle_config import model_config, opt_config

# %%
# Getting data and names
Data = fetch_401K(return_type='DataFrame')
data = Data.to_numpy()
names = np.array(list(Data[:0]))

# %%
"""
Data processing
"""

# Names
covariates = ['age', 'inc', 'educ', 'fsize', 'marr',
                 'twoearn', 'db', 'pira', 'hown', 'e401']
treatment = ["e401"]
outcome = ["net_tfa"]

# Creating tensors
X = Data[Data.columns.intersection(covariates)]
names_x = np.array(list(X[:0]))
treatment_ind = np.where(names_x == "e401")[0][0]
X = X.to_numpy()
cols_order = ([treatment_ind]+
              list(np.linspace(0,treatment_ind-1,treatment_ind).astype(int))+
              list(np.linspace(treatment_ind+1,len(X.T)-1,len(X.T)-1-treatment_ind).astype(int)))
X = X[:,cols_order]
N = len(X)
D = len(X.T)
Y = Data[Data.columns.intersection(outcome)].to_numpy().reshape(N,)
X,Y = torch.tensor(X),torch.tensor(Y).view(N,1)
print("# treated = ", int(X[:,0].sum()), "/", N)

# Scaling data
scale_X = torch.ones(len(X.T))
for i in range(len(X.T)):
    if len(torch.unique(X[:,i])) > 2:
        scale_X[i] = X[:,i].var(0)**0.5
scale_Y = Y.var(0)**0.5
Xscale,Yscale = X/scale_X, Y/scale_Y

# Random dataset shuffle
id = torch.randperm(Xscale.size(0))
Xscale,Yscale = Xscale[id].double(),Yscale[id].double()

# Train validation split
train_pc = 0.7
ntrain = int(train_pc * N)
Xtr, Ytr = Xscale[:ntrain], Yscale[:ntrain]
Xte, Yte = Xscale[ntrain:], Yscale[ntrain:]

Xscale.mean(0), Yscale.mean()
# Out:
# # treated =  3682 / 9915
# (tensor([0.3714, 3.9693, 1.5016, 1.8622, 4.6991, 0.2710, 0.6048, 0.3808, 0.2422,
#          0.6352], dtype=torch.float64),
#  tensor(0.2842, dtype=torch.float64))

# %%
"""
Conditional CDF estimation
"""

param_grid = {
    'n_estimators': [500],
    'max_depth': [2,10,50,100],
    'min_samples_leaf': [1, 3, 5],
    'max_features': ['sqrt']  # 'auto' is not allowed for RF regressor; 'sqrt' is common
}

rf = RandomForestRegressor(random_state=42)
grid_search = GridSearchCV(rf, param_grid, cv=5,
                           scoring='neg_mean_squared_error',
                           n_jobs=-1)
grid_search.fit(Xtr, Ytr.squeeze(-1))
print("Best hyperparameters from GridSearchCV:")
print(grid_search.best_params_)

best_rf = grid_search.best_estimator_

# Refit on the full training set
best_rf.fit(Xtr, Ytr.squeeze(-1))
# Out:
# Best hyperparameters from GridSearchCV:
# {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'n_estimators': 500}
# RandomForestRegressor(max_depth=10, max_features='sqrt', min_samples_leaf=3,
#                       n_estimators=500, random_state=42)

# %%
"""
KRcocycle construction + loss for CMMD
"""

# Getting sorted data + epsilon
Ysort,ids = torch.sort(Ytr.squeeze().double())
Xsort = Xtr[ids].double()
diff_unique = (Ysort[1:] - Ysort[:-1]).unique()
epsilon = min(1e-6, (diff_unique)[diff_unique!=0].min()/10)
print(epsilon)

# Construct cocycle model
conditioner = RFConditioner(best_rf, Xsort.numpy(), Ysort.numpy())
transformer = KREpsLayer(Ysort, epsilon)
model = CocycleModel(conditioner=conditioner, transformer=transformer)

# Construct loss
kernel_loss = [gaussian_kernel()] * 2
loss_factory = CocycleLossFactory(kernel_loss)
loss = loss_factory.build_loss("CMMD_V", Ytr, Ytr, subsamples=10**4)
# Out:
# 1e-06

# %%
"""
Getting validation loss on test data
"""
def cmmd_embedding_loss_vectorized(model, X, Y, kernel, batchsize=10):
    """
    Fully vectorized CMMD loss with batch processing over i.

    Args:
        model: with .inverse_transformation(X, Y), .transformation(X, Z)
        X: (n, d)
        Y: (n, p)
        kernel: with get_gram(A, B)
        batchsize: outer batch size

    Returns:
        scalar CMMD loss
    """
    import torch, gc, psutil, os

    n = X.shape[0]
    device = X.device
    total_loss = 0.0

    # Step 1: precompute base latent samples Z = f^{-1}_{x_j}(Y_j)
    print("Precomputing inverse-transformed base samples...")
    with torch.no_grad():
        Z_base = model.inverse_transformation(X, Y).detach()  # shape: (n, p)

    for i_start in range(0, n, batchsize):
        i_end = min(i_start + batchsize, n)
        b = i_end - i_start

        X_i = X[i_start:i_end]      # shape: (b, d)
        Y_i = Y[i_start:i_end]      # shape: (b, p)

        # Step 2: expand X_i to match (b x n) for transformation
        X_i_repeat = X_i[:, None, :].repeat(1, n, 1).reshape(b * n, -1)   # (b*n, d)
        Z_repeat = Z_base[None, :, :].repeat(b, 1, 1).reshape(b * n, -1)  # (b*n, p)

        # Step 3: transform → Y_hat[i, j, :] = f_{x_i}(Z_j)
        with torch.no_grad():
            Y_hat = model.transformation(X_i_repeat, Z_repeat).detach().reshape(b, n, -1)  # (b, n, p)

        # Step 4: Compute CMMD loss terms vectorized
        k_yy_diag = torch.diagonal(kernel.get_gram(Y_i, Y_i))  # (b,)
        k_y_hat = torch.stack([
            kernel.get_gram(Y_i[i:i+1], Y_hat[i]).nanmean()
            for i in range(b)
        ])
        k_hat_hat = torch.stack([
            kernel.get_gram(Y_hat[i], Y_hat[i]).nanmean()
            for i in range(b)
        ])

        loss_batch = k_yy_diag + k_hat_hat - 2 * k_y_hat
        total_loss += loss_batch.sum()

        mem_MB = psutil.Process(os.getpid()).memory_info().rss / 1e6
        print(f"[{i_end}/{n}] Memory used (MB): {mem_MB:.2f}")
        gc.collect()
        torch.cuda.empty_cache()

    return total_loss / n


cmmd = cmmd_embedding_loss_vectorized(model,Xte.double(),Yte.double(),loss.kernel[-1])
print("CMMD is ", cmmd)
# Out:
# Precomputing inverse-transformed base samples...
# [90/2975] Memory used (MB): 1042.12
# [100/2975] Memory used (MB): 1036.32
# [110/2975] Memory used (MB): 1036.77
# [120/2975] Memory used (MB): 1036.79
# [130/2975] Memory used (MB): 1043.17
# [140/2975] Memory used (MB): 1035.44
# [150/2975] Memory used (MB): 1040.75
# [160/2975] Memory used (MB): 1040.78
# [170/2975] Memory used (MB): 1039.95
# [180/2975] Memory used (MB): 1039.74
# [190/2975] Memory used (MB): 1040.98
# [200/2975] Memory used (MB): 1039.41
# [210/2975] Memory used (MB): 1037.83
# [220/2975] Memory used (MB): 1040.54
# [230/2975] Memory used (MB): 1036.13
# [240/2975] Memory used (MB): 1037.79
# [250/2975] Memory used (MB): 1037.02
# [260/2975] Memory used (MB): 1038.46
# [270/2975] Memory used (MB): 1033.33
# [280/2975] Memory used (MB): 1041.03
# [290/2975] Memory used (MB): 1039.99
# [300/2975] Memory used (MB): 1042.01
# [310/2975] Memory used (MB): 1040.98
# [320/2975] Memory used (MB): 1038.62
# [330/2975] Memory used (MB): 1038.35
# [340/2975] Memory used (MB): 1039.30
# [350/2975] Memory used (MB): 1043.32
# [370/2975] Memory used (MB): 1040.22
# [380/2975] Memory used (MB): 1037.29
# [390/2975] Memory used (MB): 1040.25
# [400/2975] Memory used (MB): 1040.77
# [410/2975] Memory used (MB): 1041.48
# [420/2975] Memory used (MB): 1034.21
# [430/2975] Memory used (MB): 1038.33
# [440/2975] Memory used (MB): 1039.54
# [450/2975] Memory used (MB): 1035.60
# [460/2975] Memory used (MB): 1038.49
# [470/2975] Memory used (MB): 1035.66
# [480/2975] Memory used (MB): 1037.75
# [490/2975] Memory used (MB): 1040.53
# [500/2975] Memory used (MB): 1033.55
# [510/2975] Memory used (MB): 1037.14
# [520/2975] Memory used (MB): 1037.04
# [530/2975] Memory used (MB): 1038.85
# [540/2975] Memory used (MB): 1041.85
# [550/2975] Memory used (MB): 1032.61
# [560/2975] Memory used (MB): 1041.48
# [570/2975] Memory used (MB): 1038.05
# [580/2975] Memory used (MB): 1038.89
# [590/2975] Memory used (MB): 1040.37
# [600/2975] Memory used (MB): 1038.90
# [610/2975] Memory used (MB): 1038.24
# [620/2975] Memory used (MB): 1038.85
# [630/2975] Memory used (MB): 1040.45
# [640/2975] Memory used (MB): 1040.98
# [650/2975] Memory used (MB): 1039.27
# [660/2975] Memory used (MB): 1041.06
# [670/2975] Memory used (MB): 1042.93
# [680/2975] Memory used (MB): 1040.21
# [690/2975] Memory used (MB): 1038.72
# [700/2975] Memory used (MB): 1044.44
# [710/2975] Memory used (MB): 1042.82
# [720/2975] Memory used (MB): 1042.41
# [730/2975] Memory used (MB): 1041.10
# [740/2975] Memory used (MB): 1040.88
# [750/2975] Memory used (MB): 1041.40
# [760/2975] Memory used (MB): 1043.20
# [770/2975] Memory used (MB): 1040.17
# [780/2975] Memory used (MB): 1039.41
# [790/2975] Memory used (MB): 1043.02
# [800/2975] Memory used (MB): 1040.37
# [810/2975] Memory used (MB): 1043.28
# [820/2975] Memory used (MB): 1042.73
# [830/2975] Memory used (MB): 1044.53
# [840/2975] Memory used (MB): 1042.10
# [850/2975] Memory used (MB): 1042.89
# [860/2975] Memory used (MB): 1040.48
# [870/2975] Memory used (MB): 1039.41
# [880/2975] Memory used (MB): 1037.01
# [890/2975] Memory used (MB): 1042.55
# [900/2975] Memory used (MB): 1039.70
# [910/2975] Memory used (MB): 1039.06
# [920/2975] Memory used (MB): 1042.94
# [930/2975] Memory used (MB): 1040.83
# [940/2975] Memory used (MB): 1042.90
# [950/2975] Memory used (MB): 1043.39
# [960/2975] Memory used (MB): 1042.77
# [970/2975] Memory used (MB): 1038.77
# [980/2975] Memory used (MB): 1039.61
# [990/2975] Memory used (MB): 1040.58
# [1000/2975] Memory used (MB): 1041.54
# [1010/2975] Memory used (MB): 1039.46
# [1020/2975] Memory used (MB): 1036.61
# [1030/2975] Memory used (MB): 1037.86
# [1040/2975] Memory used (MB): 1039.37
# [1050/2975] Memory used (MB): 1040.15
# [1060/2975] Memory used (MB): 1038.26
# [1070/2975] Memory used (MB): 1040.33
# [1080/2975] Memory used (MB): 1039.56
# [1090/2975] Memory used (MB): 1039.10
# [1100/2975] Memory used (MB): 1036.17
# [1110/2975] Memory used (MB): 1040.13
# [1120/2975] Memory used (MB): 1037.44
# [1130/2975] Memory used (MB): 1041.33
# [1140/2975] Memory used (MB): 1044.25
# [1150/2975] Memory used (MB): 1037.72
# [1160/2975] Memory used (MB): 1043.56
# [1170/2975] Memory used (MB): 1038.87
# [1180/2975] Memory used (MB): 1041.07
# [1190/2975] Memory used (MB): 1044.00
# [1200/2975] Memory used (MB): 1040.10
# [1210/2975] Memory used (MB): 1044.55
# [1220/2975] Memory used (MB): 1043.14
# [1230/2975] Memory used (MB): 1042.49
# [1240/2975] Memory used (MB): 1042.74
# [1250/2975] Memory used (MB): 1041.91
# [1260/2975] Memory used (MB): 1044.27
# [1270/2975] Memory used (MB): 1040.78
# [1280/2975] Memory used (MB): 1042.48
# [1290/2975] Memory used (MB): 1045.40
# [1300/2975] Memory used (MB): 1041.01
# [1310/2975] Memory used (MB): 1041.95
# [1320/2975] Memory used (MB): 1039.70
# [1330/2975] Memory used (MB): 1042.67
# [1340/2975] Memory used (MB): 1036.13
# [1350/2975] Memory used (MB): 1041.56
# [1360/2975] Memory used (MB): 1043.18
# [1370/2975] Memory used (MB): 1041.04
# [1380/2975] Memory used (MB): 1045.72
# [1390/2975] Memory used (MB): 1045.03
# [1400/2975] Memory used (MB): 1039.64
# [1410/2975] Memory used (MB): 1036.68
# [1420/2975] Memory used (MB): 1040.08
# [1430/2975] Memory used (MB): 1044.70
# [1440/2975] Memory used (MB): 1041.68
# [1450/2975] Memory used (MB): 1046.22
# [1460/2975] Memory used (MB): 1043.14
# [1470/2975] Memory used (MB): 1040.82
# [1480/2975] Memory used (MB): 1044.92
# [1490/2975] Memory used (MB): 1046.37
# [1500/2975] Memory used (MB): 1039.78
# [1510/2975] Memory used (MB): 1039.59
# [1520/2975] Memory used (MB): 1039.01
# [1530/2975] Memory used (MB): 1041.44
# [1540/2975] Memory used (MB): 1040.32
# [1550/2975] Memory used (MB): 1042.69
# [1560/2975] Memory used (MB): 1044.27
# [1570/2975] Memory used (MB): 1042.19
# [1580/2975] Memory used (MB): 1045.85
# [1590/2975] Memory used (MB): 1038.54
# [1600/2975] Memory used (MB): 1044.36
# [1610/2975] Memory used (MB): 1047.65
# [1620/2975] Memory used (MB): 1045.27
# [1630/2975] Memory used (MB): 1043.86
# [1640/2975] Memory used (MB): 1039.52
# [1650/2975] Memory used (MB): 1038.11
# [1660/2975] Memory used (MB): 1041.78
# [1670/2975] Memory used (MB): 1045.28
# [1680/2975] Memory used (MB): 1040.85
# [1690/2975] Memory used (MB): 1040.86
# [1700/2975] Memory used (MB): 1040.92
# [1710/2975] Memory used (MB): 1036.05
# [1720/2975] Memory used (MB): 1041.70
# [1730/2975] Memory used (MB): 1041.05
# [1740/2975] Memory used (MB): 1040.67
# [1750/2975] Memory used (MB): 1043.91
# [1760/2975] Memory used (MB): 1038.97
# [1770/2975] Memory used (MB): 1042.95
# [1780/2975] Memory used (MB): 1037.22
# [1790/2975] Memory used (MB): 1040.52
# [1800/2975] Memory used (MB): 1041.52
# [1810/2975] Memory used (MB): 1037.32
# [1820/2975] Memory used (MB): 1039.28
# [1830/2975] Memory used (MB): 1041.47
# [1840/2975] Memory used (MB): 1040.48
# [1850/2975] Memory used (MB): 1035.62
# [1860/2975] Memory used (MB): 1040.00
# [1870/2975] Memory used (MB): 1043.36
# [1880/2975] Memory used (MB): 1041.42
# [1890/2975] Memory used (MB): 1040.28
# [1900/2975] Memory used (MB): 1041.24
# [1910/2975] Memory used (MB): 1034.83
# [1920/2975] Memory used (MB): 1044.23
# [1930/2975] Memory used (MB): 1037.83
# [1940/2975] Memory used (MB): 1032.67
# [1950/2975] Memory used (MB): 1042.26
# [1960/2975] Memory used (MB): 1043.81
# [1970/2975] Memory used (MB): 1040.83
# [1980/2975] Memory used (MB): 1041.97
# [1990/2975] Memory used (MB): 1042.24
# [2000/2975] Memory used (MB): 1038.99
# [2010/2975] Memory used (MB): 1042.58
# [2020/2975] Memory used (MB): 1038.04
# [2030/2975] Memory used (MB): 1043.66
# [2040/2975] Memory used (MB): 1041.53
# [2050/2975] Memory used (MB): 1039.84
# [2060/2975] Memory used (MB): 1041.92
# [2070/2975] Memory used (MB): 1042.35
# [2080/2975] Memory used (MB): 1043.27
# [2090/2975] Memory used (MB): 1047.28
# [2100/2975] Memory used (MB): 1043.94
# [2110/2975] Memory used (MB): 1042.75
# [2120/2975] Memory used (MB): 1043.37
# [2130/2975] Memory used (MB): 1044.50
# [2140/2975] Memory used (MB): 1047.61
# [2150/2975] Memory used (MB): 1042.44
# [2160/2975] Memory used (MB): 1041.26
# [2170/2975] Memory used (MB): 1043.22
# [2180/2975] Memory used (MB): 1040.56
# [2190/2975] Memory used (MB): 1038.68
# [2200/2975] Memory used (MB): 1038.92
# [2210/2975] Memory used (MB): 1041.29
# [2220/2975] Memory used (MB): 1042.06
# [2230/2975] Memory used (MB): 1042.97
# [2240/2975] Memory used (MB): 1040.11
# [2250/2975] Memory used (MB): 1045.95
# [2260/2975] Memory used (MB): 1045.95
# [2270/2975] Memory used (MB): 1046.52
# [2280/2975] Memory used (MB): 1041.13
# [2290/2975] Memory used (MB): 1045.71
# [2300/2975] Memory used (MB): 1044.03
# [2310/2975] Memory used (MB): 1047.07
# [2320/2975] Memory used (MB): 1043.10
# [2330/2975] Memory used (MB): 1046.69
# [2340/2975] Memory used (MB): 1045.68
# [2350/2975] Memory used (MB): 1049.67
# [2360/2975] Memory used (MB): 1044.75
# [2370/2975] Memory used (MB): 1045.59
# [2380/2975] Memory used (MB): 1043.57
# [2390/2975] Memory used (MB): 1040.54
# [2400/2975] Memory used (MB): 1046.19
# [2410/2975] Memory used (MB): 1048.43
# [2420/2975] Memory used (MB): 1050.82
# [2430/2975] Memory used (MB): 1042.65
# [2440/2975] Memory used (MB): 1044.79
# [2450/2975] Memory used (MB): 1043.78
# [2460/2975] Memory used (MB): 1047.58
# [2470/2975] Memory used (MB): 1046.20
# [2480/2975] Memory used (MB): 1042.21
# [2490/2975] Memory used (MB): 1041.57
# [2500/2975] Memory used (MB): 1043.12
# [2510/2975] Memory used (MB): 1040.41
# [2520/2975] Memory used (MB): 1047.19
# [2530/2975] Memory used (MB): 1043.05
# [2540/2975] Memory used (MB): 1039.45
# [2550/2975] Memory used (MB): 1045.79
# [2560/2975] Memory used (MB): 1040.40
# [2570/2975] Memory used (MB): 1048.28
# [2580/2975] Memory used (MB): 1039.04
# [2590/2975] Memory used (MB): 1039.00
# [2600/2975] Memory used (MB): 1038.56
# [2610/2975] Memory used (MB): 1042.20
# [2620/2975] Memory used (MB): 1038.24
# [2630/2975] Memory used (MB): 1043.44
# [2640/2975] Memory used (MB): 1045.45
# [2650/2975] Memory used (MB): 1042.61
# [2660/2975] Memory used (MB): 1040.02
# [2670/2975] Memory used (MB): 1044.71
# [2680/2975] Memory used (MB): 1037.97
# [2690/2975] Memory used (MB): 1043.15
# [2700/2975] Memory used (MB): 1043.74
# [2710/2975] Memory used (MB): 1039.87
# [2720/2975] Memory used (MB): 1043.40
# [2730/2975] Memory used (MB): 1041.87
# [2740/2975] Memory used (MB): 1042.54
# [2750/2975] Memory used (MB): 1043.02
# [2760/2975] Memory used (MB): 1039.88
# [2770/2975] Memory used (MB): 1044.30
# [2780/2975] Memory used (MB): 1042.56
# [2790/2975] Memory used (MB): 1046.86
# [2800/2975] Memory used (MB): 1045.00
# [2810/2975] Memory used (MB): 1041.28
# [2820/2975] Memory used (MB): 1045.09
# [2830/2975] Memory used (MB): 1037.09
# [2840/2975] Memory used (MB): 1038.87
# [2850/2975] Memory used (MB): 1040.08
# [2860/2975] Memory used (MB): 1040.11
# [2870/2975] Memory used (MB): 1034.90
# [2880/2975] Memory used (MB): 1038.73
# [2890/2975] Memory used (MB): 1035.27
# [2900/2975] Memory used (MB): 1044.07
# [2910/2975] Memory used (MB): 1038.85
# [2920/2975] Memory used (MB): 1034.04
# [2930/2975] Memory used (MB): 1040.13
# [2940/2975] Memory used (MB): 1036.83
# [2950/2975] Memory used (MB): 1035.62
# [2960/2975] Memory used (MB): 1033.49
# [2970/2975] Memory used (MB): 1038.36
# [2975/2975] Memory used (MB): 1038.39
# CMMD is  tensor(0.4700, dtype=torch.float64)

# %%
cmmd
# Out:
# tensor(0.4700, dtype=torch.float64)

# %%
"""
Fitting final model on full data
"""

# Refit on the full training set
best_rf.fit(Xscale, Yscale.squeeze(-1))

# Getting sorted data + epsilon
Ysort,ids = torch.sort(Yscale.squeeze().double())
Xsort = Xscale[ids].double()
diff_unique = (Ysort[1:] - Ysort[:-1]).unique()
epsilon = min(1e-6, (diff_unique)[diff_unique!=0].min()/10)
print(epsilon)

# Construct cocycle model
conditioner = RFConditioner(best_rf, Xsort.numpy(), Ysort.numpy())
transformer = KREpsLayer(Ysort, epsilon)
model = CocycleModel(conditioner=conditioner, transformer=transformer)
# Out:
# 1e-06

# %%
"""
Getting predictions
"""
X0scale,X1scale = Xscale*1,Xscale*1
X0scale[:,0] = 0
X1scale[:,0] = 1
Y0scale = model.cocycle(X0scale,Xscale,Yscale).detach()
Y1scale = model.cocycle(X1scale,Xscale,Yscale).detach()

ATE = (Y1scale-Y0scale).mean()*scale_Y
ATT = (Y1scale[Xscale[:,0]==1]-Y0scale[Xscale[:,0]==1]).mean()*scale_Y
print("ATE : ", ATE.item())
print("ATT : ", ATT.item())

# %%
print("ATE : ", ATE.item())
print("ATT : ", ATT.item())
# Out:
# ATE :  7796.98193359375
# ATT :  11618.634765625

# %%
"""
Quantile plot
"""
import numpy as np
import matplotlib.pyplot as plt

# Assume Y0scale and Y1scale are 1D numpy arrays of equal length
Y_diff = (Y1scale - Y0scale)

# Step 1: Sort Y0scale and get corresponding sorted Y_diff
V = Xscale[:,2:3]
sort_idx = np.argsort(V.squeeze(-1))
Y_diff_sorted = Y_diff[sort_idx]

# Step 2: Compute quantile positions (from 0 to 1)
quantile_positions = np.linspace(0, 1, N)

# Step 3: Plot
plt.figure(figsize=(10, 6))
l = int(n/20)
plt.scatter(quantile_positions[l:n-l], Y_diff_sorted[l:n-l]*scale_Y, label="$Y_1 - Y_0$", alpha = 0.5)
plt.xlabel("Quantile of Income")
plt.ylabel("Treatment Effect")
plt.grid(True)
plt.tight_layout()
#plt.yscale("log")
plt.ylim(-10000,100000)
plt.legend()
plt.show()

# %%
"""
Quantile plot
"""
import numpy as np
import matplotlib.pyplot as plt

# Assume Y0scale and Y1scale are 1D numpy arrays of equal length
Y_diff = (Y1scale - Y0scale)

# Step 1: Sort Y0scale and get corresponding sorted Y_diff
sort_idx = np.argsort(Y0scale.squeeze(-1))
Y0_sorted = Y0scale[sort_idx]
Y_diff_sorted = Y_diff[sort_idx]

# Step 2: Compute quantile positions (from 0 to 1)
n = len(Y0scale)
quantile_positions = np.linspace(0, 1, n)

# Step 3: Plot
plt.figure(figsize=(10, 6))
l = int(n/20)
plt.scatter(quantile_positions[l:n-l], Y_diff_sorted[l:n-l]*scale_Y, label="$Y_1 - Y_0$", alpha = 0.5)
plt.xlabel("Quantile of NFA")
plt.ylabel("Treatment Effect")
plt.grid(True)
plt.tight_layout()
plt.legend()
plt.show()

# %%
"""
Train NW functional for conditional distribution 
"""
kernel_V = GaussianKernel(lengthscale=torch.ones(1))
functional_V = NWFunctional(kernel=kernel_V, reg=0.0)
CER_V = ConditionalExpectationRegressor(functional_V)
print("Starting hyperparameter optimisation...")
test_points_ = torch.quantile(Y1scale - Y0scale, torch.linspace(0,1,100, dtype = torch.float64))
feature_ = ((Y1scale - Y0scale).unsqueeze(-1)<= test_points_.unsqueeze(0)).float()
losses_V = CER_V.optimise(V.argsort(0).argsort(0)/N, feature_, maxiter=1000, nfold=5, learn_rate=1e-1, print_=True, subsamples = 256)

kernel_Y0 = GaussianKernel(lengthscale=torch.ones(1))
functional_Y0 = NWFunctional(kernel=kernel_Y0, reg=0.0)
CER_Y0 = ConditionalExpectationRegressor(functional_Y0)
print("Starting hyperparameter optimisation...")
test_points_ = torch.quantile(Y1scale - Y0scale, torch.linspace(0,1,100, dtype = torch.float64))
feature_ = ((Y1scale - Y0scale).unsqueeze(-1)<= test_points_.unsqueeze(0)).float()
losses_Y0 = CER_Y0.optimise(Y0scale.unsqueeze(-1).argsort(0).argsort(0)/N, feature_, maxiter=1000, nfold=5, learn_rate=1e-1, print_=True, subsamples = 256)
# Out:
# Starting hyperparameter optimisation...
# [iter 0] avg CV loss: 0.161393
# lengthscale: tensor([0.9048], grad_fn=<ExpBackward0>)
# [iter 10] avg CV loss: 0.148406
# lengthscale: tensor([0.3265], grad_fn=<ExpBackward0>)
# [iter 20] avg CV loss: 0.141695
# lengthscale: tensor([0.1347], grad_fn=<ExpBackward0>)
# [iter 30] avg CV loss: 0.141152
# lengthscale: tensor([0.0894], grad_fn=<ExpBackward0>)
# [iter 40] avg CV loss: 0.141898
# lengthscale: tensor([0.0824], grad_fn=<ExpBackward0>)
# [iter 50] avg CV loss: 0.140893
# lengthscale: tensor([0.0891], grad_fn=<ExpBackward0>)
# [iter 60] avg CV loss: 0.141420
# lengthscale: tensor([0.1004], grad_fn=<ExpBackward0>)
# [iter 70] avg CV loss: 0.140874
# lengthscale: tensor([0.1113], grad_fn=<ExpBackward0>)
# [iter 80] avg CV loss: 0.140862
# lengthscale: tensor([0.1195], grad_fn=<ExpBackward0>)
# [iter 90] avg CV loss: 0.141422
# lengthscale: tensor([0.1221], grad_fn=<ExpBackward0>)
# [iter 100] avg CV loss: 0.140790
# lengthscale: tensor([0.1195], grad_fn=<ExpBackward0>)
# [iter 110] avg CV loss: 0.140945
# lengthscale: tensor([0.1173], grad_fn=<ExpBackward0>)
# [iter 120] avg CV loss: 0.141159
# lengthscale: tensor([0.1146], grad_fn=<ExpBackward0>)
# [iter 130] avg CV loss: 0.141504
# lengthscale: tensor([0.1158], grad_fn=<ExpBackward0>)
# [iter 140] avg CV loss: 0.141289
# lengthscale: tensor([0.1190], grad_fn=<ExpBackward0>)
# [iter 150] avg CV loss: 0.141002
# lengthscale: tensor([0.1177], grad_fn=<ExpBackward0>)
# [iter 160] avg CV loss: 0.140653
# lengthscale: tensor([0.1181], grad_fn=<ExpBackward0>)
# [iter 170] avg CV loss: 0.140936
# lengthscale: tensor([0.1183], grad_fn=<ExpBackward0>)
# [iter 180] avg CV loss: 0.140500
# lengthscale: tensor([0.1183], grad_fn=<ExpBackward0>)
# [iter 190] avg CV loss: 0.141408
# lengthscale: tensor([0.1196], grad_fn=<ExpBackward0>)
# [iter 200] avg CV loss: 0.140621
# lengthscale: tensor([0.1165], grad_fn=<ExpBackward0>)
# [iter 210] avg CV loss: 0.141675
# lengthscale: tensor([0.1189], grad_fn=<ExpBackward0>)
# [iter 220] avg CV loss: 0.141046
# lengthscale: tensor([0.1200], grad_fn=<ExpBackward0>)
# [iter 230] avg CV loss: 0.140603
# lengthscale: tensor([0.1206], grad_fn=<ExpBackward0>)
# [iter 240] avg CV loss: 0.141305
# lengthscale: tensor([0.1171], grad_fn=<ExpBackward0>)
# [iter 250] avg CV loss: 0.140939
# lengthscale: tensor([0.1143], grad_fn=<ExpBackward0>)
# [iter 260] avg CV loss: 0.140330
# lengthscale: tensor([0.1132], grad_fn=<ExpBackward0>)
# [iter 270] avg CV loss: 0.141796
# lengthscale: tensor([0.1164], grad_fn=<ExpBackward0>)
# [iter 280] avg CV loss: 0.141130
# lengthscale: tensor([0.1248], grad_fn=<ExpBackward0>)
# [iter 290] avg CV loss: 0.140957
# lengthscale: tensor([0.1232], grad_fn=<ExpBackward0>)
# [iter 300] avg CV loss: 0.141407
# lengthscale: tensor([0.1118], grad_fn=<ExpBackward0>)
# [iter 310] avg CV loss: 0.141274
# lengthscale: tensor([0.1093], grad_fn=<ExpBackward0>)
# [iter 320] avg CV loss: 0.141626
# lengthscale: tensor([0.1132], grad_fn=<ExpBackward0>)
# [iter 330] avg CV loss: 0.141126
# lengthscale: tensor([0.1172], grad_fn=<ExpBackward0>)
# [iter 340] avg CV loss: 0.141281
# lengthscale: tensor([0.1131], grad_fn=<ExpBackward0>)
# [iter 350] avg CV loss: 0.140701
# lengthscale: tensor([0.1120], grad_fn=<ExpBackward0>)
# [iter 360] avg CV loss: 0.141166
# lengthscale: tensor([0.1102], grad_fn=<ExpBackward0>)
# [iter 370] avg CV loss: 0.141407
# lengthscale: tensor([0.1200], grad_fn=<ExpBackward0>)
# [iter 380] avg CV loss: 0.141630
# lengthscale: tensor([0.1202], grad_fn=<ExpBackward0>)
# [iter 390] avg CV loss: 0.141112
# lengthscale: tensor([0.1176], grad_fn=<ExpBackward0>)
# [iter 400] avg CV loss: 0.141179
# lengthscale: tensor([0.1171], grad_fn=<ExpBackward0>)
# [iter 410] avg CV loss: 0.141593
# lengthscale: tensor([0.1138], grad_fn=<ExpBackward0>)
# [iter 420] avg CV loss: 0.141172
# lengthscale: tensor([0.1099], grad_fn=<ExpBackward0>)
# [iter 430] avg CV loss: 0.140806
# lengthscale: tensor([0.1202], grad_fn=<ExpBackward0>)
# [iter 440] avg CV loss: 0.140820
# lengthscale: tensor([0.1191], grad_fn=<ExpBackward0>)
# [iter 450] avg CV loss: 0.140827
# lengthscale: tensor([0.1208], grad_fn=<ExpBackward0>)
# [iter 460] avg CV loss: 0.141680
# lengthscale: tensor([0.1186], grad_fn=<ExpBackward0>)
# [iter 470] avg CV loss: 0.141416
# lengthscale: tensor([0.1208], grad_fn=<ExpBackward0>)
# [iter 480] avg CV loss: 0.141013
# lengthscale: tensor([0.1184], grad_fn=<ExpBackward0>)
# [iter 490] avg CV loss: 0.141121
# lengthscale: tensor([0.1140], grad_fn=<ExpBackward0>)
# [iter 500] avg CV loss: 0.141072
# lengthscale: tensor([0.1168], grad_fn=<ExpBackward0>)
# [iter 510] avg CV loss: 0.141217
# lengthscale: tensor([0.1253], grad_fn=<ExpBackward0>)
# [iter 520] avg CV loss: 0.140767
# lengthscale: tensor([0.1182], grad_fn=<ExpBackward0>)
# [iter 530] avg CV loss: 0.141746
# lengthscale: tensor([0.1168], grad_fn=<ExpBackward0>)
# [iter 540] avg CV loss: 0.141879
# lengthscale: tensor([0.1133], grad_fn=<ExpBackward0>)
# [iter 550] avg CV loss: 0.140779
# lengthscale: tensor([0.1174], grad_fn=<ExpBackward0>)
# [iter 560] avg CV loss: 0.141293
# lengthscale: tensor([0.1216], grad_fn=<ExpBackward0>)
# [iter 570] avg CV loss: 0.141683
# lengthscale: tensor([0.1243], grad_fn=<ExpBackward0>)
# [iter 580] avg CV loss: 0.140996
# lengthscale: tensor([0.1175], grad_fn=<ExpBackward0>)
# [iter 590] avg CV loss: 0.141721
# lengthscale: tensor([0.1150], grad_fn=<ExpBackward0>)
# [iter 600] avg CV loss: 0.141075
# lengthscale: tensor([0.1218], grad_fn=<ExpBackward0>)
# [iter 610] avg CV loss: 0.140488
# lengthscale: tensor([0.1180], grad_fn=<ExpBackward0>)
# [iter 620] avg CV loss: 0.141498
# lengthscale: tensor([0.1127], grad_fn=<ExpBackward0>)
# [iter 630] avg CV loss: 0.141387
# lengthscale: tensor([0.1165], grad_fn=<ExpBackward0>)
# [iter 640] avg CV loss: 0.141071
# lengthscale: tensor([0.1146], grad_fn=<ExpBackward0>)
# [iter 650] avg CV loss: 0.141615
# lengthscale: tensor([0.1174], grad_fn=<ExpBackward0>)
# [iter 660] avg CV loss: 0.141605
# lengthscale: tensor([0.1145], grad_fn=<ExpBackward0>)
# [iter 670] avg CV loss: 0.140613
# lengthscale: tensor([0.1156], grad_fn=<ExpBackward0>)
# [iter 680] avg CV loss: 0.141740
# lengthscale: tensor([0.1204], grad_fn=<ExpBackward0>)
# [iter 690] avg CV loss: 0.140790
# lengthscale: tensor([0.1174], grad_fn=<ExpBackward0>)
# [iter 700] avg CV loss: 0.141208
# lengthscale: tensor([0.1170], grad_fn=<ExpBackward0>)
# [iter 710] avg CV loss: 0.142186
# lengthscale: tensor([0.1210], grad_fn=<ExpBackward0>)
# [iter 720] avg CV loss: 0.141357
# lengthscale: tensor([0.1219], grad_fn=<ExpBackward0>)
# [iter 730] avg CV loss: 0.141566
# lengthscale: tensor([0.1174], grad_fn=<ExpBackward0>)
# [iter 740] avg CV loss: 0.140817
# lengthscale: tensor([0.1144], grad_fn=<ExpBackward0>)
# [iter 750] avg CV loss: 0.140947
# lengthscale: tensor([0.1234], grad_fn=<ExpBackward0>)
# [iter 760] avg CV loss: 0.141237
# lengthscale: tensor([0.1241], grad_fn=<ExpBackward0>)
# [iter 770] avg CV loss: 0.141354
# lengthscale: tensor([0.1182], grad_fn=<ExpBackward0>)
# [iter 780] avg CV loss: 0.140782
# lengthscale: tensor([0.1203], grad_fn=<ExpBackward0>)
# [iter 790] avg CV loss: 0.140432
# lengthscale: tensor([0.1180], grad_fn=<ExpBackward0>)
# [iter 800] avg CV loss: 0.141219
# lengthscale: tensor([0.1179], grad_fn=<ExpBackward0>)
# [iter 810] avg CV loss: 0.140790
# lengthscale: tensor([0.1185], grad_fn=<ExpBackward0>)
# [iter 820] avg CV loss: 0.141012
# lengthscale: tensor([0.1155], grad_fn=<ExpBackward0>)
# [iter 830] avg CV loss: 0.141373
# lengthscale: tensor([0.1106], grad_fn=<ExpBackward0>)
# [iter 840] avg CV loss: 0.141204
# lengthscale: tensor([0.1202], grad_fn=<ExpBackward0>)
# [iter 850] avg CV loss: 0.140463
# lengthscale: tensor([0.1192], grad_fn=<ExpBackward0>)
# [iter 860] avg CV loss: 0.141334
# lengthscale: tensor([0.1152], grad_fn=<ExpBackward0>)
# [iter 870] avg CV loss: 0.141184
# lengthscale: tensor([0.1128], grad_fn=<ExpBackward0>)
# [iter 880] avg CV loss: 0.141151
# lengthscale: tensor([0.1219], grad_fn=<ExpBackward0>)
# [iter 890] avg CV loss: 0.140711
# lengthscale: tensor([0.1094], grad_fn=<ExpBackward0>)
# [iter 900] avg CV loss: 0.141087
# lengthscale: tensor([0.1117], grad_fn=<ExpBackward0>)
# [iter 910] avg CV loss: 0.140987
# lengthscale: tensor([0.1212], grad_fn=<ExpBackward0>)
# [iter 920] avg CV loss: 0.141682
# lengthscale: tensor([0.1204], grad_fn=<ExpBackward0>)
# [iter 930] avg CV loss: 0.141682
# lengthscale: tensor([0.1199], grad_fn=<ExpBackward0>)
# [iter 940] avg CV loss: 0.141578
# lengthscale: tensor([0.1126], grad_fn=<ExpBackward0>)
# [iter 950] avg CV loss: 0.141508
# lengthscale: tensor([0.1209], grad_fn=<ExpBackward0>)
# [iter 960] avg CV loss: 0.140646
# lengthscale: tensor([0.1276], grad_fn=<ExpBackward0>)
# [iter 970] avg CV loss: 0.141251
# lengthscale: tensor([0.1115], grad_fn=<ExpBackward0>)
# [iter 980] avg CV loss: 0.140731
# lengthscale: tensor([0.1188], grad_fn=<ExpBackward0>)
# [iter 990] avg CV loss: 0.141048
# lengthscale: tensor([0.1303], grad_fn=<ExpBackward0>)
# Starting hyperparameter optimisation...
# [iter 0] avg CV loss: 0.156646
# lengthscale: tensor([0.9048], grad_fn=<ExpBackward0>)
# [iter 10] avg CV loss: 0.120883
# lengthscale: tensor([0.3265], grad_fn=<ExpBackward0>)
# [iter 20] avg CV loss: 0.093428
# lengthscale: tensor([0.1249], grad_fn=<ExpBackward0>)
# [iter 30] avg CV loss: 0.089433
# lengthscale: tensor([0.0674], grad_fn=<ExpBackward0>)
# [iter 40] avg CV loss: 0.088065
# lengthscale: tensor([0.0477], grad_fn=<ExpBackward0>)
# [iter 50] avg CV loss: 0.087847
# lengthscale: tensor([0.0398], grad_fn=<ExpBackward0>)
# [iter 60] avg CV loss: 0.087018
# lengthscale: tensor([0.0367], grad_fn=<ExpBackward0>)
# [iter 70] avg CV loss: 0.088138
# lengthscale: tensor([0.0359], grad_fn=<ExpBackward0>)
# [iter 80] avg CV loss: 0.086980
# lengthscale: tensor([0.0358], grad_fn=<ExpBackward0>)
# [iter 90] avg CV loss: 0.087440
# lengthscale: tensor([0.0359], grad_fn=<ExpBackward0>)
# [iter 100] avg CV loss: 0.086523
# lengthscale: tensor([0.0360], grad_fn=<ExpBackward0>)
# [iter 110] avg CV loss: 0.088033
# lengthscale: tensor([0.0364], grad_fn=<ExpBackward0>)
# [iter 120] avg CV loss: 0.087510
# lengthscale: tensor([0.0366], grad_fn=<ExpBackward0>)
# [iter 130] avg CV loss: 0.087589
# lengthscale: tensor([0.0363], grad_fn=<ExpBackward0>)
# [iter 140] avg CV loss: 0.089124
# lengthscale: tensor([0.0363], grad_fn=<ExpBackward0>)
# [iter 150] avg CV loss: 0.087012
# lengthscale: tensor([0.0368], grad_fn=<ExpBackward0>)
# [iter 160] avg CV loss: 0.087565
# lengthscale: tensor([0.0371], grad_fn=<ExpBackward0>)
# [iter 170] avg CV loss: 0.087877
# lengthscale: tensor([0.0372], grad_fn=<ExpBackward0>)
# [iter 180] avg CV loss: 0.088129
# lengthscale: tensor([0.0372], grad_fn=<ExpBackward0>)
# [iter 190] avg CV loss: 0.087152
# lengthscale: tensor([0.0370], grad_fn=<ExpBackward0>)
# [iter 200] avg CV loss: 0.087817
# lengthscale: tensor([0.0369], grad_fn=<ExpBackward0>)
# [iter 210] avg CV loss: 0.087622
# lengthscale: tensor([0.0369], grad_fn=<ExpBackward0>)
# [iter 220] avg CV loss: 0.088377
# lengthscale: tensor([0.0366], grad_fn=<ExpBackward0>)
# [iter 230] avg CV loss: 0.088047
# lengthscale: tensor([0.0368], grad_fn=<ExpBackward0>)
# [iter 240] avg CV loss: 0.087742
# lengthscale: tensor([0.0368], grad_fn=<ExpBackward0>)
# [iter 250] avg CV loss: 0.088047
# lengthscale: tensor([0.0368], grad_fn=<ExpBackward0>)
# [iter 260] avg CV loss: 0.088052
# lengthscale: tensor([0.0366], grad_fn=<ExpBackward0>)
# [iter 270] avg CV loss: 0.088017
# lengthscale: tensor([0.0367], grad_fn=<ExpBackward0>)
# [iter 280] avg CV loss: 0.088018
# lengthscale: tensor([0.0369], grad_fn=<ExpBackward0>)
# [iter 290] avg CV loss: 0.087602
# lengthscale: tensor([0.0371], grad_fn=<ExpBackward0>)
# [iter 300] avg CV loss: 0.087582
# lengthscale: tensor([0.0371], grad_fn=<ExpBackward0>)
# [iter 310] avg CV loss: 0.087793
# lengthscale: tensor([0.0372], grad_fn=<ExpBackward0>)
# [iter 320] avg CV loss: 0.087701
# lengthscale: tensor([0.0373], grad_fn=<ExpBackward0>)
# [iter 330] avg CV loss: 0.087547
# lengthscale: tensor([0.0369], grad_fn=<ExpBackward0>)
# [iter 340] avg CV loss: 0.087140
# lengthscale: tensor([0.0365], grad_fn=<ExpBackward0>)
# [iter 350] avg CV loss: 0.089357
# lengthscale: tensor([0.0365], grad_fn=<ExpBackward0>)
# [iter 360] avg CV loss: 0.086998
# lengthscale: tensor([0.0372], grad_fn=<ExpBackward0>)
# [iter 370] avg CV loss: 0.088053
# lengthscale: tensor([0.0382], grad_fn=<ExpBackward0>)
# [iter 380] avg CV loss: 0.087971
# lengthscale: tensor([0.0376], grad_fn=<ExpBackward0>)
# [iter 390] avg CV loss: 0.087130
# lengthscale: tensor([0.0366], grad_fn=<ExpBackward0>)
# [iter 400] avg CV loss: 0.087191
# lengthscale: tensor([0.0363], grad_fn=<ExpBackward0>)
# [iter 410] avg CV loss: 0.087667
# lengthscale: tensor([0.0367], grad_fn=<ExpBackward0>)
# [iter 420] avg CV loss: 0.088072
# lengthscale: tensor([0.0371], grad_fn=<ExpBackward0>)
# [iter 430] avg CV loss: 0.087704
# lengthscale: tensor([0.0379], grad_fn=<ExpBackward0>)
# [iter 440] avg CV loss: 0.087914
# lengthscale: tensor([0.0381], grad_fn=<ExpBackward0>)
# [iter 450] avg CV loss: 0.087460
# lengthscale: tensor([0.0377], grad_fn=<ExpBackward0>)
# [iter 460] avg CV loss: 0.086897
# lengthscale: tensor([0.0367], grad_fn=<ExpBackward0>)
# [iter 470] avg CV loss: 0.087354
# lengthscale: tensor([0.0359], grad_fn=<ExpBackward0>)
# [iter 480] avg CV loss: 0.087457
# lengthscale: tensor([0.0365], grad_fn=<ExpBackward0>)
# [iter 490] avg CV loss: 0.086799
# lengthscale: tensor([0.0375], grad_fn=<ExpBackward0>)
# [iter 500] avg CV loss: 0.087080
# lengthscale: tensor([0.0381], grad_fn=<ExpBackward0>)
# [iter 510] avg CV loss: 0.088938
# lengthscale: tensor([0.0381], grad_fn=<ExpBackward0>)
# [iter 520] avg CV loss: 0.087150
# lengthscale: tensor([0.0378], grad_fn=<ExpBackward0>)
# [iter 530] avg CV loss: 0.088165
# lengthscale: tensor([0.0379], grad_fn=<ExpBackward0>)
# [iter 540] avg CV loss: 0.087915
# lengthscale: tensor([0.0375], grad_fn=<ExpBackward0>)
# [iter 550] avg CV loss: 0.087921
# lengthscale: tensor([0.0366], grad_fn=<ExpBackward0>)
# [iter 560] avg CV loss: 0.086735
# lengthscale: tensor([0.0356], grad_fn=<ExpBackward0>)
# [iter 570] avg CV loss: 0.087767
# lengthscale: tensor([0.0359], grad_fn=<ExpBackward0>)
# [iter 580] avg CV loss: 0.087368
# lengthscale: tensor([0.0374], grad_fn=<ExpBackward0>)
# [iter 590] avg CV loss: 0.087855
# lengthscale: tensor([0.0385], grad_fn=<ExpBackward0>)
# [iter 600] avg CV loss: 0.087109
# lengthscale: tensor([0.0377], grad_fn=<ExpBackward0>)
# [iter 610] avg CV loss: 0.087805
# lengthscale: tensor([0.0369], grad_fn=<ExpBackward0>)
# [iter 620] avg CV loss: 0.087920
# lengthscale: tensor([0.0366], grad_fn=<ExpBackward0>)
# [iter 630] avg CV loss: 0.086716
# lengthscale: tensor([0.0366], grad_fn=<ExpBackward0>)
# [iter 640] avg CV loss: 0.086825
# lengthscale: tensor([0.0371], grad_fn=<ExpBackward0>)
# [iter 650] avg CV loss: 0.087820
# lengthscale: tensor([0.0374], grad_fn=<ExpBackward0>)
# [iter 660] avg CV loss: 0.087659
# lengthscale: tensor([0.0370], grad_fn=<ExpBackward0>)
# [iter 670] avg CV loss: 0.087954
# lengthscale: tensor([0.0366], grad_fn=<ExpBackward0>)
# [iter 680] avg CV loss: 0.087974
# lengthscale: tensor([0.0371], grad_fn=<ExpBackward0>)
# [iter 690] avg CV loss: 0.088253
# lengthscale: tensor([0.0372], grad_fn=<ExpBackward0>)
# [iter 700] avg CV loss: 0.088440
# lengthscale: tensor([0.0370], grad_fn=<ExpBackward0>)
# [iter 710] avg CV loss: 0.087923
# lengthscale: tensor([0.0367], grad_fn=<ExpBackward0>)
# [iter 720] avg CV loss: 0.087435
# lengthscale: tensor([0.0369], grad_fn=<ExpBackward0>)
# [iter 730] avg CV loss: 0.087439
# lengthscale: tensor([0.0366], grad_fn=<ExpBackward0>)
# [iter 740] avg CV loss: 0.087484
# lengthscale: tensor([0.0361], grad_fn=<ExpBackward0>)
# [iter 750] avg CV loss: 0.088289
# lengthscale: tensor([0.0364], grad_fn=<ExpBackward0>)
# [iter 760] avg CV loss: 0.088469
# lengthscale: tensor([0.0369], grad_fn=<ExpBackward0>)
# [iter 770] avg CV loss: 0.088264
# lengthscale: tensor([0.0367], grad_fn=<ExpBackward0>)
# [iter 780] avg CV loss: 0.087866
# lengthscale: tensor([0.0374], grad_fn=<ExpBackward0>)
# [iter 790] avg CV loss: 0.087556
# lengthscale: tensor([0.0369], grad_fn=<ExpBackward0>)
# [iter 800] avg CV loss: 0.088307
# lengthscale: tensor([0.0364], grad_fn=<ExpBackward0>)
# [iter 810] avg CV loss: 0.088061
# lengthscale: tensor([0.0364], grad_fn=<ExpBackward0>)
# [iter 820] avg CV loss: 0.088086
# lengthscale: tensor([0.0368], grad_fn=<ExpBackward0>)
# [iter 830] avg CV loss: 0.087689
# lengthscale: tensor([0.0366], grad_fn=<ExpBackward0>)
# [iter 840] avg CV loss: 0.087519
# lengthscale: tensor([0.0362], grad_fn=<ExpBackward0>)
# [iter 850] avg CV loss: 0.087435
# lengthscale: tensor([0.0354], grad_fn=<ExpBackward0>)
# [iter 860] avg CV loss: 0.087959
# lengthscale: tensor([0.0356], grad_fn=<ExpBackward0>)
# [iter 870] avg CV loss: 0.087661
# lengthscale: tensor([0.0362], grad_fn=<ExpBackward0>)
# [iter 880] avg CV loss: 0.088067
# lengthscale: tensor([0.0371], grad_fn=<ExpBackward0>)
# [iter 890] avg CV loss: 0.088104
# lengthscale: tensor([0.0367], grad_fn=<ExpBackward0>)
# [iter 900] avg CV loss: 0.087905
# lengthscale: tensor([0.0365], grad_fn=<ExpBackward0>)
# [iter 910] avg CV loss: 0.087556
# lengthscale: tensor([0.0374], grad_fn=<ExpBackward0>)
# [iter 920] avg CV loss: 0.087898
# lengthscale: tensor([0.0373], grad_fn=<ExpBackward0>)
# [iter 930] avg CV loss: 0.087326
# lengthscale: tensor([0.0371], grad_fn=<ExpBackward0>)
# [iter 940] avg CV loss: 0.087518
# lengthscale: tensor([0.0366], grad_fn=<ExpBackward0>)
# [iter 950] avg CV loss: 0.087316
# lengthscale: tensor([0.0363], grad_fn=<ExpBackward0>)
# [iter 960] avg CV loss: 0.087370
# lengthscale: tensor([0.0357], grad_fn=<ExpBackward0>)
# [iter 970] avg CV loss: 0.087726
# lengthscale: tensor([0.0355], grad_fn=<ExpBackward0>)
# [iter 980] avg CV loss: 0.087637
# lengthscale: tensor([0.0355], grad_fn=<ExpBackward0>)
# [iter 990] avg CV loss: 0.087507
# lengthscale: tensor([0.0360], grad_fn=<ExpBackward0>)

# %%
""" 
Defining model of conditional distribution + predicting quantiles
"""
ntest = 500
quantiles = torch.tensor([[0.025,0.05,0.25,0.5,0.75,0.95,0.975]]).T
diff_sorted,ids = (Y1scale-Y0scale).squeeze(-1).sort()
Y0sorted = Y0scale[ids]
Vsorted = V[ids]

conditioner_V = NWConditioner(Vsorted.argsort(0).argsort(0).double()/N, kernel_V)
conditioner_Y0 = NWConditioner(Y0sorted.argsort().argsort().unsqueeze(-1).double()/N, kernel_Y0)
transformer_ = KREpsLayer(diff_sorted, epsilon = 0)

Y0test = torch.linspace(0.1,0.9,ntest, dtype = torch.float64).unsqueeze(-1)
Vtest = torch.linspace(0.1,0.9,ntest, dtype = torch.float64).unsqueeze(-1)
weights_V = conditioner_V.forward(Vtest)
weights_Y0 = conditioner_Y0.forward(Y0test)
quantile_preds_V = torch.zeros((len(quantiles),ntest))
quantile_preds_Y0 = torch.zeros((len(quantiles),ntest))
for i in range(ntest):
    quantile_preds_V[:,i] = transformer_.forward(weights_V[i:i+1].repeat(len(quantiles),1), quantiles)
    quantile_preds_Y0[:,i] = transformer_.forward(weights_Y0[i:i+1].repeat(len(quantiles),1), quantiles)

mu_preds_V = functional_V.forward((Y1scale-Y0scale).unsqueeze(-1),V.argsort(0).argsort(0).double()/N, Vtest)
mu_preds_Y0 = functional_Y0.forward((Y1scale-Y0scale).unsqueeze(-1),Y0scale.argsort().argsort().double().unsqueeze(-1)/N, Y0test)

# %%
"""
Plotting Results
"""
import matplotlib.pyplot as plt

# Set up axis labels
x = torch.linspace(0.1, 0.9, ntest, dtype=torch.float64).numpy()
q = quantile_preds_Y0.detach().numpy()  # shape: (n_q, ntest)

# Define quantile levels for shaded regions
quantile_levels = [0.025, 0.05, 0.25, 0.5, 0.75, 0.95, 0.975]
qmap = {level: q[i] for i, level in enumerate(quantile_levels)}

# Create figure with doubled size
plt.figure(figsize=(15, 12))

# Fill between symmetric quantiles
fill_pairs = [(0.025, 0.975), (0.05, 0.95), (0.25, 0.75)]
colors = ['#d0d1e6', '#a6bddb', '#3690c0']  # lighter to darker

for (lo, hi), color in zip(fill_pairs, colors):
    plt.fill_between(x, qmap[lo]*scale_Y.item(), qmap[hi]*scale_Y.item(), alpha=0.4, color=color,
                     label=f'{int((hi - lo)*100+0.1)}% interval')

# Add the median quantile curve
plt.plot(x,qmap[0.5]*scale_Y.item(), color='black', lw=4.0, label='Median', ls="dashed")

# Final formatting
plt.xlabel(r'Quantile of NFA(0)', fontsize=46)
plt.ylabel('Treatment Effect', fontsize=46)
plt.title(r'RF-Cocycle', fontsize=46)
plt.legend(fontsize=36, loc = 'upper left')
plt.grid(True)
plt.xticks(fontsize=40)
plt.yticks(fontsize=40)
plt.tight_layout()
plt.savefig("e401k_krcocycle_rf_NFA.png", bbox_inches = "tight")
plt.show()

"""
Plotting Results
"""
import matplotlib.pyplot as plt

# Set up axis labels
x = torch.linspace(0.1, 0.9, ntest, dtype=torch.float64).numpy()
q = quantile_preds_V.detach().numpy()  # shape: (n_q, ntest)

# Define quantile levels for shaded regions
quantile_levels = [0.025, 0.05, 0.25, 0.5, 0.75, 0.95, 0.975]
qmap = {level: q[i] for i, level in enumerate(quantile_levels)}

# Create figure with doubled size
plt.figure(figsize=(15, 12))

# Fill between symmetric quantiles
fill_pairs = [(0.025, 0.975), (0.05, 0.95), (0.25, 0.75)]
colors = ['#d0d1e6', '#a6bddb', '#3690c0']  # lighter to darker

for (lo, hi), color in zip(fill_pairs, colors):
    plt.fill_between(x, qmap[lo]*scale_Y.item(), qmap[hi]*scale_Y.item(), alpha=0.4, color=color,
                     label=f'{int((hi - lo)*100+0.1)}% interval')

# Add the median quantile curve
plt.plot(x,qmap[0.5]*scale_Y.item(), color='black', lw=4.0, label='Median', ls="dashed")

# Final formatting
plt.xlabel(r'Quantile of Income', fontsize=46)
plt.ylabel('Treatment Effect', fontsize=46)
plt.title(r'RF-Cocycle', fontsize=46)
plt.legend(fontsize=36, loc = 'upper left')
plt.grid(True)
plt.xticks(fontsize=40)
plt.yticks(fontsize=40)
plt.tight_layout()
plt.savefig("e401k_krcocycle_rf_income.png", bbox_inches = "tight")
plt.show()

# %%
import psutil, os
def cmmd_embedding_loss(model, X, Y, kernel, batchsize=10):
    """
    Computes the CMMD loss correctly via kernel trick:
      CMMD = (1/n) * sum_i || psi(Y_i) - (1/n) sum_j psi(T_{X_i,X_j}(Y_j)) ||^2
    without forming psi explicitly.

    Args:
        model: must have .cocycle(X_i, X_j, Y_j)
        X: (n, d)
        Y: (n, p)
        kernel: kernel object with get_gram(Y1, Y2)
        batchsize: number of outer-loop samples (i) to process

    Returns:
        scalar CMMD loss (torch tensor)
    """
    n = X.shape[0]
    device = X.device
    total_loss = 0.0

    for i_start in range(0, n, batchsize):
        i_end = min(i_start + batchsize, n)
        b = i_end - i_start

        # Get batch of X_i and Y_i
        X_i = X[i_start:i_end]       # (b, d)
        Y_i = Y[i_start:i_end]       # (b, p)

        # Repeat X_i n times to match (i, j)
        X_i_repeat = X_i.unsqueeze(1).repeat(1, n, 1).reshape(b * n, -1)  # (b*n, d)
        X_j = X.repeat(b, 1)                                            # (b*n, d)
        Y_j = Y.repeat(b, 1)                                            # (b*n, p)

        # Apply transport: T_{X_i, X_j}(Y_j)
        Y_hat = model.cocycle(X_i_repeat, X_j, Y_j)  # (b*n, p)
        Y_hat = Y_hat.view(b, n, -1)  # (b, n, p)

        # --- Compute CMMD terms via kernel trick ---

        # Term 1: k(Y_i, Y_i)
        K_yy_diag = torch.diagonal(kernel.get_gram(Y_i, Y_i))  # (b,)

        # Term 2: (1/n^2) sum_{j,j'} k(Ŷ_{ij}, Ŷ_{ij'})
        K_hat_hat = torch.stack([
            kernel.get_gram(Y_hat[i], Y_hat[i]).mean()
            for i in range(b)
        ])  # (b,)

        # Term 3: (1/n) sum_j k(Y_i, Ŷ_{ij})
        K_y_hat = torch.stack([
            kernel.get_gram(Y_i[i:i+1], Y_hat[i]).mean()
            for i in range(b)
        ])  # (b,)

        # Combine terms
        loss_batch = K_yy_diag + K_hat_hat - 2 * K_y_hat
        total_loss += loss_batch.sum()

        print(f"Memory used (MB): {psutil.Process(os.getpid()).memory_info().rss / 1e6}")

    return total_loss / n

def cmmd_embedding_loss_optimized(model, X, Y, kernel, batchsize=10):
    """
    Computes CMMD loss:
        CMMD = (1/n) sum_i || ψ(Y_i) - (1/n) sum_j ψ(T_{x_i, x_j}(Y_j)) ||^2

    where T_{x_i, x_j}(Y_j) = f_{x_i} ( f_{x_j}^{-1}(Y_j) )

    Args:
        model: has .inverse_transformation(Y, X), .transformation(Y, X), .conditioner(X)
        X: (n, d)
        Y: (n, p)
        kernel: with .get_gram(A, B)
        batchsize: number of i's per batch

    Returns:
        scalar torch.Tensor
    """
    import gc, psutil, os

    n = X.shape[0]
    device = X.device
    total_loss = 0.0

    # ✅ Precompute base samples: f^{-1}_{x_j}(Y_j)
    print("Precomputing inverse-transformed base samples...")
    with torch.no_grad():
        Z_base = model.inverse_transformation(X, Y).detach()  # (n, p)

    for i_start in range(0, n, batchsize):
        i_end = min(i_start + batchsize, n)
        b = i_end - i_start

        X_i = X[i_start:i_end]     # (b, d)
        Y_i = Y[i_start:i_end]     # (b, p)
        loss_batch = torch.zeros(b, device=device)

        for i in range(b):
            xi = X_i[i:i+1]        # (1, d)
            yi = Y_i[i:i+1]        # (1, p)

            # Compute transported samples: T_{xi, xj}(Y_j) = f_{xi}(Z_base)
            xi_repeat = xi.repeat(n, 1)  # (n, d)
            with torch.no_grad():
                Y_hat = model.transformation(xi_repeat,Z_base).detach().unsqueeze(-1)  # (n, p)
            # Compute kernel terms
            k_yy = kernel.get_gram(yi, yi).item()
            k_hat_hat = kernel.get_gram(Y_hat, Y_hat).nanmean().item()
            k_y_hat = kernel.get_gram(yi, Y_hat).nanmean().item()

            loss_i = k_yy + k_hat_hat - 2 * k_y_hat
            loss_batch[i] = loss_i

        total_loss += loss_batch.sum()

        mem_MB = psutil.Process(os.getpid()).memory_info().rss / 1e6
        print(f"[{i_end}/{n}] Memory used (MB): {mem_MB:.2f}")
        gc.collect()
        torch.cuda.empty_cache()

    return total_loss / n

def cmmd_embedding_loss_vectorized(model, X, Y, kernel, batchsize=10):
    """
    Fully vectorized CMMD loss with batch processing over i.

    Args:
        model: with .inverse_transformation(X, Y), .transformation(X, Z)
        X: (n, d)
        Y: (n, p)
        kernel: with get_gram(A, B)
        batchsize: outer batch size

    Returns:
        scalar CMMD loss
    """
    import torch, gc, psutil, os

    n = X.shape[0]
    device = X.device
    total_loss = 0.0

    # Step 1: precompute base latent samples Z = f^{-1}_{x_j}(Y_j)
    print("Precomputing inverse-transformed base samples...")
    with torch.no_grad():
        Z_base = model.inverse_transformation(X, Y).detach()  # shape: (n, p)

    for i_start in range(0, n, batchsize):
        i_end = min(i_start + batchsize, n)
        b = i_end - i_start

        X_i = X[i_start:i_end]      # shape: (b, d)
        Y_i = Y[i_start:i_end]      # shape: (b, p)

        # Step 2: expand X_i to match (b x n) for transformation
        X_i_repeat = X_i[:, None, :].repeat(1, n, 1).reshape(b * n, -1)   # (b*n, d)
        Z_repeat = Z_base[None, :, :].repeat(b, 1, 1).reshape(b * n, -1)  # (b*n, p)

        # Step 3: transform → Y_hat[i, j, :] = f_{x_i}(Z_j)
        with torch.no_grad():
            Y_hat = model.transformation(X_i_repeat, Z_repeat).detach().reshape(b, n, -1)  # (b, n, p)

        # Step 4: Compute CMMD loss terms vectorized
        k_yy_diag = torch.diagonal(kernel.get_gram(Y_i, Y_i))  # (b,)
        k_y_hat = torch.stack([
            kernel.get_gram(Y_i[i:i+1], Y_hat[i]).nanmean()
            for i in range(b)
        ])
        k_hat_hat = torch.stack([
            kernel.get_gram(Y_hat[i], Y_hat[i]).nanmean()
            for i in range(b)
        ])

        loss_batch = k_yy_diag + k_hat_hat - 2 * k_y_hat
        total_loss += loss_batch.sum()

        mem_MB = psutil.Process(os.getpid()).memory_info().rss / 1e6
        print(f"[{i_end}/{n}] Memory used (MB): {mem_MB:.2f}")
        gc.collect()
        torch.cuda.empty_cache()

    return total_loss / n
