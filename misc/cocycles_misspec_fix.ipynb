# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
import matplotlib.pyplot as plt
from zuko.flows.autoregressive import MaskedAutoregressiveTransform
from zuko.transforms import (
    MonotonicAffineTransform,
)
from zuko.flows import UnconditionalDistribution
from torch.distributions import Cauchy, Normal, Laplace, Bernoulli, Uniform
import copy
from causal_cocycle.model_new import ZukoCocycleModel
from causal_cocycle.optimise_new import optimise
from causal_cocycle.loss import CocycleLoss
from causal_cocycle.loss_factory import CocycleLossFactory
from causal_cocycle.kernels import gaussian_kernel
from scipy.stats import betaprime, norm
import numpy as np

class IdentityTransform(nn.Module):
    """
    A no-op bijector: forward(y) = (y, 0); inverse(u) = (u, 0).
    """

    def __init__(self):
        super().__init__()

    def forward(self, y: torch.Tensor):
        batch = y.shape[0]
        return y

    def inverse(self, u: torch.Tensor):
        batch = u.shape[0]
        return u
        
class DiscreteSelectorTransform(nn.Module):
    """
    Wraps K unconditional bijector "factories" (MaskedAutoregressiveTransform or IdentityTransform).
    Calling DiscreteSelectorTransform(x) returns a SelectedBijector. Then:
       - SelectedBijector.inv(u)  dispatches to flows[k].inverse(...)
       - SelectedBijector.forward(y) dispatches to flows[k].forward(...)
    For MaskedAutoregressiveTransform, we pass a dummy zero‐dim context tensor of shape (n_k, 0).
    """

    def __init__(self, flows: nn.ModuleList):
        """
        Args:
          flows: ModuleList of length K, each either:
                 • IdentityTransform()  (nn.Module), or
                 • MaskedAutoregressiveTransform(context=0, …)
        """
        super().__init__()
        self.flows = nn.ModuleList(flows)
        self.K = len(flows)

    def __call__(self, x: torch.Tensor):
        """
        Returns a SelectedBijector for the batch of labels x.
        Args:
          x: Tensor of shape (batch, 1) or (batch,), integer labels in {0,…,K-1}.
        """
        return DiscreteSelectorTransform.SelectedBijector(self, x)

# In architectures.py (only the SelectedBijector inner class shown)

    class SelectedBijector:
        def __init__(self, parent: "DiscreteSelectorTransform", x: torch.Tensor):
            self.parent = parent
            self.x_flat = x.view(-1).long()  # shape: (batch,)

        def inv(self, u: torch.Tensor) -> torch.Tensor:
            """
            Latent → data. For each i with label k, apply flows[k].inverse(u[i]).
            """
            batch, y_dim = u.shape
            y_out = torch.zeros_like(u)

            for k in range(self.parent.K):
                mask = (self.x_flat == k)
                if not mask.any():
                    continue
                u_k = u[mask]  # (n_k, y_dim)
                flow_k = self.parent.flows[k]

                if isinstance(flow_k, IdentityTransform):
                    y_k = flow_k.inverse(u_k)
                else:
                    # MaskedAutoregressiveTransform(context=0) → AutoregressiveTransform
                    ctx = u_k.new_empty((u_k.shape[0], 0))
                    bij = flow_k(None)            # AutoregressiveTransform
                    # Use bij.inverse(...) to invert latents → data
                    y_k = bij.inv(u_k)       # returns a single Tensor

                y_out[mask] = y_k

            return y_out

        def forward(self, y: torch.Tensor) -> torch.Tensor:
            """
            Data → latent. For each i with label k, apply flows[k].forward(y[i]).
            """
            batch, y_dim = y.shape
            u_out = torch.zeros_like(y)

            for k in range(self.parent.K):
                mask = (self.x_flat == k)
                if not mask.any():
                    continue
                y_k = y[mask]  # (n_k, y_dim)
                flow_k = self.parent.flows[k]

                if isinstance(flow_k, IdentityTransform):
                    u_k= flow_k.forward(y_k)
                else:
                    # MaskedAutoregressiveTransform(context=0) → AutoregressiveTransform
                    ctx = y_k.new_empty((y_k.shape[0], 0))
                    bij = flow_k(None)         # AutoregressiveTransform
                    # Use __call__ (i.e. bij(y_k)) to map data → latent
                    u_k = bij(y_k)            # returns a single Tensor

                u_out[mask] = u_k

            return u_out

        def __call__(self, tensor: torch.Tensor) -> torch.Tensor:
            """
            Alias so that `transform(u)` invokes `forward(u)`.
            """
            return self.forward(tensor)

def draw_abs_nbp(size):
    """
    |NBP(0.1,0.1)|  where  NB P  is  Normal–Beta-Prime:
      τ   ~ BetaPrime(0.1, 0.1)
      V|τ ~ N(0, τ)
      return |V|
    """
    τ   = betaprime.rvs(0.1, 0.1, size=size)
    v   = norm.rvs(scale=np.sqrt(τ))
    return np.abs(v)

class MixedTails:

    def __init__(self,):
        return

    def sample(self, size):
        b = Bernoulli(1/2).sample(size)
        u1 = Normal(0,1).sample(size).abs()
        u2 = torch.tensor(draw_abs_nbp(size))
        return u1*b - u2*(1-b)
    

# ── Data ─────────────────────────────────────────────────────
seed = 0
torch.manual_seed(seed)
N_train = 2000
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
U = MixedTails().sample((N_train,1)).to(device)
X = torch.cat([torch.ones(N_train //2),torch.zeros(N_train //2)])[:,None]
Y = (X+1)*U
# ── Build loss and transforms ───────────────────────────────
d = 1   # dim(Y)

maf = MaskedAutoregressiveTransform(
        features=1,
        context=0,
        hidden_features=(),
        univariate=MonotonicAffineTransform,
        shapes=[(), ()],
    )
flow0 = IdentityTransform()
flow1 = maf
transform = DiscreteSelectorTransform(nn.ModuleList([flow0, flow1]))
model = ZukoCocycleModel(transforms=torch.nn.ModuleList([transform]))

kernel = [gaussian_kernel(), gaussian_kernel()]
loss_factory = CocycleLossFactory(kernel)
loss = loss_factory.build_loss("CMMD_V", X, Y)

# %%
# Example hyperparameters—feel free to adjust as desired:
learn_rate       = 1e-2
epochs           = 500
weight_decay     = 0.0
batch_size       = 128
val_batch_size   = 256
scheduler        = False
schedule_milestone = 10
lr_mult          = 0.90
print_           = True
plot             = False
likelihood_param_opt = False
likelihood_param_lr  = 0.01

# Finally, run training. We supply both train and val sets so optimise can compute validation loss each epoch:
best_model, history = optimise(
    model            = model,
    loss_tr          = loss,
    inputs           = X,
    outputs          = Y,
    inputs_val       = None,
    outputs_val      = None,
    learn_rate       = learn_rate,
    epochs           = epochs,
    weight_decay     = weight_decay,
    batch_size       = batch_size,
    val_batch_size   = val_batch_size,
    scheduler        = scheduler,
    schedule_milestone = schedule_milestone,
    lr_mult          = lr_mult,
    print_           = print_,
    plot             = plot,
    likelihood_param_opt = likelihood_param_opt,
    likelihood_param_lr  = likelihood_param_lr,
    loss_val         = None  # no separate “loss_val” function needed, since CMMD-V is symmetric
)
# Out:
# Epoch 1/500, Training Loss: -0.4273
# Epoch 2/500, Training Loss: -0.4150
# Epoch 3/500, Training Loss: -0.4512
# Epoch 4/500, Training Loss: -0.4419
# Epoch 5/500, Training Loss: -0.4469
# Epoch 6/500, Training Loss: -0.4337
# Epoch 7/500, Training Loss: -0.4333
# Epoch 8/500, Training Loss: -0.4298
# Epoch 9/500, Training Loss: -0.4557
# Epoch 10/500, Training Loss: -0.4597
# Epoch 11/500, Training Loss: -0.4499
# Epoch 12/500, Training Loss: -0.4350
# Epoch 13/500, Training Loss: -0.4487
# Epoch 14/500, Training Loss: -0.4460
# Epoch 15/500, Training Loss: -0.4367
# Epoch 16/500, Training Loss: -0.4487
# Epoch 17/500, Training Loss: -0.4536
# Epoch 18/500, Training Loss: -0.4579
# Epoch 19/500, Training Loss: -0.4521
# Epoch 20/500, Training Loss: -0.4491
# Epoch 21/500, Training Loss: -0.4545
# Epoch 22/500, Training Loss: -0.4621
# Epoch 23/500, Training Loss: -0.4718
# Epoch 24/500, Training Loss: -0.4536
# Epoch 25/500, Training Loss: -0.4567
# Epoch 26/500, Training Loss: -0.4495
# Epoch 27/500, Training Loss: -0.4566
# Epoch 28/500, Training Loss: -0.4607
# Epoch 29/500, Training Loss: -0.4559
# Epoch 30/500, Training Loss: -0.4534
# Epoch 31/500, Training Loss: -0.4352
# Epoch 32/500, Training Loss: -0.4451
# Epoch 33/500, Training Loss: -0.4486
# Epoch 34/500, Training Loss: -0.4685
# Epoch 35/500, Training Loss: -0.4267
# Epoch 36/500, Training Loss: -0.4491
# Epoch 37/500, Training Loss: -0.4531
# Epoch 38/500, Training Loss: -0.4455
# Epoch 39/500, Training Loss: -0.4630
# Epoch 40/500, Training Loss: -0.4531
# Epoch 41/500, Training Loss: -0.4473
# Epoch 42/500, Training Loss: -0.4835
# Epoch 43/500, Training Loss: -0.4329
# Epoch 44/500, Training Loss: -0.4322
# Epoch 45/500, Training Loss: -0.4425
# Epoch 46/500, Training Loss: -0.4531
# Epoch 47/500, Training Loss: -0.4246
# Epoch 48/500, Training Loss: -0.4451
# Epoch 49/500, Training Loss: -0.4275
# Epoch 50/500, Training Loss: -0.4355
# Epoch 51/500, Training Loss: -0.4484
# Epoch 52/500, Training Loss: -0.4491
# Epoch 53/500, Training Loss: -0.4650
# Epoch 54/500, Training Loss: -0.4520
# Epoch 55/500, Training Loss: -0.4512
# Epoch 56/500, Training Loss: -0.4303
# Epoch 57/500, Training Loss: -0.4446
# Epoch 58/500, Training Loss: -0.4532
# Epoch 59/500, Training Loss: -0.4571
# Epoch 60/500, Training Loss: -0.4546
# Epoch 61/500, Training Loss: -0.4421
# Epoch 62/500, Training Loss: -0.4322
# Epoch 63/500, Training Loss: -0.4448
# Epoch 64/500, Training Loss: -0.4527
# Epoch 65/500, Training Loss: -0.4524
# Epoch 66/500, Training Loss: -0.4540
# Epoch 67/500, Training Loss: -0.4442
# Epoch 68/500, Training Loss: -0.4567
# Epoch 69/500, Training Loss: -0.4429
# Epoch 70/500, Training Loss: -0.4374
# Epoch 71/500, Training Loss: -0.4554
# Epoch 72/500, Training Loss: -0.4436
# Epoch 73/500, Training Loss: -0.4483
# Epoch 74/500, Training Loss: -0.4528
# Epoch 75/500, Training Loss: -0.4541
# Epoch 76/500, Training Loss: -0.4406
# Epoch 77/500, Training Loss: -0.4690
# Epoch 78/500, Training Loss: -0.4460
# Epoch 79/500, Training Loss: -0.4604
# Epoch 80/500, Training Loss: -0.4528
# Epoch 81/500, Training Loss: -0.4439
# Epoch 82/500, Training Loss: -0.4486
# Epoch 83/500, Training Loss: -0.4305
# Epoch 84/500, Training Loss: -0.4598
# Epoch 85/500, Training Loss: -0.4419
# Epoch 86/500, Training Loss: -0.4302
# Epoch 87/500, Training Loss: -0.4406
# Epoch 88/500, Training Loss: -0.4261
# Epoch 89/500, Training Loss: -0.4521
# Epoch 90/500, Training Loss: -0.4445
# Epoch 91/500, Training Loss: -0.4562
# Epoch 92/500, Training Loss: -0.4183
# Epoch 93/500, Training Loss: -0.4206
# Epoch 94/500, Training Loss: -0.4353
# Epoch 95/500, Training Loss: -0.4452
# Epoch 96/500, Training Loss: -0.4420
# Epoch 97/500, Training Loss: -0.4546
# Epoch 98/500, Training Loss: -0.4715
# Epoch 99/500, Training Loss: -0.4533
# Epoch 100/500, Training Loss: -0.4572
# Epoch 101/500, Training Loss: -0.4410
# Epoch 102/500, Training Loss: -0.4519
# Epoch 103/500, Training Loss: -0.4416
# Epoch 104/500, Training Loss: -0.4350
# Epoch 105/500, Training Loss: -0.4523
# Epoch 106/500, Training Loss: -0.4540
# Epoch 107/500, Training Loss: -0.4528
# Epoch 108/500, Training Loss: -0.4515
# Epoch 109/500, Training Loss: -0.4436
# Epoch 110/500, Training Loss: -0.4448
# Epoch 111/500, Training Loss: -0.4529
# Epoch 112/500, Training Loss: -0.4490
# Epoch 113/500, Training Loss: -0.4513
# Epoch 114/500, Training Loss: -0.4790
# Epoch 115/500, Training Loss: -0.4559
# Epoch 116/500, Training Loss: -0.4615
# Epoch 117/500, Training Loss: -0.4432
# Epoch 118/500, Training Loss: -0.4534
# Epoch 119/500, Training Loss: -0.4567
# Epoch 120/500, Training Loss: -0.4660
# Epoch 121/500, Training Loss: -0.4557
# Epoch 122/500, Training Loss: -0.4618
# Epoch 123/500, Training Loss: -0.4620
# Epoch 124/500, Training Loss: -0.4502
# Epoch 125/500, Training Loss: -0.4625
# Epoch 126/500, Training Loss: -0.4480
# Epoch 127/500, Training Loss: -0.4518
# Epoch 128/500, Training Loss: -0.4521
# Epoch 129/500, Training Loss: -0.4453
# Epoch 130/500, Training Loss: -0.4541
# Epoch 131/500, Training Loss: -0.4368
# Epoch 132/500, Training Loss: -0.4402
# Epoch 133/500, Training Loss: -0.4490
# Epoch 134/500, Training Loss: -0.4470
# Epoch 135/500, Training Loss: -0.4506
# Epoch 136/500, Training Loss: -0.4326
# Epoch 137/500, Training Loss: -0.4418
# Epoch 138/500, Training Loss: -0.4403
# Epoch 139/500, Training Loss: -0.4563
# Epoch 140/500, Training Loss: -0.4580
# Epoch 141/500, Training Loss: -0.4464
# Epoch 142/500, Training Loss: -0.4605
# Epoch 143/500, Training Loss: -0.4379
# Epoch 144/500, Training Loss: -0.4566
# Epoch 145/500, Training Loss: -0.4454
# Epoch 146/500, Training Loss: -0.4461
# Epoch 147/500, Training Loss: -0.4466
# Epoch 148/500, Training Loss: -0.4550
# Epoch 149/500, Training Loss: -0.4591
# Epoch 150/500, Training Loss: -0.4557
# Epoch 151/500, Training Loss: -0.4484
# Epoch 152/500, Training Loss: -0.4656
# Epoch 153/500, Training Loss: -0.4327
# Epoch 154/500, Training Loss: -0.4430
# Epoch 155/500, Training Loss: -0.4411
# Epoch 156/500, Training Loss: -0.4537
# Epoch 157/500, Training Loss: -0.4451
# Epoch 158/500, Training Loss: -0.4510
# Epoch 159/500, Training Loss: -0.4405
# Epoch 160/500, Training Loss: -0.4176
# Epoch 161/500, Training Loss: -0.4518
# Epoch 162/500, Training Loss: -0.4537
# Epoch 163/500, Training Loss: -0.4725
# Epoch 164/500, Training Loss: -0.4584
# Epoch 165/500, Training Loss: -0.4440
# Epoch 166/500, Training Loss: -0.4523
# Epoch 167/500, Training Loss: -0.4296
# Epoch 168/500, Training Loss: -0.4367
# Epoch 169/500, Training Loss: -0.4508
# Epoch 170/500, Training Loss: -0.4457
# Epoch 171/500, Training Loss: -0.4789
# Epoch 172/500, Training Loss: -0.4457
# Epoch 173/500, Training Loss: -0.4575
# Epoch 174/500, Training Loss: -0.4290
# Epoch 175/500, Training Loss: -0.4512
# Epoch 176/500, Training Loss: -0.4368
# Epoch 177/500, Training Loss: -0.4735
# Epoch 178/500, Training Loss: -0.4535
# Epoch 179/500, Training Loss: -0.4446
# Epoch 180/500, Training Loss: -0.4404
# Epoch 181/500, Training Loss: -0.4427
# Epoch 182/500, Training Loss: -0.4510
# Epoch 183/500, Training Loss: -0.4347
# Epoch 184/500, Training Loss: -0.4622
# Epoch 185/500, Training Loss: -0.4622
# Epoch 186/500, Training Loss: -0.4459
# Epoch 187/500, Training Loss: -0.4513
# Epoch 188/500, Training Loss: -0.4430
# Epoch 189/500, Training Loss: -0.4458
# Epoch 190/500, Training Loss: -0.4433
# Epoch 191/500, Training Loss: -0.4331
# Epoch 192/500, Training Loss: -0.4608
# Epoch 193/500, Training Loss: -0.4517
# Epoch 194/500, Training Loss: -0.4527
# Epoch 195/500, Training Loss: -0.4553
# Epoch 196/500, Training Loss: -0.4537
# Epoch 197/500, Training Loss: -0.4515
# Epoch 198/500, Training Loss: -0.4578
# Epoch 199/500, Training Loss: -0.4294
# Epoch 200/500, Training Loss: -0.4647
# Epoch 201/500, Training Loss: -0.4406
# Epoch 202/500, Training Loss: -0.4311
# Epoch 203/500, Training Loss: -0.4296
# Epoch 204/500, Training Loss: -0.4495
# Epoch 205/500, Training Loss: -0.4591
# Epoch 206/500, Training Loss: -0.4596
# Epoch 207/500, Training Loss: -0.4245
# Epoch 208/500, Training Loss: -0.4500
# Epoch 209/500, Training Loss: -0.4383
# Epoch 210/500, Training Loss: -0.4525
# Epoch 211/500, Training Loss: -0.4498
# Epoch 212/500, Training Loss: -0.4273
# Epoch 213/500, Training Loss: -0.4604
# Epoch 214/500, Training Loss: -0.4846
# Epoch 215/500, Training Loss: -0.4614
# Epoch 216/500, Training Loss: -0.4403
# Epoch 217/500, Training Loss: -0.4396
# Epoch 218/500, Training Loss: -0.4648
# Epoch 219/500, Training Loss: -0.4547
# Epoch 220/500, Training Loss: -0.4510
# Epoch 221/500, Training Loss: -0.4751
# Epoch 222/500, Training Loss: -0.4531
# Epoch 223/500, Training Loss: -0.4740
# Epoch 224/500, Training Loss: -0.4689
# Epoch 225/500, Training Loss: -0.4383
# Epoch 226/500, Training Loss: -0.4395
# Epoch 227/500, Training Loss: -0.4368
# Epoch 228/500, Training Loss: -0.4569
# Epoch 229/500, Training Loss: -0.4501
# Epoch 230/500, Training Loss: -0.4553
# Epoch 231/500, Training Loss: -0.4463
# Epoch 232/500, Training Loss: -0.4493
# Epoch 233/500, Training Loss: -0.4428
# Epoch 234/500, Training Loss: -0.4546
# Epoch 235/500, Training Loss: -0.4494
# Epoch 236/500, Training Loss: -0.4498
# Epoch 237/500, Training Loss: -0.4506
# Epoch 238/500, Training Loss: -0.4476
# Epoch 239/500, Training Loss: -0.4596
# Epoch 240/500, Training Loss: -0.4493
# Epoch 241/500, Training Loss: -0.4554
# Epoch 242/500, Training Loss: -0.4384
# Epoch 243/500, Training Loss: -0.4317
# Epoch 244/500, Training Loss: -0.4523
# Epoch 245/500, Training Loss: -0.4254
# Epoch 246/500, Training Loss: -0.4431
# Epoch 247/500, Training Loss: -0.4489
# Epoch 248/500, Training Loss: -0.4490
# Epoch 249/500, Training Loss: -0.4570
# Epoch 250/500, Training Loss: -0.4540
# Epoch 251/500, Training Loss: -0.4435
# Epoch 252/500, Training Loss: -0.4320
# Epoch 253/500, Training Loss: -0.4361
# Epoch 254/500, Training Loss: -0.4427
# Epoch 255/500, Training Loss: -0.4487
# Epoch 256/500, Training Loss: -0.4500
# Epoch 257/500, Training Loss: -0.4324
# Epoch 258/500, Training Loss: -0.4479
# Epoch 259/500, Training Loss: -0.4620
# Epoch 260/500, Training Loss: -0.4563
# Epoch 261/500, Training Loss: -0.4639
# Epoch 262/500, Training Loss: -0.4536
# Epoch 263/500, Training Loss: -0.4459
# Epoch 264/500, Training Loss: -0.4397
# Epoch 265/500, Training Loss: -0.4462
# Epoch 266/500, Training Loss: -0.4790
# Epoch 267/500, Training Loss: -0.4399
# Epoch 268/500, Training Loss: -0.4439
# Epoch 269/500, Training Loss: -0.4602
# Epoch 270/500, Training Loss: -0.4433
# Epoch 271/500, Training Loss: -0.4352
# Epoch 272/500, Training Loss: -0.4564
# Epoch 273/500, Training Loss: -0.4567
# Epoch 274/500, Training Loss: -0.4420
# Epoch 275/500, Training Loss: -0.4423
# Epoch 276/500, Training Loss: -0.4527
# Epoch 277/500, Training Loss: -0.4436
# Epoch 278/500, Training Loss: -0.4344
# Epoch 279/500, Training Loss: -0.4408
# Epoch 280/500, Training Loss: -0.4323
# Epoch 281/500, Training Loss: -0.4345
# Epoch 282/500, Training Loss: -0.4273
# Epoch 283/500, Training Loss: -0.4619
# Epoch 284/500, Training Loss: -0.4543
# Epoch 285/500, Training Loss: -0.4267
# Epoch 286/500, Training Loss: -0.4292
# Epoch 287/500, Training Loss: -0.4595
# Epoch 288/500, Training Loss: -0.4464
# Epoch 289/500, Training Loss: -0.4466
# Epoch 290/500, Training Loss: -0.4229
# Epoch 291/500, Training Loss: -0.4427
# Epoch 292/500, Training Loss: -0.4594
# Epoch 293/500, Training Loss: -0.4341
# Epoch 294/500, Training Loss: -0.4724
# Epoch 295/500, Training Loss: -0.4331
# Epoch 296/500, Training Loss: -0.4695
# Epoch 297/500, Training Loss: -0.4442
# Epoch 298/500, Training Loss: -0.4474
# Epoch 299/500, Training Loss: -0.4536
# Epoch 300/500, Training Loss: -0.4614
# Epoch 301/500, Training Loss: -0.4313
# Epoch 302/500, Training Loss: -0.4550
# Epoch 303/500, Training Loss: -0.4446
# Epoch 304/500, Training Loss: -0.4483
# Epoch 305/500, Training Loss: -0.4436
# Epoch 306/500, Training Loss: -0.4489
# Epoch 307/500, Training Loss: -0.4544
# Epoch 308/500, Training Loss: -0.4569
# Epoch 309/500, Training Loss: -0.4588
# Epoch 310/500, Training Loss: -0.4529
# Epoch 311/500, Training Loss: -0.4463
# Epoch 312/500, Training Loss: -0.4424
# Epoch 313/500, Training Loss: -0.4612
# Epoch 314/500, Training Loss: -0.4391
# Epoch 315/500, Training Loss: -0.4538
# Epoch 316/500, Training Loss: -0.4269
# Epoch 317/500, Training Loss: -0.4579
# Epoch 318/500, Training Loss: -0.4388
# Epoch 319/500, Training Loss: -0.4572
# Epoch 320/500, Training Loss: -0.4616
# Epoch 321/500, Training Loss: -0.4618
# Epoch 322/500, Training Loss: -0.4415
# Epoch 323/500, Training Loss: -0.4701
# Epoch 324/500, Training Loss: -0.4321
# Epoch 325/500, Training Loss: -0.4434
# Epoch 326/500, Training Loss: -0.4324
# Epoch 327/500, Training Loss: -0.4466
# Epoch 328/500, Training Loss: -0.4531
# Epoch 329/500, Training Loss: -0.4482
# Epoch 330/500, Training Loss: -0.4520
# Epoch 331/500, Training Loss: -0.4589
# Epoch 332/500, Training Loss: -0.4494
# Epoch 333/500, Training Loss: -0.4338
# Epoch 334/500, Training Loss: -0.4467
# Epoch 335/500, Training Loss: -0.4600
# Epoch 336/500, Training Loss: -0.4259
# Epoch 337/500, Training Loss: -0.4573
# Epoch 338/500, Training Loss: -0.4595
# Epoch 339/500, Training Loss: -0.4497
# Epoch 340/500, Training Loss: -0.4415
# Epoch 341/500, Training Loss: -0.4634
# Epoch 342/500, Training Loss: -0.4380
# Epoch 343/500, Training Loss: -0.4601
# Epoch 344/500, Training Loss: -0.4380
# Epoch 345/500, Training Loss: -0.4500
# Epoch 346/500, Training Loss: -0.4397
# Epoch 347/500, Training Loss: -0.4525
# Epoch 348/500, Training Loss: -0.4413
# Epoch 349/500, Training Loss: -0.4490
# Epoch 350/500, Training Loss: -0.4321
# Epoch 351/500, Training Loss: -0.4492
# Epoch 352/500, Training Loss: -0.4569
# Epoch 353/500, Training Loss: -0.4725
# Epoch 354/500, Training Loss: -0.4453
# Epoch 355/500, Training Loss: -0.4381
# Epoch 356/500, Training Loss: -0.4441
# Epoch 357/500, Training Loss: -0.4269
# Epoch 358/500, Training Loss: -0.4432
# Epoch 359/500, Training Loss: -0.4612
# Epoch 360/500, Training Loss: -0.4628
# Epoch 361/500, Training Loss: -0.4369
# Epoch 362/500, Training Loss: -0.4698
# Epoch 363/500, Training Loss: -0.4570
# Epoch 364/500, Training Loss: -0.4484
# Epoch 365/500, Training Loss: -0.4463
# Epoch 366/500, Training Loss: -0.4494
# Epoch 367/500, Training Loss: -0.4542
# Epoch 368/500, Training Loss: -0.4470
# Epoch 369/500, Training Loss: -0.4442
# Epoch 370/500, Training Loss: -0.4331
# Epoch 371/500, Training Loss: -0.4460
# Epoch 372/500, Training Loss: -0.4466
# Epoch 373/500, Training Loss: -0.4388
# Epoch 374/500, Training Loss: -0.4412
# Epoch 375/500, Training Loss: -0.4485
# Epoch 376/500, Training Loss: -0.4656
# Epoch 377/500, Training Loss: -0.4415
# Epoch 378/500, Training Loss: -0.4434
# Epoch 379/500, Training Loss: -0.4510
# Epoch 380/500, Training Loss: -0.4547
# Epoch 381/500, Training Loss: -0.4577
# Epoch 382/500, Training Loss: -0.4495
# Epoch 383/500, Training Loss: -0.4544
# Epoch 384/500, Training Loss: -0.4625
# Epoch 385/500, Training Loss: -0.4328
# Epoch 386/500, Training Loss: -0.4633
# Epoch 387/500, Training Loss: -0.4614
# Epoch 388/500, Training Loss: -0.4381
# Epoch 389/500, Training Loss: -0.4550
# Epoch 390/500, Training Loss: -0.4502
# Epoch 391/500, Training Loss: -0.4408
# Epoch 392/500, Training Loss: -0.4402
# Epoch 393/500, Training Loss: -0.4608
# Epoch 394/500, Training Loss: -0.4362
# Epoch 395/500, Training Loss: -0.4457
# Epoch 396/500, Training Loss: -0.4519
# Epoch 397/500, Training Loss: -0.4347
# Epoch 398/500, Training Loss: -0.4639
# Epoch 399/500, Training Loss: -0.4601
# Epoch 400/500, Training Loss: -0.4513
# Epoch 401/500, Training Loss: -0.4546
# Epoch 402/500, Training Loss: -0.4465
# Epoch 403/500, Training Loss: -0.4545
# Epoch 404/500, Training Loss: -0.4287
# Epoch 405/500, Training Loss: -0.4510
# Epoch 406/500, Training Loss: -0.4635
# Epoch 407/500, Training Loss: -0.4578
# Epoch 408/500, Training Loss: -0.4606
# Epoch 409/500, Training Loss: -0.4519
# Epoch 410/500, Training Loss: -0.4178
# Epoch 411/500, Training Loss: -0.4395
# Epoch 412/500, Training Loss: -0.4684
# Epoch 413/500, Training Loss: -0.4579
# Epoch 414/500, Training Loss: -0.4554
# Epoch 415/500, Training Loss: -0.4457
# Epoch 416/500, Training Loss: -0.4532
# Epoch 417/500, Training Loss: -0.4363
# Epoch 418/500, Training Loss: -0.4363
# Epoch 419/500, Training Loss: -0.4655
# Epoch 420/500, Training Loss: -0.4434
# Epoch 421/500, Training Loss: -0.4458
# Epoch 422/500, Training Loss: -0.4471
# Epoch 423/500, Training Loss: -0.4506
# Epoch 424/500, Training Loss: -0.4474
# Epoch 425/500, Training Loss: -0.4341
# Epoch 426/500, Training Loss: -0.4487
# Epoch 427/500, Training Loss: -0.4468
# Epoch 428/500, Training Loss: -0.4515
# Epoch 429/500, Training Loss: -0.4268
# Epoch 430/500, Training Loss: -0.4673
# Epoch 431/500, Training Loss: -0.4374
# Epoch 432/500, Training Loss: -0.4376
# Epoch 433/500, Training Loss: -0.4273
# Epoch 434/500, Training Loss: -0.4476
# Epoch 435/500, Training Loss: -0.4632
# Epoch 436/500, Training Loss: -0.4637
# Epoch 437/500, Training Loss: -0.4482
# Epoch 438/500, Training Loss: -0.4661
# Epoch 439/500, Training Loss: -0.4327
# Epoch 440/500, Training Loss: -0.4547
# Epoch 441/500, Training Loss: -0.4649
# Epoch 442/500, Training Loss: -0.4306
# Epoch 443/500, Training Loss: -0.4576
# Epoch 444/500, Training Loss: -0.4476
# Epoch 445/500, Training Loss: -0.4240
# Epoch 446/500, Training Loss: -0.4670
# Epoch 447/500, Training Loss: -0.4513
# Epoch 448/500, Training Loss: -0.4326
# Epoch 449/500, Training Loss: -0.4270
# Epoch 450/500, Training Loss: -0.4419
# Epoch 451/500, Training Loss: -0.4457
# Epoch 452/500, Training Loss: -0.4215
# Epoch 453/500, Training Loss: -0.4689
# Epoch 454/500, Training Loss: -0.4582
# Epoch 455/500, Training Loss: -0.4503
# Epoch 456/500, Training Loss: -0.4490
# Epoch 457/500, Training Loss: -0.4466
# Epoch 458/500, Training Loss: -0.4556
# Epoch 459/500, Training Loss: -0.4423
# Epoch 460/500, Training Loss: -0.4488
# Epoch 461/500, Training Loss: -0.4849
# Epoch 462/500, Training Loss: -0.4627
# Epoch 463/500, Training Loss: -0.4419
# Epoch 464/500, Training Loss: -0.4558
# Epoch 465/500, Training Loss: -0.4531
# Epoch 466/500, Training Loss: -0.4536
# Epoch 467/500, Training Loss: -0.4428
# Epoch 468/500, Training Loss: -0.4446
# Epoch 469/500, Training Loss: -0.4545
# Epoch 470/500, Training Loss: -0.4590
# Epoch 471/500, Training Loss: -0.4508
# Epoch 472/500, Training Loss: -0.4530
# Epoch 473/500, Training Loss: -0.4499
# Epoch 474/500, Training Loss: -0.4358
# Epoch 475/500, Training Loss: -0.4359
# Epoch 476/500, Training Loss: -0.4645
# Epoch 477/500, Training Loss: -0.4526
# Epoch 478/500, Training Loss: -0.4407
# Epoch 479/500, Training Loss: -0.4616
# Epoch 480/500, Training Loss: -0.4399
# Epoch 481/500, Training Loss: -0.4619
# Epoch 482/500, Training Loss: -0.4430
# Epoch 483/500, Training Loss: -0.4367
# Epoch 484/500, Training Loss: -0.4319
# Epoch 485/500, Training Loss: -0.4475
# Epoch 486/500, Training Loss: -0.4297
# Epoch 487/500, Training Loss: -0.4493
# Epoch 488/500, Training Loss: -0.4668
# Epoch 489/500, Training Loss: -0.4472
# Epoch 490/500, Training Loss: -0.4442
# Epoch 491/500, Training Loss: -0.4436
# Epoch 492/500, Training Loss: -0.4583
# Epoch 493/500, Training Loss: -0.4369
# Epoch 494/500, Training Loss: -0.4433
# Epoch 495/500, Training Loss: -0.4530
# Epoch 496/500, Training Loss: -0.4405
# Epoch 497/500, Training Loss: -0.4619
# Epoch 498/500, Training Loss: -0.4505
# Epoch 499/500, Training Loss: -0.4441
# Epoch 500/500, Training Loss: -0.4477

# %%
# ── 4) Paired sampling via reseeding ──────────────────────────────────────────
N_effect = 10**5
with torch.no_grad():
    Y0_eff = model.cocycle(X*0+0,X,Y)
    Y1_eff = model.cocycle(X*0+1,X,Y)
delta = (Y1_eff - Y0_eff).squeeze(-1)
Y0 = MixedTails().sample((N_effect,)).to(device)
Y1 = Y0*2
true_delta = Y1-Y0


def t(x):
    #return torch.log(x.abs()+1)*torch.sign(x)
    return torch.sigmoid(x)

# ── 5) Plot empirical histogram of ΔY ────────────────────────────────────────
plt.figure(figsize=(6,4))
plt.hist(t(true_delta), bins=50, density=True, alpha=0.8)
plt.hist(t(delta), bins=50, density=True, alpha=0.8)
plt.title("Empirical distribution of $Y(1)-Y(0)$")
plt.xlabel("$Y(1)-Y(0)$")
plt.ylabel("Density")
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as mtick
from scipy.stats import norm
from ssvkernel import ssvkernel

# ---------- aesthetics ----------
plt.rcParams.update({
    'font.size': 72,
    'axes.titlesize': 72,
    'axes.labelsize': 72,
    'xtick.labelsize': 48,
    'ytick.labelsize': 48
})
sns.set_style("whitegrid")
col_data, col_true = sns.color_palette("colorblind", 2)

# ---------- KDE estimation ----------
x_grid = np.linspace(0, 1, 200)
y_hat = ssvkernel(t(delta).numpy(), tin=x_grid, M=80, nbs=100, WinFunc='Gauss')[0]
y_true = ssvkernel(t(true_delta).numpy(), tin=x_grid, M=80, nbs=100, WinFunc='Gauss')[0]

# ---------- plot ----------
fig, ax = plt.subplots(figsize=(24, 20))  # ⬅️ doubled size

ax.plot(x_grid, y_hat, color=col_data, lw=12, label="Estimated")
ax.fill_between(x_grid, 0, y_hat, color=col_data, alpha=0.4)
ax.plot(x_grid, y_true, color=col_true, lw=15, ls="--", label="True")

# Axis labels and title with larger fontsize
ax.set_xlabel(r"$Y(1) - Y(0)$", fontsize=72)
ax.set_ylabel("Density", fontsize=72)
ax.set_title(r"CMMD - Mixed Tails Noise", fontsize=72)

# Bigger tick labels
ax.tick_params(axis='x', labelsize=60)
ax.tick_params(axis='y', labelsize=60)

# Formatting
ax.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.1f'))
ax.legend(frameon=False, fontsize=64)
ax.grid(alpha=0.5)
fig.tight_layout()
fig.savefig("cocycles_misspec_mixedtails_large.png", bbox_inches="tight")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import seaborn as sns

# Sort the data
delta_sorted = np.sort(t(delta))
true_delta_sorted = np.sort(t(true_delta))

# Empirical CDF values
n = len(delta_sorted)
m = len(true_delta_sorted)
cdf_delta = np.linspace(0, 1, n, endpoint=False)
cdf_true = np.linspace(0, 1, m, endpoint=False)

# Colors
col_data, col_true = sns.color_palette("colorblind", 2)

# Plot
plt.rcdefaults()
fig, ax = plt.subplots(figsize=(15, 12))

ax.plot(delta_sorted, cdf_delta, color=col_data, lw=5, label="Estimated")
ax.plot(true_delta_sorted, cdf_true, color=col_true, lw=7.5, ls="--", label="True")

ax.set_xlabel(r"$Y(1) - Y(0)$", fontsize=48)
ax.set_ylabel("CDF", fontsize=48)
ax.set_title(r"Empirical CDFs of $\Delta$", fontsize=48)
ax.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.1f'))
ax.legend(frameon=False, fontsize=36)
ax.grid(alpha=0.5)
fig.tight_layout()
fig.savefig("cdf_comparison_delta.png", bbox_inches="tight")
plt.show()
